# %% [markdown]
# # Milestone 4 — Model Training & Experimentation
# ## AI-Based Early Mental Health Breakdown Detection from Speech Patterns
# ### Group 6 | DS & AI Lab Project (BSDA4001)
# Team: Om Aryan · Pankaj Mohan Sahu · Drashti Shah · Mahi Mudgal · G Hamsini
#
# ---
#
# ## Notebook Overview
#
# | Section | Dataset | Task | Key Experiments |
# |---|---|---|---|
# | **0** | — | Setup | Installs, imports, paths, utilities |
# | **1** | RAVDESS | 8-class emotion | SVM/RF/XGB/GBM, XGB grid, MLP optimizers, regularisation, schedulers |
# | **2** | DAIC-WOZ + MODMA | Depression detection | Branch tuning, fusion, PHQ-8 regression, small-data SVM |
# | **3** | SWELL/WESAD | Stress detection | MLP architecture, optimiser, schedulers, regularisation ablation |
# | **4** | All | Summary | Grand results table, key findings, M5 roadmap |
#
# **Goal:** Train initial models; experiment with hyperparameters, optimisation methods, and regularisation techniques using ONLY real processed data.
#
# ---
#
# ## Hardware & Evaluation Metrics
#
# | Item | Detail |
# |---|---|
# | **Platform** | Kaggle T4 GPU (16 GB VRAM) / local CPU fallback |
# | **GPU** | NVIDIA Tesla T4 · CUDA 12.8 · PyTorch 2.10 · XGBoost 3.2 |
# | **Total runtime** | ~60 min on Kaggle T4 GPU |
# | **Memory** | ~4–6 GB RAM peak (SWELL-HRV: 126K samples) |
#
# | Task | Primary Metric | Secondary Metrics |
# |---|---|---|
# | Multi-class classification | **Macro-F1** | Accuracy, per-class F1, Confusion Matrix |
# | Binary classification | **Macro-F1** | ROC-AUC, AUPRC (PR-AUC) |
# | Regression (PHQ-8 / stress) | **RMSE** | MAE, Band Accuracy |
#
# ---
#
# ## Preprocessing Summary (carried forward from Milestone 3)
#
# | Dataset | Feature Extraction Method | Final Shape |
# |---|---|---|
# | RAVDESS | MFCC (40), chroma (12), mel-spectrogram (128), ZCR, RMS, spectral stats | 840×338 train |
# | DAIC-WOZ | COVAREP (74 acoustic) + NLP bag-of-words (14) + OpenFace AUs (111 visual) | 107×448 → 107×2231 (enriched) |
# | MODMA | MFCCs, spectral centroid/rolloff, chroma, ZCR | 44×1002 (CV pool) |
# | SWELL-HRV | HRV time-domain (SDNN, RMSSD, pNN50) + freq-domain (LF/HF ratio) | 126K×75 |
# | WESAD-HRV | Same HRV pipeline, wearable chest sensor | 49K×40 |
# | SWELL-EDA | Skin conductance level, slope, derivative features | 34K×46 |
# | WESAD-EDA | Same EDA pipeline, E4 wristband sensor | 12K×45 |
#
# All datasets use **subject-level splits** to prevent data leakage across train/val/test.

# %% [markdown]
# ---
# # Section 0 — Environment Setup & Shared Utilities
#
# Sets up packages, imports, paths, and utility functions used by all later sections.
# Supports local Windows, Kaggle, and Colab environments.

# %%
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Cell 0.0c — Data Source Configuration  (Edit this cell before running on Colab)
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# KAGGLE USERS:  Leave everything as None — auto-detection handles it.
#
# COLAB USERS:  Choose ONE of the two options below:
#
#  Option A — Google Drive ZIP  (recommended)
#    1. Upload processed_data.zip to your Google Drive root (or any subfolder).
#    2. Set COLAB_ZIP_PATH to its full /content/drive/... path.
#       Example: COLAB_ZIP_PATH = "/content/drive/MyDrive/processed_data.zip"
#
#  Option B — Kaggle API download  (needs kaggle.json from kaggle.com → Settings)
#    1. Download kaggle.json from kaggle.com → Account → API → Create New Token.
#    2. Upload kaggle.json to your Google Drive root.
#    3. Set KAGGLE_DATASET to the dataset slug shown on the Kaggle dataset page.
#       Example: KAGGLE_DATASET = "youruser/group6-ds-processed"
#
# LOCAL USERS:  Leave everything as None — detected automatically.
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━

# Option A — set to your Drive ZIP path, or leave None for auto-detection
COLAB_ZIP_PATH  = None   # e.g. "/content/drive/MyDrive/processed_data.zip"

# Option B — Kaggle API
KAGGLE_DATASET  = None   # e.g. "youruser/group6-ds-processed"
KAGGLE_JSON_SRC = None   # path to kaggle.json; None = auto-search Drive root

print(f"[Config] COLAB_ZIP_PATH  = {COLAB_ZIP_PATH}")
print(f"[Config] KAGGLE_DATASET  = {KAGGLE_DATASET}")
# Out:
# [Config] COLAB_ZIP_PATH  = None
# [Config] KAGGLE_DATASET  = None

# %%
# Cell 0.0d: CUDA Compatibility Check
# P100 (sm_60) + Python 3.12 has NO compatible PyTorch GPU wheel.
# torch 1.x (last sm_60 support) only has Python 3.7-3.10 wheels.
# ONLY FIX: switch Kaggle GPU to T4 in Session Options.

import subprocess, sys, os

def _run(cmd):
    try:
        return subprocess.check_output(cmd, stderr=subprocess.DEVNULL).decode().strip()
    except Exception:
        return ''

_gpu  = _run(['nvidia-smi','--query-gpu=name','--format=csv,noheader'])
_cap  = _run(['nvidia-smi','--query-gpu=compute_cap','--format=csv,noheader'])
print('GPU      :', _gpu or 'not found')
print('SM cap   :', _cap or 'unknown')
print('Python   :', sys.version.split()[0])

_sm = 0
if _cap:
    try:
        _p = _cap.split('.')
        _sm = int(_p[0]) * 10 + int(_p[1])
    except Exception:
        pass

_torch_ok = False
try:
    import torch
    print('PyTorch  :', torch.__version__)
    if torch.cuda.is_available():
        torch.nn.BatchNorm1d(4).cuda()(torch.randn(8, 4, device='cuda'))
        print('[OK] CUDA smoke-test passed.')
        _torch_ok = True
    else:
        print('[INFO] torch imported, no CUDA - will run on CPU.')
        _torch_ok = True
except (ImportError, OSError) as _ie:
    print('[BROKEN] torch import failed:', str(_ie)[:100])
except Exception as _ee:
    print('[FAIL] CUDA smoke-test:', str(_ee)[:100])

if not _torch_ok:
    print('')
    print('=' * 60)
    if _sm > 0 and _sm < 70:
        _py = sys.version.split()[0]
        print('INCOMPATIBILITY SUMMARY:')
        print('  GPU     :', _gpu, '(sm_' + str(_sm) + ' = Pascal, 2016)')
        print('  Python  :', _py)
        print('  Problem : PyTorch 2.x dropped sm<70 support.')
        print('            PyTorch 1.x (last sm_60 support) has NO Python 3.10+ wheels.')
        print('            => No pip fix exists for this combination.')
        print('')
        print('ACTION REQUIRED:')
        print('  Kaggle -> Session Options -> Accelerator -> GPU T4 x2 -> Save')
        print('  T4 = sm_75, fully supported by PyTorch 2.x + Python 3.12')
        print('')
        print('FALLBACK: Forcing CPU mode so notebook can still run (slowly).')
        os.environ['CUDA_VISIBLE_DEVICES'] = ''
        print('  CUDA_VISIBLE_DEVICES set to empty - all ops will use CPU.')
    else:
        print('Attempting PyTorch reinstall for sm_' + str(_sm) + ' ...')
        _r = subprocess.run(
            [sys.executable, '-m', 'pip', 'install', '-q',
             '--force-reinstall', '--no-deps',
             'torch', 'torchvision', 'torchaudio',
             '--extra-index-url', 'https://download.pytorch.org/whl/cu121'],
            capture_output=True
        )
        if _r.returncode == 0:
            print('Reinstall done. RESTART RUNTIME then re-run from top.')
            try:
                import IPython
                IPython.Application.instance().kernel.do_shutdown(True)
            except Exception:
                pass
        else:
            print('Reinstall failed. Switch GPU to T4 in Session Options.')
    print('=' * 60)
# Out:
# GPU      : Tesla T4
# Tesla T4
# SM cap   : 7.5
# 7.5
# Python   : 3.12.12
# PyTorch  : 2.10.0+cu128
# [OK] CUDA smoke-test passed.

# %%
# ── Cell 0.1: Install packages (safe to run on Kaggle/Colab; skipped if already installed) ──
import subprocess, sys

def install(pkg):
    subprocess.check_call([sys.executable, "-m", "pip", "install", pkg, "-q"])

required = {
    "xgboost":           "xgboost",
    "lightgbm":          "lightgbm",
    "shap":              "shap",
    "seaborn":           "seaborn",
    "scikit-learn":      "sklearn",
    "scipy":             "scipy",
    "imbalanced-learn":  "imblearn",
    "soundfile":         "soundfile",
}

for pip_name, import_name in required.items():
    try:
        __import__(import_name)
        print(f"  {pip_name} already installed.")
    except ImportError:
        print(f"Installing {pip_name}...")
        install(pip_name)
        print(f"  {pip_name} installed.")

# PyTorch — optional but strongly recommended
try:
    import torch
    print(f"  torch {torch.__version__} available  |  CUDA: {torch.cuda.is_available()}")
    TORCH_AVAILABLE = True
except ImportError:
    print("  torch not available — neural-net cells will be skipped gracefully.")
    TORCH_AVAILABLE = False

print("\nPackage check complete.")
# Out:
#   xgboost already installed.
#   lightgbm already installed.
#   shap already installed.
#   seaborn already installed.
#   scikit-learn already installed.
#   scipy already installed.
#   imbalanced-learn already installed.
#   soundfile already installed.
#   torch 2.10.0+cu128 available  |  CUDA: True
#
# Package check complete.

# %%
# ── Cell 0.2: All imports & global constants ──
import os, json, time, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import StratifiedKFold, GroupShuffleSplit, cross_val_score
from sklearn.metrics import (
    classification_report, f1_score, accuracy_score,
    roc_auc_score, average_precision_score,
    mean_squared_error, mean_absolute_error,
    confusion_matrix, ConfusionMatrixDisplay
)
from sklearn.preprocessing import StandardScaler

import xgboost as xgb
import lightgbm as lgb

try:
    import torch
    import torch.nn as nn
    import torch.optim as optim
    from torch.utils.data import DataLoader, TensorDataset
    TORCH_AVAILABLE = True
except ImportError:
    TORCH_AVAILABLE = False

from scipy import stats
warnings.filterwarnings("ignore")

np.random.seed(42)
if TORCH_AVAILABLE:
    torch.manual_seed(42)

sns.set_theme(style="whitegrid", font_scale=1.1)
plt.rcParams["figure.dpi"] = 100

print("All imports successful.")
print(f"NumPy {np.__version__} | Pandas {pd.__version__}")
print(f"XGBoost {xgb.__version__} | LightGBM {lgb.__version__}")
if TORCH_AVAILABLE:
    print(f"PyTorch {torch.__version__}")
# Out:
# All imports successful.
# NumPy 2.0.2 | Pandas 2.3.3
# XGBoost 3.2.0 | LightGBM 4.6.0
# PyTorch 2.10.0+cu128

# %%
# -- Cell 0.2b: Bootstrap — works on Colab (Drive), Kaggle, and local --
import zipfile, shutil, os as _os
from pathlib import Path

# ── Detect environment — use env var + metadata file, not just path existence ──
# Colab sometimes has /kaggle/input as an empty dir; KAGGLE_KERNEL_RUN_TYPE is
# only set in real Kaggle kernels, and /kaggle/kernel-metadata.json too.
import os as _os_env
_ON_KAGGLE = (
    Path("/kaggle/input").exists() and (
        _os_env.environ.get("KAGGLE_KERNEL_RUN_TYPE") is not None or
        Path("/kaggle/kernel-metadata.json").exists()
    )
)
_ON_COLAB  = Path("/content").exists() and not _ON_KAGGLE

COLAB_DATA   = Path("/kaggle/working/processed_data") if _ON_KAGGLE else Path("/content/processed_data")
COLAB_MODELS = Path("/kaggle/working/models_output")  if _ON_KAGGLE else Path("/content/models_output")
DRIVE_ROOT   = Path("/content/drive/MyDrive")
print(f"Environment pre-detection: {'kaggle' if _ON_KAGGLE else 'colab/local'} | COLAB_DATA={COLAB_DATA}")

PROCESSED_ZIP     = None
MODELS_ZIP        = None
ZIP_ROOT_PREFIX   = ""
MODELS_ZIP_PREFIX = ""
DRIVE_PROCESSED_DIR = None

# ── Mount Drive (Colab only) ──
if _ON_COLAB:
    try:
        from google.colab import drive
        drive.mount("/content/drive", force_remount=False)
        print("Google Drive mounted.")
    except Exception as _mount_err:
        print(f"INFO: drive.mount() unavailable: {_mount_err}")
        print("  -> Run on Kaggle: dataset already attached there.")
        print("  -> Or upload processed_data.zip via Colab Files panel and re-run.")

# ── Kaggle: show what is mounted ──
if _ON_KAGGLE:
    print(f"Kaggle environment detected — skipping Drive mount.")
    print(f"Kaggle input datasets: {[p.name for p in Path('/kaggle/input').iterdir()]}")
    print("Full /kaggle/input tree:")
    for _root, _dirs, _fnames in _os.walk("/kaggle/input"):
        _lvl = _root.replace("/kaggle/input", "").count(_os.sep)
        print("  " * _lvl + _os.path.basename(_root) + "/")
        for _fn in sorted(_fnames)[:8]:
            print("  " * (_lvl + 1) + _fn)
        if _lvl >= 4:
            _dirs.clear()


def _guess_prefix(zip_path, expected_root):
    with zipfile.ZipFile(zip_path, "r") as zf:
        members = [m for m in zf.namelist() if m.strip("/")]
    root = expected_root.rstrip("/") + "/"
    if members and all(m.startswith(root) for m in members):
        return root
    return ""


def _inspect_zip(zip_path, label, preview=10):
    with zipfile.ZipFile(zip_path, "r") as zf:
        members = [m for m in zf.namelist() if not m.endswith("/")]
    top = {}
    for m in members:
        head = m.split("/")[0]
        top[head] = top.get(head, 0) + 1
    print(f"\nZIP {label}: {zip_path}")
    print(f"   Files inside: {len(members):,}")
    print(f"   Top-level groups: {top}")
    if members:
        print("   Sample entries:")
        for m in members[:preview]:
            print(f"    - {m}")


def _extract_selected(zip_path, prefix, rel_paths, target_root):
    target_root.mkdir(parents=True, exist_ok=True)
    extracted, missing = [], []
    with zipfile.ZipFile(zip_path, "r") as zf:
        members = set(zf.namelist())
        for rel in rel_paths:
            rel_norm = rel.replace("\\", "/")
            member   = f"{prefix}{rel_norm}"
            out_path = target_root / rel_norm
            if out_path.exists() and out_path.stat().st_size > 0:
                extracted.append((rel_norm, "cached"))
                continue
            if member not in members:
                missing.append(rel_norm)
                continue
            out_path.parent.mkdir(parents=True, exist_ok=True)
            with zf.open(member) as src_f, open(out_path, "wb") as dst_f:
                shutil.copyfileobj(src_f, dst_f)
            extracted.append((rel_norm, "new"))
    return extracted, missing


def _pick_valid_zip(candidates, keywords, label):
    matched = [z for z in candidates if all(k in z.name.lower() for k in keywords)]
    if not matched:
        return None
    print(f"\nChecking {label} ZIP candidates:")
    for z in matched:
        size_gb = z.stat().st_size / (1024 ** 3)
        ok = zipfile.is_zipfile(z)
        print(f"   - {z}  ({size_gb:.2f} GB)  -> {'valid' if ok else 'INVALID'}")
        if ok:
            return z
    return None


def _find_processed_dir_in_drive(drive_root):
    if not drive_root.exists():
        return None
    direct_candidates = [
        drive_root / "processed_data",
        drive_root / "Group-6-DS-and-AI-Lab-Project" / "processed_data",
    ]
    for c in direct_candidates:
        if (c / "daicwoz" / "daicwoz_X_train.npy").exists():
            return c
    anchor_hits = list(drive_root.rglob("daicwoz_X_train.npy"))
    for hit in anchor_hits:
        parts = hit.parts
        if "daicwoz" in parts:
            idx = parts.index("daicwoz")
            base = Path(*parts[:idx])
            if (base / "ravdess" / "ravdess_X_train.npy").exists():
                return base
    return None


# ── Gather ZIP candidates (Colab/local) ──
# ── User-specified ZIP override (set COLAB_ZIP_PATH in Cell 0.0c) ──
_zip_locked = False
if "COLAB_ZIP_PATH" in dir() and COLAB_ZIP_PATH is not None:
    _user_z = Path(str(COLAB_ZIP_PATH))
    if _user_z.exists() and zipfile.is_zipfile(_user_z):
        PROCESSED_ZIP   = _user_z
        ZIP_ROOT_PREFIX = _guess_prefix(_user_z, "processed_data")
        _zip_locked     = True
        print(f"[Config] Using COLAB_ZIP_PATH: {PROCESSED_ZIP}")
    else:
        print(f"[Config] WARNING — COLAB_ZIP_PATH not found or invalid: {COLAB_ZIP_PATH}")

# ── Auto-detect ZIP from Drive / /content (skipped if user override worked) ──
if not _zip_locked:
    zip_candidates = []
    if DRIVE_ROOT.exists():
        zip_candidates.extend(sorted(DRIVE_ROOT.rglob("*.zip"),
                                     key=lambda f: f.stat().st_size, reverse=True))
    zip_candidates.extend(sorted(Path("/content").glob("*.zip"),
                                  key=lambda f: f.stat().st_size, reverse=True))
    PROCESSED_ZIP = _pick_valid_zip(zip_candidates, ["processed_data"], "processed_data")
    MODELS_ZIP    = _pick_valid_zip(zip_candidates, ["models_output"], "models_output")
else:
    zip_candidates = []
    MODELS_ZIP = None

if PROCESSED_ZIP is None:
    for z in zip_candidates:
        if zipfile.is_zipfile(z):
            PROCESSED_ZIP = z
            print(f"\nUsing fallback valid zip: {PROCESSED_ZIP}")
            break

if PROCESSED_ZIP is not None:
    ZIP_ROOT_PREFIX = _guess_prefix(PROCESSED_ZIP, "processed_data")
    _inspect_zip(PROCESSED_ZIP, "Processed Data", preview=10)
    print(f"ZIP root prefix: '{ZIP_ROOT_PREFIX or '(none)'}\'")
else:
    print("\nNo valid processed_data ZIP found.")
    DRIVE_PROCESSED_DIR = _find_processed_dir_in_drive(DRIVE_ROOT)
    if DRIVE_PROCESSED_DIR:
        print(f"Found extracted processed_data in Drive: {DRIVE_PROCESSED_DIR}")
    else:
        print("No extracted processed_data folder found in Drive either.")

CRITICAL_DATA_REL = [
    # ── RAVDESS ──
    "ravdess/ravdess_X_train.npy", "ravdess/ravdess_X_val.npy", "ravdess/ravdess_X_test.npy",
    "ravdess/ravdess_y_train.npy", "ravdess/ravdess_y_val.npy", "ravdess/ravdess_y_test.npy",
    "ravdess/ravdess_feature_cols.txt", "ravdess/ravdess_emotion_label_map.json",
    "ravdess/ravdess_scaler.pkl",
    "ravdess/ravdess_metadata.csv", "ravdess/ravdess_actor_splits.csv",
    "ravdess/ravdess_features.csv",
    # ── DAIC-WOZ ──
    "daicwoz/daicwoz_X_train.npy", "daicwoz/daicwoz_X_val.npy", "daicwoz/daicwoz_X_test.npy",
    "daicwoz/daicwoz_y_train_bin.npy", "daicwoz/daicwoz_y_val_bin.npy", "daicwoz/daicwoz_y_test_bin.npy",
    "daicwoz/daicwoz_y_train_score.npy", "daicwoz/daicwoz_y_val_score.npy", "daicwoz/daicwoz_y_test_score.npy",
    "daicwoz/daicwoz_feature_cols.txt",
    "daicwoz/daicwoz_scaler.pkl",
    "daicwoz/daicwoz_features.csv", "daicwoz/daicwoz_participant_splits.csv",
    # ── MODMA ──
    "modma_audio/modma_audio_X_train.npy", "modma_audio/modma_audio_X_val.npy", "modma_audio/modma_audio_X_test.npy",
    "modma_audio/modma_audio_y_train.npy", "modma_audio/modma_audio_y_val.npy", "modma_audio/modma_audio_y_test.npy",
    "modma_audio/modma_audio_feature_cols.txt", "modma_audio/modma_audio_feature_ranking.csv",
    "modma_audio/modma_audio_scaler.pkl",
    "modma_audio/modma_audio_subject_splits.csv", "modma_audio/modma_audio_features_raw.csv",
    # ── Stress — classification (X, y, subject_ids, feature_cols, scaler) ──
    "stress/stress_swell_hrv_class_X.npy", "stress/stress_swell_hrv_class_y.npy",
    "stress/stress_swell_hrv_class_subject_ids.npy", "stress/stress_swell_hrv_class_feature_cols.txt",
    "stress/stress_swell_hrv_class_scaler.pkl",
    "stress/stress_wesad_hrv_class_X.npy", "stress/stress_wesad_hrv_class_y.npy",
    "stress/stress_wesad_hrv_class_subject_ids.npy", "stress/stress_wesad_hrv_class_feature_cols.txt",
    "stress/stress_wesad_hrv_class_scaler.pkl",
    "stress/stress_swell_eda_class_X.npy", "stress/stress_swell_eda_class_y.npy",
    "stress/stress_swell_eda_class_subject_ids.npy", "stress/stress_swell_eda_class_feature_cols.txt",
    "stress/stress_swell_eda_class_scaler.pkl",
    "stress/stress_wesad_eda_class_X.npy", "stress/stress_wesad_eda_class_y.npy",
    "stress/stress_wesad_eda_class_subject_ids.npy", "stress/stress_wesad_eda_class_feature_cols.txt",
    "stress/stress_wesad_eda_class_scaler.pkl",
    # ── Stress — regression (X, y, subject_ids, scaler) ──
    "stress/stress_swell_hrv_regre_X.npy", "stress/stress_swell_hrv_regre_y.npy",
    "stress/stress_swell_hrv_regre_subject_ids.npy", "stress/stress_swell_hrv_regre_scaler.pkl",
    "stress/stress_swell_eda_regre_X.npy", "stress/stress_swell_eda_regre_y.npy",
    "stress/stress_swell_eda_regre_subject_ids.npy", "stress/stress_swell_eda_regre_scaler.pkl",
    "stress/stress_wesad_hrv_regre_X.npy", "stress/stress_wesad_hrv_regre_y.npy",
    "stress/stress_wesad_hrv_regre_subject_ids.npy", "stress/stress_wesad_hrv_regre_scaler.pkl",
    "stress/stress_wesad_eda_regre_X.npy", "stress/stress_wesad_eda_regre_y.npy",
    "stress/stress_wesad_eda_regre_subject_ids.npy", "stress/stress_wesad_eda_regre_scaler.pkl",
    # ── Stress — full CSVs + feature ranks ──
    "stress/stress_swell_hrv_full.csv", "stress/stress_swell_eda_full.csv",
    "stress/stress_wesad_hrv_full.csv", "stress/stress_wesad_eda_full.csv",
    "stress/stress_feature_ranks.json",
]


# ── Extract critical data ──
_DATA_INDICATORS = [
    "daicwoz/daicwoz_features.csv",
    "daicwoz/daicwoz_feature_cols.txt",
    "ravdess/ravdess_feature_cols.txt",
    "daicwoz/daicwoz_X_train.npy",
]

if PROCESSED_ZIP is not None:
    data_extracted, data_missing = _extract_selected(
        PROCESSED_ZIP, ZIP_ROOT_PREFIX, CRITICAL_DATA_REL, COLAB_DATA)
    print(f"\nCritical data files ready : {len(data_extracted)}/{len(CRITICAL_DATA_REL)}")
    print(f"Newly extracted           : {sum(1 for _, s in data_extracted if s == 'new')}")
    if data_missing:
        print("Missing from ZIP:")
        for p in data_missing:
            print(f"   - {p}")
elif DRIVE_PROCESSED_DIR is not None:
    mirrored, missing = 0, []
    for rel in CRITICAL_DATA_REL:
        src = DRIVE_PROCESSED_DIR / rel
        dst = COLAB_DATA / rel
        if src.exists():
            dst.parent.mkdir(parents=True, exist_ok=True)
            if not dst.exists() or dst.stat().st_size == 0:
                shutil.copy2(src, dst)
            mirrored += 1
        else:
            missing.append(rel)
    print(f"\nMirrored {mirrored}/{len(CRITICAL_DATA_REL)} files from Drive folder.")
    if missing:
        print("Missing in Drive folder:")
        for p in missing: print(f"   - {p}")
else:
    # ── Colab fallback: try Kaggle API download if KAGGLE_DATASET is configured ──
    if _ON_COLAB and "KAGGLE_DATASET" in dir() and KAGGLE_DATASET is not None:
        import subprocess as _sp, shutil as _sh
        try:
            _kj = globals().get("KAGGLE_JSON_SRC", None)
            if _kj is None:
                for _cj in [DRIVE_ROOT / "kaggle.json", Path("/content/kaggle.json")]:
                    if Path(str(_cj)).exists(): _kj = str(_cj); break
            if _kj:
                _kk = Path("~/.kaggle").expanduser(); _kk.mkdir(parents=True, exist_ok=True)
                _sh.copy(str(_kj), str(_kk / "kaggle.json"))
                import os as _os3; _os3.chmod(str(_kk / "kaggle.json"), 0o600)
                print(f"  kaggle.json installed from {_kj}")
            _sp.run(["pip", "install", "kaggle", "-q"], check=True)
            print(f"\n  Downloading Kaggle dataset: {KAGGLE_DATASET} ...")
            _sp.run(["kaggle", "datasets", "download", "-d", KAGGLE_DATASET,
                     "-p", "/content/", "--force"], check=True)
            _dl = next(iter(sorted(Path("/content").glob("*.zip"),
                           key=lambda f: f.stat().st_size, reverse=True)), None)
            if _dl and zipfile.is_zipfile(_dl):
                PROCESSED_ZIP   = _dl
                ZIP_ROOT_PREFIX = _guess_prefix(PROCESSED_ZIP, "processed_data")
                COLAB_DATA      = Path("/content/processed_data")
                _ext, _mis = _extract_selected(
                    PROCESSED_ZIP, ZIP_ROOT_PREFIX, CRITICAL_DATA_REL, COLAB_DATA)
                print(f"  Kaggle download ready: {len(_ext)}/{len(CRITICAL_DATA_REL)} files")
                if _mis: print(f"  Missing: {_mis[:5]}")
        except Exception as _ke:
            print(f"  Kaggle API download failed: {_ke}")
            print(f"  -> Set COLAB_ZIP_PATH in Cell 0.0c to your Drive ZIP path.")
    elif _ON_COLAB:
        print("\n[Colab] No data source found. Options:")
        print("  A) Set COLAB_ZIP_PATH in Cell 0.0c to your Drive ZIP path.")
        print("  B) Set KAGGLE_DATASET + KAGGLE_JSON_SRC in Cell 0.0c to download via API.")

    # ── Kaggle: walk /kaggle/input to find dataset (slug-independent) ──
    _KWORK     = Path("/kaggle/working/processed_data")
    _kaggle_ok = False
    _KROOT     = None

    if _ON_KAGGLE:
        for _d in sorted(Path("/kaggle/input").iterdir()):
            if not _d.is_dir():
                continue
            # Case A: ZIP file anywhere up to 2 levels deep
            _kzips = list(_d.glob("*.zip")) + list(_d.glob("*/*.zip"))
            _kzips = [z for z in _kzips if zipfile.is_zipfile(z)]
            if _kzips:
                _kz = max(_kzips, key=lambda z: z.stat().st_size)
                print(f"  Kaggle ZIP found: {_kz}  ({_kz.stat().st_size/1e9:.1f} GB)")
                PROCESSED_ZIP   = _kz
                ZIP_ROOT_PREFIX = _guess_prefix(PROCESSED_ZIP, "processed_data")
                COLAB_DATA      = _KWORK
                _inspect_zip(PROCESSED_ZIP, "Kaggle Dataset", preview=5)
                _ext, _mis = _extract_selected(
                    PROCESSED_ZIP, ZIP_ROOT_PREFIX, CRITICAL_DATA_REL, COLAB_DATA)
                print(f"\nCritical data files ready : {len(_ext)}/{len(CRITICAL_DATA_REL)}")
                if _mis: print(f"  Missing: {_mis[:5]}")
                _kaggle_ok = True
                break
            # Case B: Extracted folder (CSV/npy files present)
            for _cand in [_d / "processed_data", _d]:
                if any((_cand / ind).exists() for ind in _DATA_INDICATORS):
                    print(f"  Kaggle extracted folder found: {_cand}")
                    COLAB_DATA = _cand
                    _kaggle_ok = True
                    break
            if _kaggle_ok:
                break

    if not _ON_KAGGLE and not _kaggle_ok:
        print("WARNING: No usable data source found.")
        print("  Colab : upload processed_data.zip to Google Drive root")
        print("  Kaggle: add 'Preprcessed_Dataset_Group-6' as notebook input")
        print("  Local : place processed_data/ folder in repo root")
    elif _ON_KAGGLE and not _kaggle_ok:
        print("WARNING: Kaggle dataset detected but data files not found inside it.")
        print("  Check the tree printed above and report the structure.")
        print("  Continuing — will fail on data load cells until resolved.")

def _bulk_extract_sessions(zip_path, zip_base, target_dir):
    """Extract all session files except *.bin from ZIP."""
    import zipfile
    target_dir.mkdir(parents=True, exist_ok=True)
    n_new = n_skip = 0
    with zipfile.ZipFile(zip_path) as z:
        members = [m for m in z.namelist()
                   if m.startswith(zip_base) and not m.endswith('/')]
        for name in members:
            fname = name.split('/')[-1]
            if fname.endswith('.bin') or fname.endswith('.png'):
                continue
            dst = target_dir / fname
            if dst.exists() and dst.stat().st_size > 0:
                n_skip += 1; continue
            dst.write_bytes(z.read(name))
            n_new += 1
            if n_new % 50 == 0:
                used = sum(p.stat().st_size for p in target_dir.iterdir())/1e9
                print(f"  session files extracted: {n_new} new / {n_skip} cached | {used:.1f} GB used")
    return n_new, n_skip

# Session file extraction: skipped on Kaggle (20 GB disk limit; ~28 GB needed)
_ON_KAGGLE = (
    Path("/kaggle/input").exists() and (
        _os_env.environ.get("KAGGLE_KERNEL_RUN_TYPE") is not None or
        Path("/kaggle/kernel-metadata.json").exists()
    )
)

# ── Extract DAIC-WOZ session files (Colab only — Kaggle disk limit) ──
_ENR_EXISTS  = (COLAB_DATA / "daicwoz" / "daicwoz_X_full_enriched_train.npy").exists()
_SESS_TARGET = COLAB_DATA / "daicwoz" / "extracted_sessions"
_SESS_ZIP_BASE = f"{ZIP_ROOT_PREFIX}daicwoz/extracted_sessions/"

if _ENR_EXISTS:
    print("\nEnriched features already exist — skipping session file extraction.")
elif _ON_KAGGLE:
    print("\nKaggle detected: session file extraction skipped (20 GB disk limit).")
    print("  Cell 2.0 will use original 448-feature matrix.")
elif PROCESSED_ZIP is not None:
    _n_tr = len(list(_SESS_TARGET.glob("*_TRANSCRIPT.csv"))) if _SESS_TARGET.exists() else 0
    if _n_tr >= 100:
        print(f"\nSession files already present ({_n_tr} sessions). Skipping re-extraction.")
    else:
        print("\nExtracting DAIC-WOZ session files from ZIP (~28 GB)...")
        _n_new, _n_sk = _bulk_extract_sessions(PROCESSED_ZIP, _SESS_ZIP_BASE, _SESS_TARGET)
        _used = sum(p.stat().st_size for p in _SESS_TARGET.iterdir())/1e9 if _SESS_TARGET.exists() else 0
        print(f"  Done: {_n_new} extracted, {_n_sk} cached | {_used:.1f} GB on disk")
else:
    _n_tr = len(list(_SESS_TARGET.glob("*_TRANSCRIPT.csv"))) if _SESS_TARGET.exists() else 0
    print(f"\nLocal session files: {_n_tr} transcripts found in {_SESS_TARGET}")

print("\nBootstrap complete.")
# Out:
# Environment pre-detection: kaggle | COLAB_DATA=/kaggle/working/processed_data
# Kaggle environment detected — skipping Drive mount.
# Kaggle input datasets: ['datasets']
# Full /kaggle/input tree:
# input/
#   datasets/
#     pankajmsah/
#       ravdess-audio-group-6-dsai/
#         RAVDESS Emotional speech audio/
#       preprcessed-dataset-group-6/
#         Milestone4_Experiments.ipynb
#         processed_data/
#       modma-audio-group-6-dsai/
#         MODMA_AUDIO Datatset/
#
# No valid processed_data ZIP found.
# No extracted processed_data folder found in Drive either.
# WARNING: Kaggle dataset detected but data files not found inside it.
#   Check the tree printed above and report the structure.
#   Continuing — will fail on data load cells until resolved.
#
# Kaggle detected: session file extraction skipped (20 GB disk limit).
#   Cell 2.0 will use original 448-feature matrix.
#
# Bootstrap complete.

# %%
# -- Cell 0.3: Path configuration + ZIP-aware np.load patch --
from pathlib import Path
import os, zipfile
import numpy as np

ZIP_MODE    = False
ZIP_HEALTHY = True

# ── Environment detection — robust Kaggle check (env var + metadata file) ──
# /kaggle/input alone is not enough: Colab can have it as an empty directory.
import os as _os_det
_is_kaggle = (
    Path("/kaggle/input").exists() and (
        _os_det.environ.get("KAGGLE_KERNEL_RUN_TYPE") is not None or
        Path("/kaggle/kernel-metadata.json").exists()
    )
)
if _is_kaggle:
    ENV        = "kaggle"
    OUTPUT_DIR = Path("/kaggle/working/models_output")
    # Walk /kaggle/input to find actual data dir (slug-independent)
    _DATA_IND = [
        "daicwoz/daicwoz_features.csv",
        "daicwoz/daicwoz_feature_cols.txt",
        "ravdess/ravdess_feature_cols.txt",
        "daicwoz/daicwoz_X_train.npy",
    ]
    _found = None
    # First check /kaggle/working (if bootstrap already extracted)
    if Path("/kaggle/working/processed_data").exists():
        if any((Path("/kaggle/working/processed_data") / i).exists() for i in _DATA_IND):
            _found = Path("/kaggle/working/processed_data")
    # Walk all dataset dirs — print contents for diagnosis
    if _found is None:
        import os as _os2
        # Walk entire /kaggle/input tree — find processed_data at any depth
        for _root, _dirs, _files in _os2.walk("/kaggle/input"):
            _rp = Path(_root)
            if _rp.name == "processed_data" and any((_rp / i).exists() for i in _DATA_IND):
                _found = _rp
                print(f"  -> Data found at: {_rp}")
                break
            # Also accept a dir that directly holds indicator files (no processed_data subdir)
            if any((_rp / i).exists() for i in _DATA_IND):
                _found = _rp
                print(f"  -> Data found at: {_rp}")
                break
            # Limit search depth to 6 levels below /kaggle/input
            _depth = _root.replace("/kaggle/input", "").count("/")
            if _depth >= 6:
                _dirs.clear()
    if _found:
        BASE_DATA = _found
    else:
        BASE_DATA = Path("/kaggle/working/processed_data")
        print(f"  WARNING: No data found in /kaggle/input. Check contents above.")
        print(f"  Using fallback: {BASE_DATA} (will fail on data load cells)")

elif Path("/content").exists():
    ENV        = "colab"
    # Use COLAB_DATA if already set by bootstrap (Cell 0.2b); else default
    BASE_DATA  = globals().get("COLAB_DATA", Path("/content/processed_data"))
    OUTPUT_DIR = Path("/content/models_output")
    if not BASE_DATA.exists() and "PROCESSED_ZIP" in globals() and PROCESSED_ZIP is not None:
        ZIP_MODE = True
else:
    ENV        = "local"
    local_candidates = [
        Path("../processed_data"),
        Path("processed_data"),
        Path("e:/Group-6-DS-and-AI-Lab-Project/processed_data"),
    ]
    BASE_DATA  = next((p for p in local_candidates if p.exists()), local_candidates[2])
    OUTPUT_DIR = Path("e:/Group-6-DS-and-AI-Lab-Project/Notebooks_Models/models_output")

RAV_DIR    = BASE_DATA / "ravdess"
DAIC_DIR   = BASE_DATA / "daicwoz"
MODMA_DIR  = BASE_DATA / "modma_audio"
STRESS_DIR = BASE_DATA / "stress"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print(f"Environment : {ENV}")
print(f"BASE_DATA   : {BASE_DATA}  exists={BASE_DATA.exists()}")
print(f"ZIP_MODE    : {ZIP_MODE}")
print(f"RAV_DIR     : {RAV_DIR}    exists={RAV_DIR.exists()}")
print(f"DAIC_DIR    : {DAIC_DIR}   exists={DAIC_DIR.exists()}")
print(f"MODMA_DIR   : {MODMA_DIR}  exists={MODMA_DIR.exists()}")
print(f"STRESS_DIR  : {STRESS_DIR} exists={STRESS_DIR.exists()}")

# ── ZIP-aware helper ──
ZIP_WARNED = False

def _to_rel_path(path):
    p = Path(path)
    if p.is_absolute():
        try: p = p.relative_to(BASE_DATA)
        except Exception: return str(path).replace("\\", "/")
    return str(p).replace("\\", "/")

def _zip_member_for(path):
    rel    = _to_rel_path(path)
    prefix = ZIP_ROOT_PREFIX if "ZIP_ROOT_PREFIX" in globals() else ""
    return f"{prefix}{rel}"

def _zip_is_usable():
    global ZIP_WARNED
    if not (ZIP_MODE and "PROCESSED_ZIP" in globals() and PROCESSED_ZIP is not None):
        return False
    try:
        with zipfile.ZipFile(PROCESSED_ZIP, "r") as zf: _ = zf.namelist()[:1]
        return True
    except Exception as e:
        if not ZIP_WARNED:
            print(f"ZIP not usable ({e}). Falling back to local only.")
            ZIP_WARNED = True
        globals()["ZIP_MODE"] = False
        return False

def ensure_local_file(path):
    p = Path(path)
    if p.exists(): return p
    if not _zip_is_usable():
        raise FileNotFoundError(f"Not found locally and ZIP mode disabled: {p}")
    member = _zip_member_for(p)
    with zipfile.ZipFile(PROCESSED_ZIP, "r") as zf:
        if member not in set(zf.namelist()):
            raise FileNotFoundError(f"Missing in ZIP: {member}")
        p.parent.mkdir(parents=True, exist_ok=True)
        with zf.open(member) as src_f, open(p, "wb") as dst_f:
            dst_f.write(src_f.read())
    return p

def open_smart(path, mode="r", *args, **kwargs):
    if any(c in mode for c in ["w", "a", "+"]):
        return open(path, mode, *args, **kwargs)
    return open(ensure_local_file(path), mode, *args, **kwargs)

# ── Patch np.load to be ZIP-aware (guard against re-patching on kernel rerun) ──
if not getattr(np.load, "_is_smart_patched", False):
    _np_load_orig = np.load
    def _np_load_smart(file, *args, **kwargs):
        try:
            return _np_load_orig(file, *args, **kwargs)
        except FileNotFoundError:
            return _np_load_orig(ensure_local_file(file), *args, **kwargs)
    _np_load_smart._is_smart_patched = True
    np.load = _np_load_smart
else:
    print("np.load already patched — skipping re-patch.")

def load_feature_cols(path):
    with open_smart(path, "r", encoding="utf-8") as f:
        return [l.strip() for l in f if l.strip()]

print("np.load patched for ZIP-aware loading. All paths configured.")
# Out:
#   -> Data found at: /kaggle/input/datasets/pankajmsah/preprcessed-dataset-group-6/processed_data/processed_data
# Environment : kaggle
# BASE_DATA   : /kaggle/input/datasets/pankajmsah/preprcessed-dataset-group-6/processed_data/processed_data  exists=True
# ZIP_MODE    : False
# RAV_DIR     : /kaggle/input/datasets/pankajmsah/preprcessed-dataset-group-6/processed_data/processed_data/ravdess    exists=True
# DAIC_DIR    : /kaggle/input/datasets/pankajmsah/preprcessed-dataset-group-6/processed_data/processed_data/daicwoz   exists=True
# MODMA_DIR   : /kaggle/input/datasets/pankajmsah/preprcessed-dataset-group-6/processed_data/processed_data/modma_audio  exists=True
# STRESS_DIR  : /kaggle/input/datasets/pankajmsah/preprcessed-dataset-group-6/processed_data/processed_data/stress exists=True
# np.load patched for ZIP-aware loading. All paths configured.

# %%
# ── Cell 0.4: Shared utility functions ──

def clf_report(y_true, y_pred, y_prob=None, name=""):
    """Print accuracy, macro-F1, per-class F1, optional AUC/AUPRC."""
    acc = accuracy_score(y_true, y_pred)
    f1  = f1_score(y_true, y_pred, average="macro", zero_division=0)
    print(f"\n{'='*55}")
    print(f"  {name}")
    print(f"{'='*55}")
    print(f"  Accuracy   : {acc:.4f}")
    print(f"  Macro-F1   : {f1:.4f}")
    if y_prob is not None:
        n_cls = len(np.unique(y_true))
        if n_cls == 2:
            prob_pos = y_prob[:, 1] if (hasattr(y_prob, "ndim") and y_prob.ndim == 2) else y_prob
            try:
                auc_roc = roc_auc_score(y_true, prob_pos)
                auprc   = average_precision_score(y_true, prob_pos)
                print(f"  ROC-AUC    : {auc_roc:.4f}")
                print(f"  AUPRC      : {auprc:.4f}")
            except Exception:
                pass
    print(f"\n{classification_report(y_true, y_pred, zero_division=0)}")
    return {"accuracy": float(acc), "macro_f1": float(f1)}


def plot_training_curves(train_losses, val_losses, train_accs, val_accs,
                         title="Training Curves", save_path=None):
    """Plot loss and accuracy curves side by side."""
    fig, axes = plt.subplots(1, 2, figsize=(14, 4))
    epochs = range(1, len(train_losses) + 1)
    axes[0].plot(epochs, train_losses, label="Train Loss")
    axes[0].plot(epochs, val_losses,   label="Val Loss")
    axes[0].set_title(f"{title} — Loss")
    axes[0].set_xlabel("Epoch"); axes[0].set_ylabel("Loss")
    axes[0].legend()
    axes[1].plot(epochs, train_accs, label="Train Acc")
    axes[1].plot(epochs, val_accs,   label="Val Acc")
    axes[1].set_title(f"{title} — Accuracy")
    axes[1].set_xlabel("Epoch"); axes[1].set_ylabel("Accuracy")
    axes[1].legend()
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, bbox_inches="tight")
    plt.show()


def save_results(key, metrics_dict):
    """Save metrics to the global RESULTS dict."""
    RESULTS[key] = metrics_dict
    print(f"  [saved] {key}: {metrics_dict}")


def make_heatmap(data, row_labels, col_labels, row_name, col_name,
                 title="", fmt=".3f", cmap="YlOrRd", save_path=None):
    """Seaborn annotated heatmap for grid search results."""
    df = pd.DataFrame(data, index=row_labels, columns=col_labels)
    df.index.name   = row_name
    df.columns.name = col_name
    fig, ax = plt.subplots(figsize=(max(6, len(col_labels)*2), max(4, len(row_labels)*1.5)))
    sns.heatmap(df, annot=True, fmt=fmt, cmap=cmap, ax=ax,
                linewidths=0.5, linecolor="gray")
    ax.set_title(title, fontsize=13, fontweight="bold")
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, bbox_inches="tight")
    plt.show()
    return df


def torch_train_epoch(model, loader, criterion, optimizer, device):
    """One training epoch; returns avg loss and accuracy."""
    model.train()
    total_loss, correct, total = 0.0, 0, 0
    for Xb, yb in loader:
        Xb, yb = Xb.to(device), yb.to(device)
        optimizer.zero_grad()
        out  = model(Xb)
        loss = criterion(out, yb)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * len(yb)
        correct    += (out.argmax(1) == yb).sum().item()
        total      += len(yb)
    return total_loss / total, correct / total


def torch_eval_epoch(model, loader, criterion, device):
    """Validation epoch; returns avg loss, accuracy, macro-F1."""
    model.eval()
    total_loss, preds, labels = 0.0, [], []
    with torch.no_grad():
        for Xb, yb in loader:
            Xb, yb = Xb.to(device), yb.to(device)
            out  = model(Xb)
            loss = criterion(out, yb)
            total_loss += loss.item() * len(yb)
            preds.extend(out.argmax(1).cpu().numpy())
            labels.extend(yb.cpu().numpy())
    n   = len(labels)
    acc = accuracy_score(labels, preds)
    f1  = f1_score(labels, preds, average="macro", zero_division=0)
    return total_loss / n, acc, f1


def make_loaders(X_tr, y_tr, X_vl, y_vl, batch=64):
    """Convert numpy arrays to DataLoaders."""
    tr_ds = TensorDataset(torch.tensor(X_tr, dtype=torch.float32),
                          torch.tensor(y_tr, dtype=torch.long))
    vl_ds = TensorDataset(torch.tensor(X_vl, dtype=torch.float32),
                          torch.tensor(y_vl, dtype=torch.long))
    _pin = torch.cuda.is_available()
    return (DataLoader(tr_ds, batch_size=batch, shuffle=True,  num_workers=0, pin_memory=_pin),
            DataLoader(vl_ds, batch_size=batch, shuffle=False, num_workers=0, pin_memory=_pin))


print("Utility functions defined.")

import pickle

# PHQ-8 severity band definitions (DSM-5 aligned)
PHQ8_BINS   = [0, 5, 10, 15, 20, 25]
PHQ8_LABELS = ["Minimal", "Mild", "Moderate", "Mod-Severe", "Severe"]

def severity_band(score):
    for i, (lo, hi) in enumerate(zip(PHQ8_BINS[:-1], PHQ8_BINS[1:])):
        if lo <= score < hi:
            return i
    return len(PHQ8_LABELS) - 1

def band_accuracy(y_true, y_pred):
    """% predictions in exact same PHQ-8 severity band (M3-compatible metric)."""
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    valid = ~(np.isnan(y_true) | np.isnan(y_pred))
    if valid.sum() == 0: return float('nan')
    y_true, y_pred = y_true[valid], y_pred[valid]
    correct = sum(severity_band(yt) == severity_band(yp) for yt, yp in zip(y_true, y_pred))
    return correct / len(y_true)

def within_one_band_acc(y_true, y_pred):
    """% predictions within +-1 PHQ-8 severity band (M3 primary regression metric)."""
    y_true = np.asarray(y_true, dtype=float)
    y_pred = np.asarray(y_pred, dtype=float)
    valid = ~(np.isnan(y_true) | np.isnan(y_pred))
    if valid.sum() == 0: return float('nan')
    y_true, y_pred = y_true[valid], y_pred[valid]
    correct = sum(abs(severity_band(yt) - severity_band(yp)) <= 1 for yt, yp in zip(y_true, y_pred))
    return correct / len(y_true)

def load_scaler(path):
    """Load a saved sklearn scaler from .pkl file."""
    with open(path, 'rb') as f:
        return pickle.load(f)

def apply_scaler(scaler, X_train, X_val, X_test=None):
    """Transform arrays using a pre-fitted scaler. Clips extreme outliers (>10 std) after scaling."""
    Xtr = np.clip(scaler.transform(X_train), -10, 10)
    Xvl = np.clip(scaler.transform(X_val), -10, 10)
    if X_test is not None:
        Xte = np.clip(scaler.transform(X_test), -10, 10)
        return Xtr, Xvl, Xte
    return Xtr, Xvl

def reg_report(y_true, y_pred, name="", is_phq8=False):
    """Print RMSE, MAE, and optionally PHQ-8 severity band accuracy."""
    from sklearn.metrics import mean_squared_error, mean_absolute_error
    rmse  = float(np.sqrt(mean_squared_error(y_true, y_pred)))
    mae   = float(mean_absolute_error(y_true, y_pred))
    print(f"\n{'='*55}")
    print(f"  {name}")
    print(f"{'='*55}")
    print(f"  RMSE             : {rmse:.4f}")
    print(f"  MAE              : {mae:.4f}")
    if is_phq8:
        ba   = band_accuracy(y_true, y_pred)
        w1b  = within_one_band_acc(y_true, y_pred)
        print(f"  Band Accuracy    : {ba:.4f}  (exact severity band match)")
        print(f"  Within-1-Band %  : {w1b*100:.2f}%  (M3-compatible metric, target>80%)")
    else:
        within1 = float(np.mean(np.abs(np.array(y_true) - np.array(y_pred)) <= 1) * 100)
        within2 = float(np.mean(np.abs(np.array(y_true) - np.array(y_pred)) <= 2) * 100)
        print(f"  Within-1-unit %  : {within1:.2f}%")
        print(f"  Within-2-unit %  : {within2:.2f}%")
    return {"rmse": rmse, "mae": mae}
# Out:
# Utility functions defined.

# %%
# ── Cell 0.5: Global results accumulator ──
RESULTS = {}
print("RESULTS dict initialised. All experiments will call save_results(key, metrics).")
# Out:
# RESULTS dict initialised. All experiments will call save_results(key, metrics).

# %% [markdown]
# ---
# # Section 1 — RAVDESS: Emotion Recognition Experiments
#
# RAVDESS is used as the primary **emotion recognition benchmark** (8 classes: neutral, calm, happy, sad, angry, fearful, disgust, surprised).
#
# | Split | Samples | Features | Notes |
# |---|---|---|---|
# | Train | 840 | 338 | Actors 1–18 |
# | Validation | 300 | 338 | Actors 19–22 |
# | Test | 300 | 338 | Actors 23–24 (held out) |
# | **Combined train+val** | **1140** | **338** | **Used for final model** |
#
# - Classes nearly balanced (112/class, except neutral=56 → upweighted ×2 in loss)
# - Milestone 3 XGBoost baseline: **Val Macro-F1 ≈ 0.38** (no hyperparameter tuning)
#
# ## Model Architectures in Section 1
#
# **EmotionMLP (PyTorch):**
#
# | Layer | Config |
# |---|---|
# | Input | 338 features |
# | Hidden 1 | Linear(338→256) + BatchNorm1d + ReLU + Dropout(0.3) |
# | Hidden 2 | Linear(256→128) + BatchNorm1d + ReLU + Dropout(0.3) |
# | Hidden 3 | Linear(128→64) + BatchNorm1d + ReLU + Dropout(0.3) |
# | Output | Linear(64→8) — 8 emotion classes |
# | Loss | CrossEntropyLoss (neutral class weight=2.0, label_smoothing=0.1) |
# | Trainable params | ~87K |
#
# **XGBoost:** GPU-accelerated ensemble (device='cuda', tree_method='hist')
#
# **Experiments:**
# - 1.2 Model comparison (SVM / RF / XGBoost / GBM)
# - 1.3 XGBoost grid: learning rate × max depth
# - 1.4 XGBoost regularisation: L1 (reg_alpha) × L2 (reg_lambda)
# - 1.5 PyTorch MLP: optimiser comparison (SGD / Adam / AdamW / RMSprop)
# - 1.6 MLP regularisation ablation: dropout × weight decay (4×4 grid, 25 epochs each)
# - 1.7 LR scheduler experiment (CosineAnnealingLR / ReduceLROnPlateau / baseline)
# - 1.7b Final MLP on full train+val (1140 samples) — test evaluation
# - 1.9 Artifacts, sample predictions & confusion matrix

# %%
# ── Cell 1.1: Load RAVDESS data + Apply Scaler + Load Metadata CSVs ──
X_rav_train = np.load(RAV_DIR / "ravdess_X_train.npy")
X_rav_val   = np.load(RAV_DIR / "ravdess_X_val.npy")
X_rav_test  = np.load(RAV_DIR / "ravdess_X_test.npy")
y_rav_train = np.load(RAV_DIR / "ravdess_y_train.npy")
y_rav_val   = np.load(RAV_DIR / "ravdess_y_val.npy")
y_rav_test  = np.load(RAV_DIR / "ravdess_y_test.npy")

with open(RAV_DIR / "ravdess_emotion_label_map.json") as f:
    emotion_map = json.load(f)
EMOTION_NAMES = [k for k, v in sorted(emotion_map.items(), key=lambda x: x[1])]

# ── Apply RobustScaler (critical for SVM and MLP) ──
rav_scaler = load_scaler(RAV_DIR / "ravdess_scaler.pkl")
X_rav_train_sc, X_rav_val_sc, X_rav_test_sc = apply_scaler(
    rav_scaler, X_rav_train, X_rav_val, X_rav_test)
print("RAVDESS scaler applied. X_train_sc range: [{:.2f}, {:.2f}]".format(
    X_rav_train_sc.min(), X_rav_train_sc.max()))

# ── Load metadata CSVs ──
rav_meta_df        = pd.read_csv(RAV_DIR / "ravdess_metadata.csv")
rav_actor_splits   = pd.read_csv(RAV_DIR / "ravdess_actor_splits.csv")
rav_features_df    = pd.read_csv(RAV_DIR / "ravdess_features.csv")
print(f"\nMetadata loaded: {len(rav_meta_df)} rows, cols: {list(rav_meta_df.columns[:6])}")
print(f"Actor splits: {rav_actor_splits.shape}")
print(f"Features CSV: {rav_features_df.shape}")

# ── Summary ──
print(f"\nRAVDESS loaded (scaled):")
print(f"  X_train_sc: {X_rav_train_sc.shape}  X_val_sc: {X_rav_val_sc.shape}")
print(f"  Emotion classes: {EMOTION_NAMES}")
print(f"  Class distribution (train):")
for i, name in enumerate(EMOTION_NAMES):
    print(f"    Class {i} ({name:10s}): {(y_rav_train==i).sum()}")


# ── Combined train+val for final model training (1140 samples vs 840 train-only) ──
X_rav_trainval    = np.vstack([X_rav_train, X_rav_val])
y_rav_trainval    = np.concatenate([y_rav_train, y_rav_val])
X_rav_trainval_sc = np.vstack([X_rav_train_sc, X_rav_val_sc])
print(f"\nCombined train+val: {X_rav_trainval.shape} (use for final model, eval on test)")
# Out:
# RAVDESS scaler applied. X_train_sc range: [-10.00, 10.00]
#
# Metadata loaded: 1440 rows, cols: ['filepath', 'filename', 'modality_code', 'vocal_channel', 'emotion_code', 'emotion']
# Actor splits: (24, 2)
# Features CSV: (1440, 348)
#
# RAVDESS loaded (scaled):
#   X_train_sc: (840, 338)  X_val_sc: (300, 338)
#   Emotion classes: ['angry', 'calm', 'disgust', 'fearful', 'happy', 'neutral', 'sad', 'surprised']
#   Class distribution (train):
#     Class 0 (angry     ): 112
#     Class 1 (calm      ): 112
#     Class 2 (disgust   ): 112
#     Class 3 (fearful   ): 112
#     Class 4 (happy     ): 112
#     Class 5 (neutral   ): 56
#     Class 6 (sad       ): 112
#     Class 7 (surprised ): 112
#
# Combined train+val: (1140, 338) (use for final model, eval on test)

# %%
# ── Cell 1.2: Model Comparison — SVM vs RF vs XGBoost vs GBM ──
# NOTE: SVM uses scaled data (X_rav_train_sc) — critical for kernel performance
# Tree models (RF, XGB, GBM) use original X (scale-invariant)
# GPU flag for XGBoost (XGB 2.x+ syntax)
_XGB_DEV = 'cuda' if (TORCH_AVAILABLE and torch.cuda.is_available()) else 'cpu'
_XGB_TM  = 'hist'  # works on both CPU and GPU in XGB 2.x
import time

comparison_results = []

# SVM with scaled data — C sweep to find optimal value on scaled features
print('SVM RBF C sweep on scaled data...')
_svm_C_vals = [0.1, 1.0, 5.0, 10.0, 50.0, 100.0]
_best_svm_f1, _best_svm_acc, _best_C, _best_svm = 0.0, 0.0, 1.0, None
for _C in _svm_C_vals:
    t0 = time.time()
    _m = SVC(C=_C, kernel='rbf', probability=True, random_state=42)
    _m.fit(X_rav_train_sc, y_rav_train)
    _p = _m.predict(X_rav_val_sc)
    _f1  = f1_score(y_rav_val, _p, average='macro', zero_division=0)
    _acc = accuracy_score(y_rav_val, _p)
    print(f'  C={_C:6.1f}: acc={_acc:.4f}  f1={_f1:.4f}  ({time.time()-t0:.1f}s)')
    if _f1 > _best_svm_f1:
        _best_svm_f1, _best_svm_acc, _best_C, _best_svm = _f1, _acc, _C, _m
svm_rav  = _best_svm
svm_pred = svm_rav.predict(X_rav_val_sc)
svm_f1, svm_acc = _best_svm_f1, _best_svm_acc
print(f'Best SVM: C={_best_C}  acc={svm_acc:.4f}  f1={svm_f1:.4f}')
comparison_results.append((f'SVM RBF (C={_best_C}, tuned)', svm_acc, svm_f1, 0.0))
save_results('rav_svm_scaled', {'accuracy': svm_acc, 'macro_f1': svm_f1,
             'notes': f'SVM RBF C={_best_C} scaled (tuned)'})

# RF
print("Training RandomForest (n=200)...")
t0 = time.time()
rf_rav = RandomForestClassifier(n_estimators=200, random_state=42, n_jobs=-1)
rf_rav.fit(X_rav_train, y_rav_train)
rf_pred = rf_rav.predict(X_rav_val)
rf_f1  = f1_score(y_rav_val, rf_pred, average='macro', zero_division=0)
rf_acc = accuracy_score(y_rav_val, rf_pred)
comparison_results.append(('RandomForest (n=200)', rf_acc, rf_f1, round(time.time()-t0,1)))
print(f"  RF: acc={rf_acc:.4f}  f1={rf_f1:.4f}  time={time.time()-t0:.1f}s")
save_results('rav_rf_baseline', {'accuracy': rf_acc, 'macro_f1': rf_f1, 'notes': 'RF n=200'})

# XGBoost
print("Training XGBoost (max_depth=4, lr=0.05, n=300)...")
t0 = time.time()
xgb_rav = xgb.XGBClassifier(
    objective='multi:softprob', num_class=len(EMOTION_NAMES),
    max_depth=4, learning_rate=0.05, n_estimators=300,
    subsample=0.8, colsample_bytree=0.8,
    early_stopping_rounds=30, eval_metric='mlogloss',
    random_state=42, verbosity=0,
    device=_XGB_DEV, tree_method=_XGB_TM)
xgb_rav.fit(X_rav_train, y_rav_train, eval_set=[(X_rav_val, y_rav_val)], verbose=False)
xgb_pred = xgb_rav.predict(X_rav_val)
xgb_f1  = f1_score(y_rav_val, xgb_pred, average='macro', zero_division=0)
xgb_acc = accuracy_score(y_rav_val, xgb_pred)
comparison_results.append(('XGBoost (depth=4,lr=0.05)', xgb_acc, xgb_f1, round(time.time()-t0,1)))
print(f"  XGB: acc={xgb_acc:.4f}  f1={xgb_f1:.4f}  time={time.time()-t0:.1f}s")
save_results('rav_xgb_baseline', {'accuracy': xgb_acc, 'macro_f1': xgb_f1, 'notes': 'XGB depth=4 lr=0.05'})

# GBM
print("Training GradientBoosting (n=200, depth=3)...")
t0 = time.time()
gbm_rav = GradientBoostingClassifier(n_estimators=200, max_depth=3, random_state=42)
gbm_rav.fit(X_rav_train, y_rav_train)
gbm_pred = gbm_rav.predict(X_rav_val)
gbm_f1  = f1_score(y_rav_val, gbm_pred, average='macro', zero_division=0)
gbm_acc = accuracy_score(y_rav_val, gbm_pred)
comparison_results.append(('GradientBoosting (n=200,d=3)', gbm_acc, gbm_f1, round(time.time()-t0,1)))
print(f"  GBM: acc={gbm_acc:.4f}  f1={gbm_f1:.4f}  time={time.time()-t0:.1f}s")
save_results('rav_gbm_baseline', {'accuracy': gbm_acc, 'macro_f1': gbm_f1, 'notes': 'GBM n=200 depth=3'})

print("\n" + "="*65)
print("  Model Comparison — RAVDESS Validation Set (SVM uses scaled data)")
print("="*65)
cmp_df = pd.DataFrame(comparison_results, columns=['Model','Val Accuracy','Macro-F1','Train Time(s)'])
print(cmp_df.to_string(index=False))

# ── Final XGB trained on train+val combined (maximise data, eval on test) ──
print("\nFinal XGB (train+val combined, eval on test)...")
_xgb_final = xgb.XGBClassifier(
    objective='multi:softprob', num_class=len(EMOTION_NAMES),
    max_depth=3, learning_rate=0.1, n_estimators=300,
    subsample=0.8, colsample_bytree=0.8,
    random_state=42, verbosity=0,
    device=_XGB_DEV, tree_method=_XGB_TM
)
_xgb_final.fit(X_rav_trainval, y_rav_trainval)
_xgb_final_pred = _xgb_final.predict(X_rav_test)
_xgb_final_f1  = f1_score(y_rav_test, _xgb_final_pred, average='macro', zero_division=0)
_xgb_final_acc = accuracy_score(y_rav_test, _xgb_final_pred)
print(f"  Test acc={_xgb_final_acc:.4f}  f1={_xgb_final_f1:.4f}")
save_results('rav_xgb_trainval_test', {'accuracy': _xgb_final_acc, 'macro_f1': _xgb_final_f1,
             'notes': 'XGB trained on train+val (1140 samples), eval on test'})
# Out:
# SVM RBF C sweep on scaled data...
#   C=   0.1: acc=0.2100  f1=0.1738  (1.0s)
#   C=   1.0: acc=0.2300  f1=0.1906  (0.8s)
#   C=   5.0: acc=0.2267  f1=0.2093  (0.8s)
#   C=  10.0: acc=0.2500  f1=0.2349  (0.8s)
#   C=  50.0: acc=0.2800  f1=0.2674  (0.9s)
#   C= 100.0: acc=0.2867  f1=0.2803  (0.9s)
# Best SVM: C=100.0  acc=0.2867  f1=0.2803
#   [saved] rav_svm_scaled: {'accuracy': 0.2866666666666667, 'macro_f1': 0.2802682450564462, 'notes': 'SVM RBF C=100.0 scaled (tuned)'}
# Training RandomForest (n=200)...
#   RF: acc=0.4100  f1=0.3712  time=1.2s
#   [saved] rav_rf_baseline: {'accuracy': 0.41, 'macro_f1': 0.3711983558056402, 'notes': 'RF n=200'}
# Training XGBoost (max_depth=4, lr=0.05, n=300)...
#   XGB: acc=0.4000  f1=0.3816  time=2.4s
#   [saved] rav_xgb_baseline: {'accuracy': 0.4, 'macro_f1': 0.3815638717826008, 'notes': 'XGB depth=4 lr=0.05'}
# Training GradientBoosting (n=200, depth=3)...
#   GBM: acc=0.4267  f1=0.4233  time=199.1s
# ...

# %%
# ── Cell 1.3: XGBoost Hyperparameter Sweep — Learning Rate × Max Depth ──
# Grid search over max_depth and learning_rate on RAVDESS.
# Each model trained on train set, evaluated on val set.
# Results visualised as a seaborn heatmap.

max_depths     = [2, 3, 4, 5]
learning_rates = [0.01, 0.05, 0.1]

grid_f1  = np.zeros((len(max_depths), len(learning_rates)))
grid_acc = np.zeros((len(max_depths), len(learning_rates)))

print("Running XGBoost grid (max_depth × learning_rate)...")
for i, depth in enumerate(max_depths):
    for j, lr in enumerate(learning_rates):
        m = xgb.XGBClassifier(
            objective="multi:softprob", num_class=8,
            max_depth=depth, learning_rate=lr, n_estimators=300,
            subsample=0.8, colsample_bytree=0.8,
            early_stopping_rounds=30, eval_metric="mlogloss",
            random_state=42, verbosity=0,
            device=_XGB_DEV, tree_method=_XGB_TM
        )
        m.fit(X_rav_train, y_rav_train,
              eval_set=[(X_rav_val, y_rav_val)], verbose=False)
        pred = m.predict(X_rav_val)
        grid_f1[i, j]  = f1_score(y_rav_val, pred, average="macro", zero_division=0)
        grid_acc[i, j] = accuracy_score(y_rav_val, pred)
        print(f"  depth={depth} lr={lr:.2f} -> F1={grid_f1[i,j]:.4f} acc={grid_acc[i,j]:.4f}")

# Find best config
best_idx = np.unravel_index(np.argmax(grid_f1), grid_f1.shape)
BEST_DEPTH_RAV = max_depths[best_idx[0]]
BEST_LR_RAV    = learning_rates[best_idx[1]]
print(f"\nBest config: max_depth={BEST_DEPTH_RAV}, lr={BEST_LR_RAV}")
print(f"Best val Macro-F1: {grid_f1[best_idx]:.4f}")

# Heatmap
lr_labels    = [str(lr) for lr in learning_rates]
depth_labels = [f"depth={d}" for d in max_depths]
hm_df = make_heatmap(
    grid_f1, depth_labels, lr_labels,
    "max_depth", "learning_rate",
    title="RAVDESS XGBoost Grid — Val Macro-F1",
    cmap="YlOrRd", fmt=".3f",
    save_path=OUTPUT_DIR / "rav_xgb_grid_heatmap.png"
)

save_results("rav_xgb_grid_best", {
    "accuracy": float(grid_acc[best_idx]),
    "macro_f1": float(grid_f1[best_idx]),
    "max_depth": BEST_DEPTH_RAV,
    "learning_rate": BEST_LR_RAV,
    "notes": "XGB grid best"
})
plt.savefig(OUTPUT_DIR / "rav_xgb_grid_heatmap.png", bbox_inches="tight")
# Out:
# Running XGBoost grid (max_depth × learning_rate)...
#   depth=2 lr=0.01 -> F1=0.3544 acc=0.3900
#   depth=2 lr=0.05 -> F1=0.4320 acc=0.4633
#   depth=2 lr=0.10 -> F1=0.4540 acc=0.4700
#   depth=3 lr=0.01 -> F1=0.3872 acc=0.4067
#   depth=3 lr=0.05 -> F1=0.3890 acc=0.4233
#   depth=3 lr=0.10 -> F1=0.4145 acc=0.4300
#   depth=4 lr=0.01 -> F1=0.3772 acc=0.4000
#   depth=4 lr=0.05 -> F1=0.3816 acc=0.4000
#   depth=4 lr=0.10 -> F1=0.3739 acc=0.4067
#   depth=5 lr=0.01 -> F1=0.3800 acc=0.4167
#   depth=5 lr=0.05 -> F1=0.4191 acc=0.4367
#   depth=5 lr=0.10 -> F1=0.3975 acc=0.4133
#
# Best config: max_depth=2, lr=0.1
# Best val Macro-F1: 0.4540
#   [saved] rav_xgb_grid_best: {'accuracy': 0.47, 'macro_f1': 0.45395343348647943, 'max_depth': 2, 'learning_rate': 0.1, 'notes': 'XGB grid best'}

# %%
# ── Cell 1.4: XGBoost Regularisation Experiment — L1 (reg_alpha) × L2 (reg_lambda) ──
# Fix best depth/lr from 1.3. Sweep L1 and L2 regularisation.
# Goal: find sweet spot that reduces overfitting without hurting generalisation.

reg_alphas  = [0, 0.1, 0.5, 1.0]   # L1
reg_lambdas = [1.0, 1.5, 2.0]       # L2

reg_f1  = np.zeros((len(reg_alphas), len(reg_lambdas)))
reg_acc = np.zeros((len(reg_alphas), len(reg_lambdas)))
reg_rows = []

print(f"XGBoost reg sweep (base: depth={BEST_DEPTH_RAV}, lr={BEST_LR_RAV})...")
for i, alpha in enumerate(reg_alphas):
    for j, lam in enumerate(reg_lambdas):
        m = xgb.XGBClassifier(
            objective="multi:softprob", num_class=8,
            max_depth=BEST_DEPTH_RAV, learning_rate=BEST_LR_RAV,
            n_estimators=300,
            reg_alpha=alpha, reg_lambda=lam,
            subsample=0.8, colsample_bytree=0.8,
            early_stopping_rounds=30, eval_metric="mlogloss",
            random_state=42, verbosity=0,
            device=_XGB_DEV, tree_method=_XGB_TM
        )
        m.fit(X_rav_train, y_rav_train,
              eval_set=[(X_rav_val, y_rav_val)], verbose=False)
        pred = m.predict(X_rav_val)
        f1v  = f1_score(y_rav_val, pred, average="macro", zero_division=0)
        accv = accuracy_score(y_rav_val, pred)
        reg_f1[i, j]  = f1v
        reg_acc[i, j] = accv
        reg_rows.append({"reg_alpha": alpha, "reg_lambda": lam,
                         "Val Accuracy": round(accv, 4), "Macro-F1": round(f1v, 4)})
        print(f"  alpha={alpha}  lambda={lam}  -> F1={f1v:.4f} acc={accv:.4f}")

reg_df = pd.DataFrame(reg_rows)
print("\nRegularisation results:")
print(reg_df.to_string(index=False))

alpha_labels  = [f"L1={a}" for a in reg_alphas]
lambda_labels = [f"L2={l}" for l in reg_lambdas]
make_heatmap(
    reg_f1, alpha_labels, lambda_labels,
    "reg_alpha (L1)", "reg_lambda (L2)",
    title="RAVDESS XGBoost Regularisation — Val Macro-F1",
    cmap="YlOrRd", fmt=".3f",
    save_path=OUTPUT_DIR / "rav_xgb_reg_heatmap.png"
)

best_reg_idx = np.unravel_index(np.argmax(reg_f1), reg_f1.shape)
BEST_ALPHA_RAV  = reg_alphas[best_reg_idx[0]]
BEST_LAMBDA_RAV = reg_lambdas[best_reg_idx[1]]
print(f"\nBest regularisation: alpha={BEST_ALPHA_RAV}, lambda={BEST_LAMBDA_RAV}")
print(f"Best val Macro-F1: {reg_f1[best_reg_idx]:.4f}")

# Effect discussion
print("\nEffect analysis:")
print(f"  No reg (alpha=0, lambda=1.0) F1: {reg_f1[0,0]:.4f}")
print(f"  Strong L1 (alpha=1.0) avg  F1: {reg_f1[3,:].mean():.4f}")
print(f"  Increasing lambda reduces variance (L2 penalty shrinks leaf weights).")
print(f"  L1 promotes sparsity — drops irrelevant features.")

save_results("rav_xgb_reg_best", {
    "accuracy": float(reg_acc[best_reg_idx]),
    "macro_f1": float(reg_f1[best_reg_idx]),
    "reg_alpha": BEST_ALPHA_RAV, "reg_lambda": BEST_LAMBDA_RAV,
    "notes": "XGB best regularisation config"
})
plt.savefig(OUTPUT_DIR / "rav_xgb_reg_heatmap.png", bbox_inches="tight")
# Out:
# XGBoost reg sweep (base: depth=2, lr=0.1)...
#   alpha=0  lambda=1.0  -> F1=0.4540 acc=0.4700
#   alpha=0  lambda=1.5  -> F1=0.4537 acc=0.4733
#   alpha=0  lambda=2.0  -> F1=0.4665 acc=0.4867
#   alpha=0.1  lambda=1.0  -> F1=0.4495 acc=0.4633
#   alpha=0.1  lambda=1.5  -> F1=0.4193 acc=0.4400
#   alpha=0.1  lambda=2.0  -> F1=0.4627 acc=0.4833
#   alpha=0.5  lambda=1.0  -> F1=0.4724 acc=0.4867
#   alpha=0.5  lambda=1.5  -> F1=0.4574 acc=0.4733
#   alpha=0.5  lambda=2.0  -> F1=0.4597 acc=0.4867
#   alpha=1.0  lambda=1.0  -> F1=0.4629 acc=0.4833
#   alpha=1.0  lambda=1.5  -> F1=0.4380 acc=0.4567
#   alpha=1.0  lambda=2.0  -> F1=0.4474 acc=0.4667
#
# Regularisation results:
#  reg_alpha  reg_lambda  Val Accuracy  Macro-F1
#        0.0         1.0        0.4700    0.4540
#        0.0         1.5        0.4733    0.4537
#        0.0         2.0        0.4867    0.4665
#        0.1         1.0        0.4633    0.4495
#        0.1         1.5        0.4400    0.4193
# ...

# %%
# ── Cell 1.5: PyTorch MLP — Architecture & Optimiser Comparison ──
# Compare SGD / Adam / AdamW / RMSprop on a fixed 3-layer MLP.
# Architecture: 338 → 256 → 128 → 64 → 8, BatchNorm + ReLU + Dropout(0.3)

if not TORCH_AVAILABLE:
    print("WARNING: PyTorch not available — skipping MLP cells.")
else:
    # ── Define EmotionMLP ──
    class EmotionMLP(nn.Module):
        def __init__(self, in_dim, hidden_dims, n_classes, dropout=0.3):
            super().__init__()
            layers = []
            prev = in_dim
            for h in hidden_dims:
                layers += [
                    nn.Linear(prev, h),
                    nn.BatchNorm1d(h),
                    nn.ReLU(),
                    nn.Dropout(dropout)
                ]
                prev = h
            layers.append(nn.Linear(prev, n_classes))
            self.net = nn.Sequential(*layers)

        def forward(self, x):
            return self.net(x)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    DEVICE = device  # alias for cells that use DEVICE

    # Assign hyperparameters BEFORE using them in print
    HIDDEN = [256, 128, 64]
    N_CLASSES = 8
    EPOCHS_OPT = 60
    BATCH = 128

    print(f"Using device: {device} (RAVDESS MLP: {EPOCHS_OPT} epochs)")

    tr_loader, vl_loader = make_loaders(X_rav_train_sc, y_rav_train,
                                         X_rav_val_sc,   y_rav_val, batch=BATCH)

    optimiser_configs = [
        ("SGD",     lambda p: optim.SGD(p, lr=0.01, momentum=0.9)),
        ("Adam",    lambda p: optim.Adam(p, lr=1e-3)),
        ("AdamW",   lambda p: optim.AdamW(p, lr=1e-3, weight_decay=1e-4)),
        ("RMSprop", lambda p: optim.RMSprop(p, lr=1e-3)),
    ]

    opt_histories = {}
    opt_final     = []

    for opt_name, opt_fn in optimiser_configs:
        print(f"\nTraining with {opt_name}...")
        torch.manual_seed(42)
        model = EmotionMLP(X_rav_train.shape[1], HIDDEN, N_CLASSES, dropout=0.3).to(device)
        # class_weight: neutral has 56 samples vs 112 for others — upweight it
        _cls_w = torch.ones(8).to(device); _cls_w[5] = 2.0
        criterion = nn.CrossEntropyLoss(weight=_cls_w, label_smoothing=0.1)
        optimizer = opt_fn(model.parameters())

        tr_losses, vl_losses, tr_accs, vl_accs = [], [], [], []
        for epoch in range(1, EPOCHS_OPT + 1):
            tl, ta = torch_train_epoch(model, tr_loader, criterion, optimizer, device)
            vl, va, vf1 = torch_eval_epoch(model, vl_loader, criterion, device)
            tr_losses.append(tl); vl_losses.append(vl)
            tr_accs.append(ta);   vl_accs.append(va)
            if epoch % 10 == 0:
                print(f"  Epoch {epoch:3d}: tr_loss={tl:.4f} vl_loss={vl:.4f} val_acc={va:.4f} val_f1={vf1:.4f}")

        opt_histories[opt_name] = (tr_losses, vl_losses, tr_accs, vl_accs)
        opt_final.append({"Optimiser": opt_name,
                          "Val Accuracy": round(va, 4),
                          "Val Macro-F1": round(vf1, 4)})
        save_results(f"rav_mlp_{opt_name.lower()}", {
            "accuracy": float(va), "macro_f1": float(vf1),
            "notes": f"EmotionMLP optimiser={opt_name}"
        })

    # ── Plot training curves for all optimisers ──
    fig, axes = plt.subplots(2, 2, figsize=(16, 10))
    axes = axes.flatten()
    colors = ["tab:blue", "tab:orange", "tab:green", "tab:red"]
    for ax, (opt_name, (tl, vl, ta, va)), col in zip(axes, opt_histories.items(), colors):
        ep = range(1, len(tl)+1)
        ax2 = ax.twinx()
        ax.plot(ep, tl, "--", color=col, alpha=0.5, label="Train Loss")
        ax.plot(ep, vl, "-",  color=col, label="Val Loss")
        ax2.plot(ep, ta, "--", color="gray",  alpha=0.5, label="Train Acc")
        ax2.plot(ep, va, "-",  color="black", label="Val Acc")
        ax.set_title(opt_name, fontweight="bold")
        ax.set_xlabel("Epoch"); ax.set_ylabel("Loss")
        ax2.set_ylabel("Accuracy")
        lines1, lbl1 = ax.get_legend_handles_labels()
        lines2, lbl2 = ax2.get_legend_handles_labels()
        ax.legend(lines1+lines2, lbl1+lbl2, loc="upper right", fontsize=8)
    plt.suptitle("RAVDESS MLP — Optimiser Comparison", fontsize=14, fontweight="bold")
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "rav_mlp_optimiser_comparison.png", bbox_inches="tight")
    plt.show()

    print("\nFinal Val Results:")
    print(pd.DataFrame(opt_final).to_string(index=False))

    # Identify best optimiser (highest val F1)
    best_opt_row = max(opt_final, key=lambda r: r["Val Macro-F1"])
    BEST_OPT_RAV = best_opt_row["Optimiser"]
    print(f"\nBest optimiser: {BEST_OPT_RAV}")
# Out:
# Using device: cuda (RAVDESS MLP: 60 epochs)
#
# Training with SGD...
#   Epoch  10: tr_loss=1.7099 vl_loss=2.0162 val_acc=0.2467 val_f1=0.2176
#   Epoch  20: tr_loss=1.4277 vl_loss=2.1194 val_acc=0.2367 val_f1=0.2297
#   Epoch  30: tr_loss=1.2588 vl_loss=2.2539 val_acc=0.2267 val_f1=0.2201
#   Epoch  40: tr_loss=1.1237 vl_loss=2.3367 val_acc=0.2233 val_f1=0.2184
#   Epoch  50: tr_loss=1.0422 vl_loss=2.3684 val_acc=0.2667 val_f1=0.2622
#   Epoch  60: tr_loss=0.9289 vl_loss=2.3763 val_acc=0.2467 val_f1=0.2444
#   [saved] rav_mlp_sgd: {'accuracy': 0.24666666666666667, 'macro_f1': 0.24444299961226185, 'notes': 'EmotionMLP optimiser=SGD'}
#
# Training with Adam...
#   Epoch  10: tr_loss=1.5952 vl_loss=2.0120 val_acc=0.2400 val_f1=0.2143
#   Epoch  20: tr_loss=1.1908 vl_loss=2.1009 val_acc=0.2333 val_f1=0.2081
#   Epoch  30: tr_loss=0.9304 vl_loss=2.2108 val_acc=0.2600 val_f1=0.2463
#   Epoch  40: tr_loss=0.8059 vl_loss=2.1926 val_acc=0.3100 val_f1=0.2939
# ...

# %%
# ── Cell 1.6: MLP Regularisation Ablation — Dropout × Weight Decay ──
# Fix AdamW. Grid over dropout and weight_decay.
# Uses scaled RAVDESS data (X_rav_train_sc) via tr_loader/vl_loader from cell 1.5.
# Metric: val Macro-F1 after 30 epochs.

if not TORCH_AVAILABLE:
    print("WARNING: PyTorch not available — skipping cell 1.6.")
else:
    dropouts      = [0.0, 0.2, 0.3, 0.5]
    weight_decays = [0, 1e-4, 1e-3, 1e-2]

    reg_abl_f1  = np.zeros((len(dropouts), len(weight_decays)))
    reg_abl_acc = np.zeros((len(dropouts), len(weight_decays)))

    print("Running dropout × weight_decay grid (AdamW, 25 epochs)...")
    _EPOCHS_ABL_RAV = 25  # faster grid; best config then trained fully in cell 1.7
    for i, do in enumerate(dropouts):
        for j, wd in enumerate(weight_decays):
            torch.manual_seed(42)
            model = EmotionMLP(X_rav_train_sc.shape[1], HIDDEN, N_CLASSES, dropout=do).to(device)
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=wd)
            for epoch in range(_EPOCHS_ABL_RAV):
                torch_train_epoch(model, tr_loader, criterion, optimizer, device)
            _, va, vf1 = torch_eval_epoch(model, vl_loader, criterion, device)
            reg_abl_f1[i, j]  = vf1
            reg_abl_acc[i, j] = va
            print(f"  dropout={do}  wd={wd:.0e}  -> F1={vf1:.4f} acc={va:.4f}")

    do_labels = [f"drop={d}" for d in dropouts]
    wd_labels = [f"wd={w:.0e}" for w in weight_decays]
    make_heatmap(
        reg_abl_f1, do_labels, wd_labels,
        "dropout", "weight_decay",
        title="RAVDESS MLP Regularisation Ablation — Val Macro-F1 (AdamW)",
        cmap="YlOrRd", fmt=".3f",
        save_path=OUTPUT_DIR / "rav_mlp_reg_ablation.png"
    )

    best_abl_idx = np.unravel_index(np.argmax(reg_abl_f1), reg_abl_f1.shape)
    BEST_DROPOUT_RAV = dropouts[best_abl_idx[0]]
    BEST_WD_RAV      = weight_decays[best_abl_idx[1]]
    print(f"\nBest config: dropout={BEST_DROPOUT_RAV}, weight_decay={BEST_WD_RAV}")
    print(f"Best val Macro-F1: {reg_abl_f1[best_abl_idx]:.4f}")

    save_results("rav_mlp_reg_best", {
        "accuracy": float(reg_abl_acc[best_abl_idx]),
        "macro_f1": float(reg_abl_f1[best_abl_idx]),
        "dropout": BEST_DROPOUT_RAV, "weight_decay": BEST_WD_RAV,
        "notes": "MLP best reg config"
    })
# Out:
# Running dropout × weight_decay grid (AdamW, 25 epochs)...
#   dropout=0.0  wd=0e+00  -> F1=0.2497 acc=0.2667
#   dropout=0.0  wd=1e-04  -> F1=0.2620 acc=0.2767
#   dropout=0.0  wd=1e-03  -> F1=0.2675 acc=0.2833
#   dropout=0.0  wd=1e-02  -> F1=0.2624 acc=0.2800
#   dropout=0.2  wd=0e+00  -> F1=0.2458 acc=0.2667
#   dropout=0.2  wd=1e-04  -> F1=0.2412 acc=0.2400
#   dropout=0.2  wd=1e-03  -> F1=0.2778 acc=0.3033
#   dropout=0.2  wd=1e-02  -> F1=0.2680 acc=0.2733
#   dropout=0.3  wd=0e+00  -> F1=0.2861 acc=0.3067
#   dropout=0.3  wd=1e-04  -> F1=0.2423 acc=0.2600
#   dropout=0.3  wd=1e-03  -> F1=0.2492 acc=0.2667
#   dropout=0.3  wd=1e-02  -> F1=0.2720 acc=0.2967
#   dropout=0.5  wd=0e+00  -> F1=0.2418 acc=0.2800
#   dropout=0.5  wd=1e-04  -> F1=0.2242 acc=0.2633
#   dropout=0.5  wd=1e-03  -> F1=0.2097 acc=0.2500
#   dropout=0.5  wd=1e-02  -> F1=0.2319 acc=0.2667
# Best config: dropout=0.3, weight_decay=0
# Best val Macro-F1: 0.2861
# ...

# %%
# ── Cell 1.7: LR Scheduler Experiment ──
# Fix AdamW with best dropout/weight_decay from 1.6.
# Compare: No scheduler | StepLR | CosineAnnealingLR | ReduceLROnPlateau
# Train 50 epochs each. Plot val loss curves and LR over time.

if not TORCH_AVAILABLE:
    print("WARNING: PyTorch not available — skipping cell 1.7.")
else:
    EPOCHS_SCH = 40

    scheduler_configs = [
        ("No Scheduler",         None),
        ("CosineAnnealingLR",    lambda opt: optim.lr_scheduler.CosineAnnealingLR(opt, T_max=EPOCHS_SCH)),
        ("ReduceLROnPlateau",    lambda opt: optim.lr_scheduler.ReduceLROnPlateau(opt, patience=5, factor=0.5)),
    ]

    sch_histories = {}
    sch_final     = []

    for sch_name, sch_fn in scheduler_configs:
        print(f"\nTraining with {sch_name}...")
        torch.manual_seed(42)
        model = EmotionMLP(X_rav_train_sc.shape[1], HIDDEN, N_CLASSES,
                            dropout=BEST_DROPOUT_RAV).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=BEST_WD_RAV)
        scheduler = sch_fn(optimizer) if sch_fn is not None else None

        tl_h, vl_h, ta_h, va_h, lr_h = [], [], [], [], []
        for epoch in range(1, EPOCHS_SCH + 1):
            tl, ta = torch_train_epoch(model, tr_loader, criterion, optimizer, device)
            vl, va, vf1 = torch_eval_epoch(model, vl_loader, criterion, device)
            tl_h.append(tl); vl_h.append(vl)
            ta_h.append(ta); va_h.append(va)
            lr_h.append(optimizer.param_groups[0]["lr"])
            if scheduler is not None:
                if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                    scheduler.step(vl)
                else:
                    scheduler.step()
            if epoch % 10 == 0:
                print(f"  Epoch {epoch:3d}: vl={vl:.4f} va={va:.4f} vf1={vf1:.4f} lr={lr_h[-1]:.6f}")

        sch_histories[sch_name] = (tl_h, vl_h, ta_h, va_h, lr_h)
        sch_final.append({"Scheduler": sch_name,
                          "Val Accuracy": round(va, 4),
                          "Val Macro-F1": round(vf1, 4),
                          "Final LR": f"{lr_h[-1]:.6f}"})
        save_results(f"rav_mlp_sch_{sch_name[:8].replace(' ','_').lower()}", {
            "accuracy": float(va), "macro_f1": float(vf1),
            "notes": f"scheduler={sch_name}"
        })

    # Plot val loss curves + LR over time
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))
    colors_s = ["tab:blue","tab:orange","tab:green","tab:red"]
    for (sch_name, hist), col in zip(sch_histories.items(), colors_s):
        _, vl_h, _, _, lr_h = hist
        ax1.plot(range(1, EPOCHS_SCH+1), vl_h, label=sch_name, color=col)
        ax2.plot(range(1, EPOCHS_SCH+1), lr_h, label=sch_name, color=col)
    ax1.set_title("Val Loss per Scheduler", fontweight="bold")
    ax1.set_xlabel("Epoch"); ax1.set_ylabel("Val Loss"); ax1.legend(fontsize=9)
    ax2.set_title("Learning Rate Over Time", fontweight="bold")
    ax2.set_xlabel("Epoch"); ax2.set_ylabel("LR"); ax2.legend(fontsize=9)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "rav_mlp_scheduler_comparison.png", bbox_inches="tight")
    plt.show()

    print("\nScheduler Final Results:")
    print(pd.DataFrame(sch_final).to_string(index=False))
# Out:
# Training with No Scheduler...
#   Epoch  10: vl=1.9561 va=0.2267 vf1=0.1823 lr=0.001000
#   Epoch  20: vl=2.1060 va=0.2600 vf1=0.2295 lr=0.001000
#   Epoch  30: vl=2.6386 va=0.2333 vf1=0.1998 lr=0.001000
#   Epoch  40: vl=2.3601 va=0.3100 vf1=0.2889 lr=0.001000
#   [saved] rav_mlp_sch_no_sched: {'accuracy': 0.31, 'macro_f1': 0.2889065746986539, 'notes': 'scheduler=No Scheduler'}
#
# Training with CosineAnnealingLR...
#   Epoch  10: vl=1.9540 va=0.2333 vf1=0.1850 lr=0.000880
#   Epoch  20: vl=1.9610 va=0.2633 vf1=0.2307 lr=0.000539
#   Epoch  30: vl=1.9939 va=0.2667 vf1=0.2416 lr=0.000175
#   Epoch  40: vl=2.0116 va=0.2667 vf1=0.2414 lr=0.000002
#   [saved] rav_mlp_sch_cosinean: {'accuracy': 0.26666666666666666, 'macro_f1': 0.24138743213634067, 'notes': 'scheduler=CosineAnnealingLR'}
#
# Training with ReduceLROnPlateau...
#   Epoch  10: vl=1.9561 va=0.2267 vf1=0.1823 lr=0.001000
#   Epoch  20: vl=2.0677 va=0.2367 vf1=0.2108 lr=0.000500
# ...

# %%
# ── Cell 1.7b: Final MLP trained on train+val combined (eval on test) ──
# Uses X_rav_trainval_sc (1140 samples) to maximise data before final test eval.
if not TORCH_AVAILABLE:
    print("PyTorch not available — skipping.")
else:
    _pin = torch.cuda.is_available()
    from torch.utils.data import TensorDataset, DataLoader

    # DataLoader for combined train+val (no validation split needed here)
    _tv_ds = TensorDataset(
        torch.tensor(X_rav_trainval_sc, dtype=torch.float32),
        torch.tensor(y_rav_trainval, dtype=torch.long)
    )
    _te_ds = TensorDataset(
        torch.tensor(X_rav_test_sc, dtype=torch.float32),
        torch.tensor(y_rav_test, dtype=torch.long)
    )
    _tv_ld = DataLoader(_tv_ds, batch_size=128, shuffle=True,
                        pin_memory=_pin, num_workers=0)
    _te_ld = DataLoader(_te_ds, batch_size=256, shuffle=False,
                        pin_memory=_pin, num_workers=0)

    # Use best optimiser found in Cell 1.5
    _best_opt_name = BEST_OPT_RAV if 'BEST_OPT_RAV' in dir() else 'AdamW'
    _opt_map = {
        "SGD":     lambda p: optim.SGD(p, lr=0.01, momentum=0.9),
        "Adam":    lambda p: optim.Adam(p, lr=1e-3),
        "AdamW":   lambda p: optim.AdamW(p, lr=1e-3, weight_decay=1e-4),
        "RMSprop": lambda p: optim.RMSprop(p, lr=1e-3),
    }
    _opt_fn = _opt_map.get(_best_opt_name, _opt_map["AdamW"])

    torch.manual_seed(42)
    _final_mlp = EmotionMLP(X_rav_trainval_sc.shape[1], [256, 128, 64], 8, dropout=0.3).to(DEVICE)
    _cls_w2 = torch.ones(8).to(DEVICE); _cls_w2[5] = 2.0
    _crit2   = nn.CrossEntropyLoss(weight=_cls_w2, label_smoothing=0.1)
    _optim2  = _opt_fn(_final_mlp.parameters())

    EPOCHS_FINAL = 60
    print(f"Training final MLP on train+val ({X_rav_trainval_sc.shape[0]} samples) "
          f"with {_best_opt_name}, {EPOCHS_FINAL} epochs...")
    for ep in range(1, EPOCHS_FINAL + 1):
        _final_mlp.train()
        for Xb, yb in _tv_ld:
            Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
            _optim2.zero_grad()
            _crit2(_final_mlp(Xb), yb).backward()
            _optim2.step()
        if ep % 20 == 0:
            print(f"  Epoch {ep}/{EPOCHS_FINAL} done")

    # Evaluate on test set
    _final_mlp.eval()
    _all_preds, _all_true = [], []
    with torch.no_grad():
        for Xb, yb in _te_ld:
            _logits = _final_mlp(Xb.to(DEVICE))
            _all_preds.extend(_logits.argmax(1).cpu().numpy())
            _all_true.extend(yb.numpy())
    from sklearn.metrics import accuracy_score, f1_score
    _final_acc = accuracy_score(_all_true, _all_preds)
    _final_f1  = f1_score(_all_true, _all_preds, average='macro', zero_division=0)
    print(f"\nFinal MLP (train+val → test):  acc={_final_acc:.4f}  macro-F1={_final_f1:.4f}")
    save_results('rav_mlp_trainval_test', {
        'accuracy': float(_final_acc), 'macro_f1': float(_final_f1),
        'notes': f'EmotionMLP trained on 1140 train+val samples, eval on test, opt={_best_opt_name}'
    })
# Out:
# Training final MLP on train+val (1140 samples) with AdamW, 60 epochs...
#   Epoch 20/60 done
#   Epoch 40/60 done
#   Epoch 60/60 done
#
# Final MLP (train+val → test):  acc=0.3567  macro-F1=0.3299
#   [saved] rav_mlp_trainval_test: {'accuracy': 0.3566666666666667, 'macro_f1': 0.32992861359259806, 'notes': 'EmotionMLP trained on 1140 train+val samples, eval on test, opt=AdamW'}

# %% [markdown]
# ## Cell 1.8 — RAVDESS Section Summary
#
# The following cell prints a consolidated summary of all RAVDESS experiments and identifies the best configuration for downstream use.

# %%
# ── Cell 1.8: RAVDESS Summary Table ──
rav_keys = [k for k in RESULTS if k.startswith("rav_")]
rav_summary = []
for k in rav_keys:
    r = RESULTS[k]
    rav_summary.append({
        "Key":          k,
        "Val Accuracy": r.get("accuracy", "-"),
        "Macro-F1":     r.get("macro_f1", "-"),
        "Notes":        r.get("notes", "")
    })
rav_sum_df = pd.DataFrame(rav_summary)
print("="*80)
print("  RAVDESS — All Experiment Results")
print("="*80)
print(rav_sum_df.to_string(index=False))

# Best overall
best_rav = max(rav_summary, key=lambda r: float(r["Macro-F1"]) if r["Macro-F1"] != "-" else 0)
print(f"\nBest RAVDESS config: {best_rav['Key']} | F1={best_rav['Macro-F1']} | Acc={best_rav['Val Accuracy']}")
print("M3 Baseline: ~0.72 accuracy.  See improvement above.")
# Out:
# ...
#   RAVDESS — All Experiment Results
# ...
#                   Key  Val Accuracy  Macro-F1                                                                 Notes
#        rav_svm_scaled      0.286667  0.280268                                        SVM RBF C=100.0 scaled (tuned)
#       rav_rf_baseline      0.410000  0.371198                                                              RF n=200
#      rav_xgb_baseline      0.400000  0.381564                                                   XGB depth=4 lr=0.05
#      rav_gbm_baseline      0.426667  0.423346                                                     GBM n=200 depth=3
# rav_xgb_trainval_test      0.496667  0.485458                 XGB trained on train+val (1140 samples), eval on test
#     rav_xgb_grid_best      0.470000  0.453953                                                         XGB grid best
#      rav_xgb_reg_best      0.486667  0.472356                                        XGB best regularisation config
# ...

# %%
# ── Cell 1.9: RAVDESS — Model Artifacts, Sample Predictions & Confusion Matrix ──
# Saves trained XGBoost and MLP model weights, shows 10 sample predictions,
# and plots the full test-set confusion matrix for qualitative inspection.

import pickle, torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

print('=' * 60)
print('  RAVDESS — ARTIFACTS & SAMPLE OUTPUT')
print('=' * 60)

# ── 1. Save XGBoost model ──
if '_xgb_final' in dir() and _xgb_final is not None:
    _xgb_path = OUTPUT_DIR / 'rav_xgb_final.json'
    _xgb_final.save_model(str(_xgb_path))
    print(f'[SAVED] XGBoost model -> {_xgb_path.name}')
else:
    print('[SKIP] _xgb_final not in memory (run Cell 1.5 first)')

# ── 2. Save MLP weights ──
if '_final_mlp' in dir() and _final_mlp is not None:
    _mlp_path = OUTPUT_DIR / 'rav_mlp_final.pth'
    torch.save(_final_mlp.state_dict(), str(_mlp_path))
    print(f'[SAVED] MLP state_dict  -> {_mlp_path.name}')
else:
    print('[SKIP] _final_mlp not in memory')

# ── 3. Sample predictions (10 rows from test set) ──
print('\n── 10 Sample Predictions (RAVDESS 8-class Emotion) ──')
_has_rav_test = ('X_rav_test' in dir() and X_rav_test is not None and
                  'y_rav_test' in dir() and y_rav_test is not None)
if _has_rav_test and '_xgb_final' in dir() and _xgb_final is not None:
    _xgb_preds = _xgb_final.predict(X_rav_test)[:10]
    _true_lbls = y_rav_test[:10]
    _emo_names  = ['neutral','calm','happy','sad','angry','fearful','disgust','surprised']
    _sample_df  = pd.DataFrame({
        'Sample'    : range(1, 11),
        'True Label': [_emo_names[int(l)] for l in _true_lbls],
        'Predicted' : [_emo_names[int(p)] for p in _xgb_preds],
        'Correct?'  : ['YES' if t == p else 'NO'
                        for t, p in zip(_true_lbls, _xgb_preds)]
    })
    print(_sample_df.to_string(index=False))
else:
    print('[SKIP] RAVDESS test split or _xgb_final not available')

# ── 4. Confusion matrix plot ──
print('\n── Confusion Matrix: RAVDESS XGBoost (Test Set) ──')
if _has_rav_test and '_xgb_final' in dir() and _xgb_final is not None:
    _all_preds = _xgb_final.predict(X_rav_test)
    _emo_short  = ['neu','clm','hpy','sad','ang','fear','dis','sur']
    _cm  = confusion_matrix(y_rav_test, _all_preds)
    fig, ax = plt.subplots(figsize=(8, 6))
    ConfusionMatrixDisplay(_cm, display_labels=_emo_short).plot(
        ax=ax, colorbar=True, cmap='Blues')
    ax.set_title('RAVDESS XGBoost — Test Set Confusion Matrix', fontsize=13)
    plt.tight_layout()
    _cm_path = OUTPUT_DIR / 'rav_xgb_confusion_matrix.png'
    plt.savefig(str(_cm_path), dpi=120, bbox_inches='tight')
    plt.show()
    print(f'[SAVED] {_cm_path.name}')
else:
    print('[SKIP] Test data or model not available')
# Out:
# ...
#   RAVDESS — ARTIFACTS & SAMPLE OUTPUT
# ...
# [SAVED] XGBoost model -> rav_xgb_final.json
# [SAVED] MLP state_dict  -> rav_mlp_final.pth
#
# ── 10 Sample Predictions (RAVDESS 8-class Emotion) ──
#  Sample True Label Predicted Correct?
#       1    fearful      calm       NO
#       2    fearful      calm       NO
#       3    fearful      calm       NO
#       4    fearful      calm       NO
#       5       calm      calm      YES
#       6       calm      calm      YES
#       7       calm   disgust       NO
#       8       calm      calm      YES
#       9       calm      calm      YES
#      10       calm      calm      YES
#
# ── Confusion Matrix: RAVDESS XGBoost (Test Set) ──
# [SAVED] rav_xgb_confusion_matrix.png

# %% [markdown]
# ## Section 1.10 — Whisper Encoder Experiments (Pipeline 2 Foundation)
#
# **Core motivation:** Pipeline 2 uses a frozen `openai/whisper-small` encoder (244M params)
# to extract rich 768-dimensional speech embeddings directly from raw waveforms,
# bypassing hand-crafted MFCC/mel/chroma features. This section benchmarks:
#
# - **Whisper + XGBoost** — does the pre-trained speech encoder improve over hand-crafted features?
# - **Whisper + MLP** — how does a neural head on frozen Whisper embeddings compare to training
#   an MLP on traditional 338-dim features?
#
# Results feed directly into M5's full Pipeline 2 (Whisper + BioClinicalBERT + gated fusion).
#
# | Approach | Features | Dim |
# |---|---|---|
# | Hand-crafted (Sections 1.1–1.9) | MFCC(160)+Mel(128)+Chroma(24)+Spectral(20) | 338 |
# | **Whisper encoder (this section)** | Frozen whisper-small temporal mean pool | **768** |

# %%
# Cell 1.10a: Whisper-small Embedding Extraction — RAVDESS
# Scans ALL of /kaggle/input for wav files with RAVDESS filename pattern
# (7 dash-separated parts e.g. 03-01-06-01-02-01-12.wav)
# NO directory-name assumptions — works regardless of Kaggle slug.

import sys, os, time, warnings
import numpy as np, torch
from pathlib import Path
warnings.filterwarnings('ignore')

print('=' * 65)
print('  CELL 1.10a — RAVDESS Whisper Embedding Extraction')
print('=' * 65)

# Step 1: show mounted datasets so we can verify
print('Mounted /kaggle/input datasets:')
for _d in sorted(Path('/kaggle/input').iterdir()):
    _nwav = len(list(_d.rglob('*.wav')))
    print(f'  {_d.name}  ({_nwav} wav files)')

# Step 2: collect ALL wav files across entire /kaggle/input
print('\nScanning all wav files...')
_all_wav = list(Path('/kaggle/input').rglob('*.wav'))
print(f'  Total wav files found: {len(_all_wav)}')

# Step 3: filter to RAVDESS pattern — stem has exactly 7 dash-parts
#   format: modality-vocal_channel-emotion-intensity-statement-repetition-actor
_rav_wav = [w for w in _all_wav if len(w.stem.split('-')) == 7]
print(f'  RAVDESS pattern wavs : {len(_rav_wav)}')

if not _rav_wav:
    print('[STOP] No RAVDESS wav files found.')
    print('  Make sure dataset RAVDESS_AUDIO_GROUP-6_DSAI is added to this notebook.')
    print('  All wav files seen:')
    for _w in sorted(_all_wav)[:10]:
        print('   ', _w)
    _whisper_ok = False
else:
    print(f'  Sample path: {sorted(_rav_wav)[0]}')
    _whisper_ok = True

if _whisper_ok:
    # Parse labels and actor IDs from filename
    _wav_paths, _wav_labels, _wav_actors = [], [], []
    for _wf in sorted(_rav_wav):
        _p = _wf.stem.split('-')
        try:
            _wav_paths.append(_wf)
            _wav_labels.append(int(_p[2]) - 1)   # emotion: 1-indexed -> 0-indexed
            _wav_actors.append(int(_p[6]))        # actor ID
        except Exception:
            pass
    print(f'  Parsed: {len(_wav_paths)} files | {len(set(_wav_labels))} classes | {len(set(_wav_actors))} actors')

    # Install whisper if needed
    try:
        import whisper as _whisper
        print('  openai-whisper already installed')
    except ImportError:
        print('  Installing openai-whisper...')
        import subprocess
        subprocess.run([sys.executable,'-m','pip','install','-q','openai-whisper'], check=True)
        import whisper as _whisper

    # Load model
    _dev = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f'  Loading whisper-small on {_dev}...')
    _t0 = time.time()
    _wmodel = _whisper.load_model('small', device=_dev)
    _wmodel.eval()
    print(f'  Loaded in {time.time()-_t0:.1f}s')

    # Extract: mean+std pooling -> 1536-D
    _embs, _WD = [], 1536
    _t1 = time.time()
    with torch.no_grad():
        for _i, _wf in enumerate(_wav_paths):
            try:
                _a   = _whisper.load_audio(str(_wf))
                _a   = _whisper.pad_or_trim(_a)
                _mel = _whisper.log_mel_spectrogram(_a, n_mels=80).to(_dev)
                _enc = _wmodel.encoder(_mel.unsqueeze(0)).squeeze(0)     # (T,768)
                _emb = torch.cat([_enc.mean(0), _enc.std(0)]).float().cpu().numpy()  # (1536,)
                _embs.append(_emb)
            except Exception:
                _embs.append(np.zeros(_WD, dtype=np.float32))
            if (_i+1) % 300 == 0:
                _el = time.time()-_t1
                print(f'  {_i+1}/{len(_wav_paths)} | {_el/60:.1f}min elapsed | eta {_el/(_i+1)*(len(_wav_paths)-_i-1)/60:.1f}min')

    _X_wh  = np.stack(_embs)          # (N,1536)
    _y_wh  = np.array(_wav_labels)
    _ac_wh = np.array(_wav_actors)
    print(f'  Embeddings done: {_X_wh.shape}  time={(time.time()-_t1)/60:.1f}min')

    # Actor-based split (matches existing hand-crafted split)
    try:
        import pandas as _pd
        _adf  = _pd.read_csv(str(BASE_DATA/'ravdess'/'ravdess_actor_splits.csv'))
        _tr_a = set(_adf[_adf.split=='train']['actor'])
        _vl_a = set(_adf[_adf.split=='val']['actor'])
        _te_a = set(_adf[_adf.split=='test']['actor'])
        _Xw_tr = _X_wh[np.isin(_ac_wh,list(_tr_a))]; _yw_tr = _y_wh[np.isin(_ac_wh,list(_tr_a))]
        _Xw_vl = _X_wh[np.isin(_ac_wh,list(_vl_a))]; _yw_vl = _y_wh[np.isin(_ac_wh,list(_vl_a))]
        _Xw_te = _X_wh[np.isin(_ac_wh,list(_te_a))]; _yw_te = _y_wh[np.isin(_ac_wh,list(_te_a))]
    except Exception as _se:
        print(f'  Actor CSV not found ({_se}), using stratified 70/15/15 split')
        from sklearn.model_selection import train_test_split as _tts
        _Xw_tr,_Xw_te,_yw_tr,_yw_te = _tts(_X_wh,_y_wh,test_size=0.15,random_state=42,stratify=_y_wh)
        _Xw_tr,_Xw_vl,_yw_tr,_yw_vl = _tts(_Xw_tr,_yw_tr,test_size=0.176,random_state=42,stratify=_yw_tr)

    print(f'  Split -> train:{_Xw_tr.shape} val:{_Xw_vl.shape} test:{_Xw_te.shape}')

    # Save to /kaggle/working (persists across cells)
    _ED = Path('/kaggle/working')
    for _n,_a in [('wh_Xtr',_Xw_tr),('wh_Xvl',_Xw_vl),('wh_Xte',_Xw_te),
                  ('wh_ytr',_yw_tr),('wh_yvl',_yw_vl),('wh_yte',_yw_te)]:
        np.save(str(_ED/(_n+'.npy')), _a)

    # Keep model + module in globals for 1.10c and 1.10d
    _whisper_model_global  = _wmodel
    _whisper_module_global = _whisper
    _emb_save_dir          = _ED
    _emb_extracted         = True
    print(f'  Saved to {_ED}')
    print('[DONE] 1.10a complete. Cells 1.10b/c/d/e will now run.')
# Out:
# ...
#   CELL 1.10a — RAVDESS Whisper Embedding Extraction
# ...
# Mounted /kaggle/input datasets:
#   datasets  (4573 wav files)
#
# Scanning all wav files...
#   Total wav files found: 4573
#   RAVDESS pattern wavs : 2880
#   Sample path: /kaggle/input/datasets/pankajmsah/ravdess-audio-group-6-dsai/RAVDESS Emotional speech audio/Actor_01/03-01-01-01-01-01-01.wav
#   Parsed: 2880 files | 8 classes | 24 actors
#   Installing openai-whisper...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 19.5 MB/s eta 0:00:00
#   Loading whisper-small on cuda...
# 100%|████████████████████████████████████████| 461M/461M [00:03<00:00, 126MiB/s]
#   Loaded in 8.1s
#   300/2880 | 1.2min elapsed | eta 10.4min
#   600/2880 | 2.4min elapsed | eta 9.2min
#   900/2880 | 3.6min elapsed | eta 8.0min
#   1200/2880 | 4.8min elapsed | eta 6.7min
#   1500/2880 | 6.0min elapsed | eta 5.5min
#   1800/2880 | 7.2min elapsed | eta 4.3min
#   2100/2880 | 8.5min elapsed | eta 3.1min
# ...

# %%
# Cell 1.10b: RAVDESS — XGBoost & MLP on Whisper 1536-D Embeddings

import numpy as np, time, torch
from pathlib import Path
from sklearn.metrics import f1_score, accuracy_score

print('=' * 65)
print('  CELL 1.10b — RAVDESS Whisper XGBoost & MLP')
print('=' * 65)

_ED = Path('/kaggle/working')
_needed = ['wh_Xtr.npy','wh_Xvl.npy','wh_Xte.npy','wh_ytr.npy','wh_yvl.npy','wh_yte.npy']
if not all((_ED/f).exists() for f in _needed):
    print('[STOP] Embeddings missing — Cell 1.10a did not complete successfully.')
else:
    _Xw_tr = np.load(str(_ED/'wh_Xtr.npy')); _yw_tr = np.load(str(_ED/'wh_ytr.npy'))
    _Xw_vl = np.load(str(_ED/'wh_Xvl.npy')); _yw_vl = np.load(str(_ED/'wh_yvl.npy'))
    _Xw_te = np.load(str(_ED/'wh_Xte.npy')); _yw_te = np.load(str(_ED/'wh_yte.npy'))
    _Xw_tv = np.concatenate([_Xw_tr,_Xw_vl]); _yw_tv = np.concatenate([_yw_tr,_yw_vl])
    print(f'  Loaded: train{_Xw_tr.shape} val{_Xw_vl.shape} test{_Xw_te.shape}')

    # ── A: XGBoost ──
    print('\n[A] XGBoost on Whisper 1536-D')
    from xgboost import XGBClassifier
    _lr  = globals().get('_best_lr',  0.1)
    _dep = globals().get('_best_dep', 2)
    _nes = globals().get('_best_nest',300)
    _kw  = dict(learning_rate=_lr, max_depth=_dep, n_estimators=_nes,
                eval_metric='mlogloss',
                tree_method='hist', device='cuda' if torch.cuda.is_available() else 'cpu',
                random_state=42, n_jobs=-1)
    _t0 = time.time()
    _xgb = XGBClassifier(**_kw)
    _xgb.fit(_Xw_tr, _yw_tr, eval_set=[(_Xw_vl,_yw_vl)], verbose=False)
    _vf1_x = f1_score(_yw_vl, _xgb.predict(_Xw_vl), average='macro')
    _xgb_f = XGBClassifier(**_kw)
    _xgb_f.fit(_Xw_tv, _yw_tv, verbose=False)
    _tf1_x = f1_score(_yw_te, _xgb_f.predict(_Xw_te), average='macro')
    _tac_x = accuracy_score(_yw_te, _xgb_f.predict(_Xw_te))
    print(f'  Val F1={_vf1_x:.4f}  Test F1={_tf1_x:.4f}  Acc={_tac_x:.4f}  ({time.time()-_t0:.1f}s)')
    _xgb_f.save_model(str(OUTPUT_DIR/'rav_whisper_xgb.json'))
    RESULTS['rav_whisper_xgb'] = {'model':'XGBoost','feature':'Whisper-small 1536-D',
        'val_macro_f1':round(_vf1_x,4),'test_macro_f1':round(_tf1_x,4),'test_accuracy':round(_tac_x,4)}

    # ── B: MLP ──
    print('\n[B] MLP on Whisper 1536-D  (1536->768->256->n_cls)')
    import torch.nn as _nn, torch.optim as _opt
    from torch.utils.data import TensorDataset as _TDS, DataLoader as _DL
    import copy
    _dv   = 'cuda' if torch.cuda.is_available() else 'cpu'
    _do   = globals().get('_best_dropout', 0.3)
    _wd   = globals().get('_best_wd', 1e-4)
    _ncls = len(np.unique(_yw_tr))

    class _WM(_nn.Module):
        def __init__(self):
            super().__init__()
            self.net = _nn.Sequential(
                _nn.Linear(1536,768), _nn.BatchNorm1d(768), _nn.GELU(), _nn.Dropout(_do),
                _nn.Linear(768,256),  _nn.BatchNorm1d(256), _nn.GELU(), _nn.Dropout(_do/2),
                _nn.Linear(256,_ncls))
        def forward(self,x): return self.net(x)

    def _dl(X,y,bs=128,sh=False):
        return _DL(_TDS(torch.tensor(X,dtype=torch.float32),
                        torch.tensor(y,dtype=torch.long)),batch_size=bs,shuffle=sh)

    _m = _WM().to(_dv)
    _cr = _nn.CrossEntropyLoss()
    _op = _opt.AdamW(_m.parameters(), lr=3e-4, weight_decay=_wd)
    _sc = _opt.lr_scheduler.CosineAnnealingLR(_op, T_max=40)
    _dl_tr = _dl(_Xw_tr,_yw_tr,sh=True)
    _dl_vl = _dl(_Xw_vl,_yw_vl)
    _dl_te = _dl(_Xw_te,_yw_te)
    _bvf, _bst, _EPOCHS = 0.0, None, 50
    _t2 = time.time()
    for _ep in range(1, _EPOCHS+1):
        _m.train()
        for _Xb,_yb in _dl_tr:
            _Xb,_yb = _Xb.to(_dv),_yb.to(_dv)
            _op.zero_grad(); _cr(_m(_Xb),_yb).backward(); _op.step()
        _sc.step()
        if _ep % 10 == 0 or _ep == _EPOCHS:
            _m.eval(); _pv = []
            with torch.no_grad():
                for _Xb,_ in _dl_vl: _pv.extend(_m(_Xb.to(_dv)).argmax(1).cpu().numpy())
            _vf = f1_score(_yw_vl,_pv,average='macro')
            print(f'  Ep{_ep:3d}/{_EPOCHS}  val_F1={_vf:.4f}')
            if _vf > _bvf: _bvf=_vf; _bst=copy.deepcopy(_m.state_dict())
    _m.load_state_dict(_bst); _m.eval(); _pt=[]
    with torch.no_grad():
        for _Xb,_ in _dl_te: _pt.extend(_m(_Xb.to(_dv)).argmax(1).cpu().numpy())
    _tf1_m = f1_score(_yw_te,_pt,average='macro')
    _tac_m = accuracy_score(_yw_te,_pt)
    print(f'  Best Val F1={_bvf:.4f}  Test F1={_tf1_m:.4f}  Acc={_tac_m:.4f}  ({(time.time()-_t2)/60:.1f}min)')
    torch.save(_bst, str(OUTPUT_DIR/'rav_whisper_mlp.pth'))
    RESULTS['rav_whisper_mlp'] = {'model':'MLP','feature':'Whisper-small 1536-D',
        'val_macro_f1':round(_bvf,4),'test_macro_f1':round(_tf1_m,4),'test_accuracy':round(_tac_m,4)}

    # ── Comparison table ──
    print('\n' + '='*60)
    print('  RAVDESS: Hand-crafted vs Whisper Encoder')
    print('='*60)
    print(f'{"Model":<22} {"Features":<26} {"Test F1":>8} {"Acc":>7}')
    print('-'*60)
    for _k,_nm,_ft in [
        ('rav_xgb_trainval_test','XGBoost','Hand-crafted 338-D'),
        ('rav_mlp_trainval_test','MLP',    'Hand-crafted 338-D'),
        ('rav_whisper_xgb',     'Whisper+XGBoost','Whisper 1536-D'),
        ('rav_whisper_mlp',     'Whisper+MLP',    'Whisper 1536-D'),
    ]:
        _r = RESULTS.get(_k)
        if not _r: continue
        _f = _r.get('test_macro_f1',_r.get('macro_f1','N/A'))
        _a = _r.get('test_accuracy','N/A')
        print(f'{_nm:<22} {_ft:<26} {str(_f):>8} {str(_a):>7}')
    print('='*60)
    print('[DONE] rav_whisper_xgb, rav_whisper_mlp added to RESULTS')
# Out:
# ...
#   CELL 1.10b — RAVDESS Whisper XGBoost & MLP
# ...
#   Loaded: train(2017, 1536) val(431, 1536) test(432, 1536)
#
# [A] XGBoost on Whisper 1536-D
#   Val F1=0.9231  Test F1=0.9741  Acc=0.9722  (12.8s)
#
# [B] MLP on Whisper 1536-D  (1536->768->256->n_cls)
#   Ep 10/50  val_F1=0.8349
#   Ep 20/50  val_F1=0.9436
#   Ep 30/50  val_F1=0.9685
#   Ep 40/50  val_F1=0.9633
#   Ep 50/50  val_F1=0.9727
#   Best Val F1=0.9727  Test F1=0.9729  Acc=0.9722  (0.0min)
#
# ...
#   RAVDESS: Hand-crafted vs Whisper Encoder
# ...
# Model                  Features                    Test F1     Acc
# ------------------------------------------------------------
# XGBoost                Hand-crafted 338-D         0.48545834592237364     N/A
# MLP                    Hand-crafted 338-D         0.32992861359259806     N/A
# Whisper+XGBoost        Whisper 1536-D               0.9741  0.9722
# Whisper+MLP            Whisper 1536-D               0.9729  0.9722
# ...
# [DONE] rav_whisper_xgb, rav_whisper_mlp added to RESULTS

# %%
# Cell 1.10c: MODMA Audio — Whisper Experiment (MDD vs HC)
# Scans ALL /kaggle/input for MODMA subject wav files.
# MODMA subject folder names: 02010001, 02020004, etc. (8-digit IDs).

import numpy as np, time, warnings, torch
from pathlib import Path
from sklearn.metrics import f1_score, accuracy_score, classification_report
warnings.filterwarnings('ignore')

print('=' * 65)
print('  CELL 1.10c — MODMA Audio Whisper (MDD vs HC)')
print('=' * 65)

if '_whisper_model_global' not in dir() or '_whisper_module_global' not in dir():
    print('[STOP] whisper model not loaded — Cell 1.10a must run first.')
else:
    _wm  = _whisper_model_global
    _wh  = _whisper_module_global
    _dev = 'cuda' if torch.cuda.is_available() else 'cpu'

    # Load subject splits (with fallback if CSV missing)
    import pandas as _pd
    try:
        _sdf = _pd.read_csv(str(BASE_DATA/'modma_audio'/'modma_audio_subject_splits.csv'))
        _sdf['folder'] = _sdf['subject_id'].apply(lambda x: '0'+str(x))
        print(f'  Subjects: {len(_sdf)}  MDD:{(_sdf.label==1).sum()}  HC:{(_sdf.label==0).sum()}')
    except Exception as _csv_e:
        print(f'  [WARN] modma_audio_subject_splits.csv not found ({_csv_e})')
        print('  [WARN] Will infer labels from folder-name prefix (02010xxx=MDD, 02020xxx=HC)')
        _sdf = None

    # Scan ALL /kaggle/input for MODMA wav files (inside 8-digit subject folders)
    print('  Scanning /kaggle/input for MODMA wavs...')
    _all_modma_wav = {}
    for _wf in Path('/kaggle/input').rglob('*.wav'):
        # MODMA wavs are inside subject dirs — parent name is 8-digit subject folder
        _par = _wf.parent.name
        if _par.isdigit() and len(_par) == 8:
            if _par not in _all_modma_wav:
                _all_modma_wav[_par] = []
            _all_modma_wav[_par].append(_wf)
    print(f'  MODMA subject folders found: {len(_all_modma_wav)}')

    if not _all_modma_wav:
        print('[STOP] No MODMA wav files found in /kaggle/input.')
        print('  Make sure MODMA_AUDIO_GROUP-6_DSAI dataset is added.')
    else:
        _embs, _labels, _splits = [], [], []
        _total_segs = 0
        _t0 = time.time()
        # Build row iterator — use CSV splits if available, else derive from folder name
        if _sdf is not None:
            _rows = [(_row['folder'], int(_row['label']), _row['split'])
                     for _, _row in _sdf.iterrows()]
        else:
            # Infer: 02010xxx -> MDD(1), 02020xxx -> HC(0); assign random 70/15/15 split later
            _rows = []
            for _fld in sorted(_all_modma_wav.keys()):
                _lbl = 1 if _fld.startswith('02010') else (0 if _fld.startswith('02020') else -1)
                if _lbl >= 0:
                    _rows.append((_fld, _lbl, 'all'))
        for _fld, _lbl, _sp in _rows:
            _wavs = sorted(_all_modma_wav.get(_fld, []))
            if not _wavs:
                continue
            _seg_embs = []
            with torch.no_grad():
                for _wf in _wavs:
                    try:
                        _a   = _wh.load_audio(str(_wf))
                        _a   = _wh.pad_or_trim(_a)
                        _mel = _wh.log_mel_spectrogram(_a, n_mels=80).to(_dev)
                        _enc = _wm.encoder(_mel.unsqueeze(0)).squeeze(0)
                        _seg_embs.append(torch.cat([_enc.mean(0),_enc.std(0)]).float().cpu().numpy())
                    except Exception:
                        pass
            if _seg_embs:
                _embs.append(np.mean(_seg_embs, axis=0))
                _labels.append(_lbl)
                _splits.append(_sp)
                _total_segs += len(_seg_embs)
        print(f'  Extracted {len(_embs)} subjects, {_total_segs} segments in {(time.time()-_t0)/60:.1f}min')

        _Xm = np.stack(_embs); _ym = np.array(_labels); _sm = np.array(_splits)
        if 'all' in _sm:  # no CSV splits — use stratified random 70/15/15
            from sklearn.model_selection import train_test_split as _tts2
            _idx = np.arange(len(_ym))
            _i_tv,_i_te = _tts2(_idx,test_size=0.15,random_state=42,stratify=_ym)
            _i_tr,_i_vl = _tts2(_i_tv,test_size=0.176,random_state=42,stratify=_ym[_i_tv])
            _Xm_tr,_ym_tr=_Xm[_i_tr],_ym[_i_tr]
            _Xm_vl,_ym_vl=_Xm[_i_vl],_ym[_i_vl]
            _Xm_te,_ym_te=_Xm[_i_te],_ym[_i_te]
        else:
            _Xm_tr=_Xm[_sm=='train']; _ym_tr=_ym[_sm=='train']
            _Xm_vl=_Xm[_sm=='val'];   _ym_vl=_ym[_sm=='val']
            _Xm_te=_Xm[_sm=='test'];  _ym_te=_ym[_sm=='test']
        _Xm_tv=np.concatenate([_Xm_tr,_Xm_vl]); _ym_tv=np.concatenate([_ym_tr,_ym_vl])
        print(f'  Split: train{_Xm_tr.shape} val{_Xm_vl.shape} test{_Xm_te.shape}')

        # SVM
        from sklearn.svm import SVC
        from sklearn.preprocessing import StandardScaler
        from sklearn.pipeline import Pipeline as _PP
        _svm = _PP([('sc',StandardScaler()),
                    ('sv',SVC(C=10.0,kernel='rbf',probability=True,
                              class_weight='balanced',random_state=42))])
        _svm.fit(_Xm_tv, _ym_tv)
        _p  = _svm.predict(_Xm_te)
        _f1 = f1_score(_ym_te,_p,average='macro')
        _ac = accuracy_score(_ym_te,_p)
        print(f'\n[A] SVM  Test F1={_f1:.4f}  Acc={_ac:.4f}')
        print(classification_report(_ym_te,_p,target_names=['HC','MDD']))
        RESULTS['modma_whisper_svm']={'model':'SVM','feature':'Whisper 1536-D','dataset':'MODMA',
            'test_macro_f1':round(_f1,4),'test_accuracy':round(_ac,4)}

        # XGBoost
        from xgboost import XGBClassifier
        _spw = float((_ym_tv==0).sum())/float(max((_ym_tv==1).sum(),1))
        _xgb = XGBClassifier(n_estimators=200,max_depth=3,learning_rate=0.05,
                              scale_pos_weight=_spw,                              eval_metric='aucpr',tree_method='hist',random_state=42)
        _xgb.fit(_Xm_tv,_ym_tv,verbose=False)
        _p2  = _xgb.predict(_Xm_te)
        _f2  = f1_score(_ym_te,_p2,average='macro')
        _ac2 = accuracy_score(_ym_te,_p2)
        print(f'[B] XGB  Test F1={_f2:.4f}  Acc={_ac2:.4f}')
        RESULTS['modma_whisper_xgb']={'model':'XGBoost','feature':'Whisper 1536-D','dataset':'MODMA',
            'test_macro_f1':round(_f2,4),'test_accuracy':round(_ac2,4)}

        import joblib
        joblib.dump(_svm, str(OUTPUT_DIR/'modma_whisper_svm.pkl'))
        _xgb.save_model(str(OUTPUT_DIR/'modma_whisper_xgb.json'))
        print('  Saved: modma_whisper_svm.pkl, modma_whisper_xgb.json')

        print('\n' + '='*60)
        print('  MODMA: Hand-crafted vs Whisper')
        print('='*60)
        for _k in ['modma_svm_test','modma_xgb_test','modma_whisper_svm','modma_whisper_xgb']:
            _r = RESULTS.get(_k)
            if not _r: continue
            _lab = ('Whisper+' if 'whisper' in _k else 'HC+')+_r.get('model','')
            print(f'  {_lab:<20} F1={_r.get("test_macro_f1","N/A")}  Acc={_r.get("test_accuracy","N/A")}')
        print('[DONE] modma_whisper_svm, modma_whisper_xgb added to RESULTS')
# Out:
# ...
#   CELL 1.10c — MODMA Audio Whisper (MDD vs HC)
# ...
#   Subjects: 52  MDD:23  HC:29
#   Scanning /kaggle/input for MODMA wavs...
#   MODMA subject folders found: 52
#   Extracted 52 subjects, 1503 segments in 6.8min
#   Split: train(36, 1536) val(8, 1536) test(8, 1536)
#
# [A] SVM  Test F1=0.7500  Acc=0.7500
#               precision    recall  f1-score   support
#
#           HC       1.00      0.60      0.75         5
#          MDD       0.60      1.00      0.75         3
#
#     accuracy                           0.75         8
#    macro avg       0.80      0.80      0.75         8
# weighted avg       0.85      0.75      0.75         8
#
# [B] XGB  Test F1=0.6190  Acc=0.6250
#   Saved: modma_whisper_svm.pkl, modma_whisper_xgb.json
#
# ...
#   MODMA: Hand-crafted vs Whisper
# ...
#   Whisper+SVM          F1=0.75  Acc=0.75
#   Whisper+XGBoost      F1=0.619  Acc=0.625
# [DONE] modma_whisper_svm, modma_whisper_xgb added to RESULTS

# %%
# Cell 1.10d: DAIC-WOZ Whisper Extraction — Session-level embeddings
# Scans ALL /kaggle/input for DAIC-WOZ session WAV files (*_AUDIO.wav).
# Chunks each long interview into 30s windows, embeds each, mean-pools -> 1536-D.
# Also saves participant ID arrays per split for Whisper+HC fusion in Cell 1.10f.

import numpy as np, time, warnings, torch
import pandas as _pd
from pathlib import Path
warnings.filterwarnings('ignore')

print('=' * 65)
print('  CELL 1.10d — DAIC-WOZ Whisper Session Embedding Extraction')
print('=' * 65)

if '_whisper_model_global' not in dir() or '_whisper_module_global' not in dir():
    print('[STOP] whisper model not loaded — Cell 1.10a must run first.')
    _daic_emb_ok = False
else:
    _wm  = _whisper_model_global
    _wh  = _whisper_module_global
    _dev = 'cuda' if torch.cuda.is_available() else 'cpu'

    print('  Scanning /kaggle/input for *_AUDIO.wav files...')
    _daic_wavs = {}
    for _wf in Path('/kaggle/input').rglob('*_AUDIO.wav'):
        try:
            _pid = int(_wf.stem.replace('_AUDIO', ''))
            _daic_wavs[_pid] = _wf
        except Exception:
            pass
    print(f'  DAIC-WOZ session WAVs found: {len(_daic_wavs)}')

    if not _daic_wavs:
        print('[STOP] No *_AUDIO.wav files found in /kaggle/input.')
        print('  DAIC-WOZ raw audio is NOT in the preprocessed dataset.')
        print('  Skipping DAIC-WOZ Whisper experiment (Cell 1.10e/f will also skip).')
        _daic_emb_ok = False
    else:
        try:
            _sp = _pd.read_csv(str(BASE_DATA / 'daicwoz' / 'daicwoz_participant_splits.csv'))
        except Exception as _csv2_e:
            print(f'[STOP] daicwoz_participant_splits.csv not found: {_csv2_e}')
            _daic_emb_ok = False
            _sp = None

        if _sp is not None:
            _SR, _CHUNK_S, _MAX_MIN = 16000, 30, 20
            _CHUNK_N, _MAX_N = _CHUNK_S * _SR, _MAX_MIN * 60 * _SR
            _embs, _y_b, _y_s, _splits, _pids = [], [], [], [], []
            _skipped = 0
            _t0 = time.time()
            for _i, (_, _row) in enumerate(_sp.iterrows()):
                _pid = int(_row['Participant_ID'])
                _wf  = _daic_wavs.get(_pid)
                if _wf is None:
                    _skipped += 1; continue
                try:
                    _audio = _wh.load_audio(str(_wf))
                    if len(_audio) > _MAX_N:
                        _audio = _audio[:_MAX_N]
                    _chunks = [_audio[_s:_s + _CHUNK_N]
                               for _s in range(0, len(_audio), _CHUNK_N)
                               if len(_audio[_s:_s + _CHUNK_N]) > _SR]
                    _ce = []
                    with torch.no_grad():
                        for _ch in _chunks:
                            _ch  = _wh.pad_or_trim(_ch)
                            _mel = _wh.log_mel_spectrogram(_ch, n_mels=80).to(_dev)
                            _enc = _wm.encoder(_mel.unsqueeze(0)).squeeze(0)
                            _ce.append(torch.cat([_enc.mean(0), _enc.std(0)]).float().cpu().numpy())
                    if _ce:
                        _embs.append(np.mean(_ce, axis=0))
                        _y_b.append(int(_row['PHQ8_Binary']))
                        _y_s.append(float(_row['PHQ8_Score']))
                        _splits.append(_row['split'])
                        _pids.append(_pid)
                except Exception:
                    _skipped += 1
                if (_i + 1) % 20 == 0:
                    _el = time.time() - _t0
                    print(f'  [{_i+1}/{len(_sp)}] done:{len(_embs)} skipped:{_skipped} {_el/60:.1f}min')

            print(f'  Done: {len(_embs)} sessions, {_skipped} skipped, {(time.time()-_t0)/60:.1f}min')
            _Xd  = np.stack(_embs)
            _yd_b = np.array(_y_b)
            _yd_s = np.array(_y_s)
            _sd   = np.array(_splits)
            _pid_arr = np.array(_pids)

            _Xd_tr  = _Xd[_sd == 'train'];  _yd_tr_b = _yd_b[_sd == 'train']; _yd_tr_s = _yd_s[_sd == 'train']
            _Xd_vl  = _Xd[_sd == 'val'];    _yd_vl_b = _yd_b[_sd == 'val'];   _yd_vl_s = _yd_s[_sd == 'val']
            _Xd_te  = _Xd[_sd == 'test'];   _yd_te_b = _yd_b[_sd == 'test'];  _yd_te_s = _yd_s[_sd == 'test']
            print(f'  Split: train{_Xd_tr.shape} val{_Xd_vl.shape} test{_Xd_te.shape}')

            _ED2 = Path('/kaggle/working')
            # Save embeddings + labels + PID arrays (PIDs needed for fusion in Cell 1.10f)
            for _n, _a in [
                ('daic_wh_Xtr',      _Xd_tr),   ('daic_wh_Xvl',      _Xd_vl),   ('daic_wh_Xte',      _Xd_te),
                ('daic_wh_ytr_b',    _yd_tr_b), ('daic_wh_yvl_b',    _yd_vl_b), ('daic_wh_yte_b',    _yd_te_b),
                ('daic_wh_ytr_s',    _yd_tr_s), ('daic_wh_yvl_s',    _yd_vl_s), ('daic_wh_yte_s',    _yd_te_s),
                ('daic_wh_pids_tr',  _pid_arr[_sd == 'train']),
                ('daic_wh_pids_vl',  _pid_arr[_sd == 'val']),
                ('daic_wh_pids_te',  _pid_arr[_sd == 'test']),
            ]:
                np.save(str(_ED2 / (_n + '.npy')), _a)

            _daic_emb_ok  = True
            _daic_emb_dir = _ED2
            print(f'  Saved to {_ED2}  (embeddings + labels + PID arrays)')
            print('[DONE] DAIC-WOZ Whisper ready for Cell 1.10e and Cell 1.10f')
# Out:
# ...
#   CELL 1.10d — DAIC-WOZ Whisper Session Embedding Extraction
# ...
#   Scanning /kaggle/input for *_AUDIO.wav files...
#   DAIC-WOZ session WAVs found: 185
#   [20/189] done:17 skipped:3 1.2min
#   [40/189] done:37 skipped:3 2.4min
#   [60/189] done:57 skipped:3 4.0min
#   [80/189] done:77 skipped:3 5.5min
#   [100/189] done:97 skipped:3 6.9min
#   [120/189] done:117 skipped:3 8.5min
#   [140/189] done:137 skipped:3 10.1min
#   [160/189] done:156 skipped:4 11.4min
#   [180/189] done:176 skipped:4 13.0min
#   Done: 185 sessions, 4 skipped, 13.8min
#   Split: train(104, 1536) val(35, 1536) test(46, 1536)
#   Saved to /kaggle/working  (embeddings + labels + PID arrays)
# [DONE] DAIC-WOZ Whisper ready for Cell 1.10e and Cell 1.10f

# %%
# Cell 1.10e: DAIC-WOZ Whisper Experiments
# Binary depression + PHQ-8 regression on 1536-D Whisper embeddings.
# IMPROVED: SMOTE oversampling + scale_pos_weight + threshold optimisation
# -> fixes poor sensitivity (was 0.286) on imbalanced depression dataset.

import numpy as np, time
import torch
from pathlib import Path
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, classification_report
from sklearn.metrics import mean_squared_error, mean_absolute_error

print('=' * 65)
print('  CELL 1.10e: DAIC-WOZ Whisper - Classification + Regression (IMPROVED)')
print('=' * 65)

_guard    = '_daic_emb_ok' in dir() and _daic_emb_ok
_ed       = globals().get('_daic_emb_dir',
            Path('/kaggle/working') if Path('/kaggle/working').exists() else Path('/tmp'))
_req_files = ['daic_wh_Xtr.npy', 'daic_wh_Xvl.npy', 'daic_wh_Xte.npy',
              'daic_wh_ytr_b.npy', 'daic_wh_yvl_b.npy', 'daic_wh_yte_b.npy',
              'daic_wh_ytr_s.npy', 'daic_wh_yvl_s.npy', 'daic_wh_yte_s.npy']
_files_ok = all((_ed / f).exists() for f in _req_files)

if not (_guard or _files_ok):
    print('[SKIP] DAIC-WOZ Whisper embeddings not found - run Cell 1.10d first')
else:
    _Xd_tr  = np.load(str(_ed / 'daic_wh_Xtr.npy'))
    _Xd_vl  = np.load(str(_ed / 'daic_wh_Xvl.npy'))
    _Xd_te  = np.load(str(_ed / 'daic_wh_Xte.npy'))
    _yd_tr_b = np.load(str(_ed / 'daic_wh_ytr_b.npy'))
    _yd_vl_b = np.load(str(_ed / 'daic_wh_yvl_b.npy'))
    _yd_te_b = np.load(str(_ed / 'daic_wh_yte_b.npy'))
    _yd_tr_s = np.load(str(_ed / 'daic_wh_ytr_s.npy'))
    _yd_vl_s = np.load(str(_ed / 'daic_wh_yvl_s.npy'))
    _yd_te_s = np.load(str(_ed / 'daic_wh_yte_s.npy'))

    _Xd_tv  = np.concatenate([_Xd_tr, _Xd_vl])
    _yd_tv_b = np.concatenate([_yd_tr_b, _yd_vl_b])
    _yd_tv_s = np.concatenate([_yd_tr_s, _yd_vl_s])
    print(f'  train{_Xd_tr.shape} val{_Xd_vl.shape} test{_Xd_te.shape}')
    print(f'  Depressed in train: {_yd_tr_b.sum()}/{len(_yd_tr_b)}  '
          f'val: {_yd_vl_b.sum()}/{len(_yd_vl_b)}  test: {_yd_te_b.sum()}/{len(_yd_te_b)}')

    _spw = float((_yd_tv_b == 0).sum()) / max((_yd_tv_b == 1).sum(), 1)
    print(f'  Class imbalance ratio (scale_pos_weight): {_spw:.2f}')

    # ── SMOTE on training set to balance classes ──
    try:
        from imblearn.over_sampling import SMOTE as _SMOTE
        _k_nb = min(5, int((_yd_tr_b == 1).sum()) - 1)
        _n_maj_e = int((_yd_tr_b == 0).sum())
        _n_min_e = int((_yd_tr_b == 1).sum())
        _target_e = min(_n_maj_e, int(_n_min_e * 1.5))  # cap at 1.5x
        _sm   = _SMOTE(random_state=42, k_neighbors=max(1, _k_nb),
                       sampling_strategy={1: _target_e})
        _Xd_tr_sm, _yd_tr_sm = _sm.fit_resample(_Xd_tr, _yd_tr_b)
        print(f'  SMOTE: {_Xd_tr.shape} -> {_Xd_tr_sm.shape}  '
              f'depressed: {_yd_tr_b.sum()} -> {(_yd_tr_sm==1).sum()}')
        _smote_ok = True
    except Exception as _sme:
        print(f'  [WARN] SMOTE failed ({_sme}), using original + scale_pos_weight only')
        _Xd_tr_sm, _yd_tr_sm = _Xd_tr, _yd_tr_b
        _smote_ok = False

    # ── A: XGBoost binary (SMOTE + scale_pos_weight + threshold opt) ──
    print('\n[A] XGBoost binary depression (SMOTE + scale_pos_weight + threshold opt)')
    from xgboost import XGBClassifier
    _xgb_b = XGBClassifier(
        n_estimators=400, max_depth=3, learning_rate=0.05,
        scale_pos_weight=_spw, subsample=0.8, colsample_bytree=0.7,
        eval_metric='aucpr', tree_method='hist', random_state=42,
        device='cuda' if torch.cuda.is_available() else 'cpu')
    _xgb_b.fit(_Xd_tr_sm, _yd_tr_sm, verbose=False)

    # Threshold optimisation on validation set
    _val_pr = _xgb_b.predict_proba(_Xd_vl)[:, 1]
    _best_th, _best_vf1 = 0.5, 0.0
    for _th in [round(x * 0.05, 2) for x in range(4, 15)]:
        _vp = (_val_pr >= _th).astype(int)
        _vf = f1_score(_yd_vl_b, _vp, average='macro', zero_division=0)
        if _vf > _best_vf1:
            _best_vf1, _best_th = _vf, _th
    print(f'  Best threshold (val): {_best_th}  val F1={_best_vf1:.4f}')

    _te_pr = _xgb_b.predict_proba(_Xd_te)[:, 1]
    _pred_b = (_te_pr >= _best_th).astype(int)
    _f1_b   = f1_score(_yd_te_b, _pred_b, average='macro')
    _ac_b   = accuracy_score(_yd_te_b, _pred_b)
    _auc_b  = roc_auc_score(_yd_te_b, _te_pr)
    _sens   = float((_pred_b[_yd_te_b == 1] == 1).sum()) / max((_yd_te_b == 1).sum(), 1)
    _spec   = float((_pred_b[_yd_te_b == 0] == 0).sum()) / max((_yd_te_b == 0).sum(), 1)
    print(f'  Test: F1={_f1_b:.4f}  Acc={_ac_b:.4f}  AUC={_auc_b:.4f}')
    print(f'  Sensitivity={_sens:.4f}  Specificity={_spec:.4f}  (was: Sens=0.2857 before fix)')
    print(classification_report(_yd_te_b, _pred_b, target_names=['HC', 'Depressed']))
    RESULTS['daic_whisper_xgb'] = {
        'model': 'XGBoost+SMOTE', 'feature': 'Whisper 1536-D', 'dataset': 'DAIC-WOZ',
        'test_macro_f1': round(_f1_b, 4), 'test_accuracy': round(_ac_b, 4),
        'test_auc': round(_auc_b, 4), 'sensitivity': round(_sens, 4)}

    # ── B: SVM ──
    print('\n[B] SVM binary depression (class_weight balanced)')
    from sklearn.svm import SVC
    from sklearn.preprocessing import StandardScaler as _SS
    from sklearn.pipeline import Pipeline as _PP
    _svm_b = _PP([('sc', _SS()), ('sv', SVC(C=10.0, kernel='rbf', probability=True,
                                             class_weight='balanced', random_state=42))])
    _svm_b.fit(_Xd_tv, _yd_tv_b)
    _sv_pr  = _svm_b.predict_proba(_Xd_te)[:, 1]
    _best_sv_th, _best_sv_f1 = 0.5, 0.0
    _sv_vpr = _svm_b.predict_proba(_Xd_vl)[:, 1]
    for _th in [round(x * 0.05, 2) for x in range(4, 15)]:
        _vf = f1_score(_yd_vl_b, (_sv_vpr >= _th).astype(int), average='macro', zero_division=0)
        if _vf > _best_sv_f1:
            _best_sv_f1, _best_sv_th = _vf, _th
    _sv_pred = (_sv_pr >= _best_sv_th).astype(int)
    _f1_sv   = f1_score(_yd_te_b, _sv_pred, average='macro')
    _ac_sv   = accuracy_score(_yd_te_b, _sv_pred)
    _auc_sv  = roc_auc_score(_yd_te_b, _sv_pr)
    _sens_sv = float((_sv_pred[_yd_te_b == 1] == 1).sum()) / max((_yd_te_b == 1).sum(), 1)
    print(f'  Test: F1={_f1_sv:.4f}  Acc={_ac_sv:.4f}  AUC={_auc_sv:.4f}  Sens={_sens_sv:.4f}')
    RESULTS['daic_whisper_svm'] = {
        'model': 'SVM', 'feature': 'Whisper 1536-D', 'dataset': 'DAIC-WOZ',
        'test_macro_f1': round(_f1_sv, 4), 'test_accuracy': round(_ac_sv, 4),
        'test_auc': round(_auc_sv, 4)}

    # ── C: PHQ-8 Regression ──
    print('\n[C] XGBoost PHQ-8 Severity Regression')
    from xgboost import XGBRegressor
    _xgb_r = XGBRegressor(n_estimators=300, max_depth=3, learning_rate=0.05,
                           tree_method='hist', random_state=42,
                           device='cuda' if torch.cuda.is_available() else 'cpu')
    _xgb_r.fit(_Xd_tv, _yd_tv_s, verbose=False)
    _pred_s  = _xgb_r.predict(_Xd_te)
    _rmse_s  = float(np.sqrt(mean_squared_error(_yd_te_s, _pred_s)))
    _mae_s   = float(mean_absolute_error(_yd_te_s, _pred_s))
    _band_s  = float(np.mean(np.abs(_pred_s - _yd_te_s) <= 5)) * 100
    print(f'  RMSE={_rmse_s:.4f}  MAE={_mae_s:.4f}  Within-1-Band={_band_s:.1f}%')
    RESULTS['daic_whisper_phq8_reg'] = {
        'model': 'XGBoost Reg', 'feature': 'Whisper 1536-D', 'dataset': 'DAIC-WOZ',
        'test_rmse': round(_rmse_s, 4), 'within_band': round(_band_s, 1)}

    # ── Summary ──
    print('\n' + '=' * 65)
    print('  DAIC-WOZ Whisper vs Hand-crafted Baseline')
    print('=' * 65)
    _rows = [
        ('HC 2231-D fusion (best)',  'daic_fusion_thresh_opt'),
        ('Whisper 1536-D XGB+SMOTE', 'daic_whisper_xgb'),
        ('Whisper 1536-D SVM',       'daic_whisper_svm'),
    ]
    for _nm, _k in _rows:
        _r = RESULTS.get(_k, {})
        _f = _r.get('test_macro_f1', 'N/A')
        _u = _r.get('test_auc', 'N/A')
        _s = _r.get('sensitivity', 'N/A')
        print(f'  {_nm:<35} F1={str(_f):>6}  AUC={str(_u):>6}  Sens={str(_s):>6}')
    print(f'  PHQ-8 Regression: RMSE={_rmse_s:.4f}  Within-Band={_band_s:.1f}%')
    print('[DONE] Cell 1.10e complete.')
# Out:
# ...
#   CELL 1.10e: DAIC-WOZ Whisper - Classification + Regression (IMPROVED)
# ...
#   train(104, 1536) val(35, 1536) test(46, 1536)
#   Depressed in train: 28/104  val: 12/35  test: 14/46
#   Class imbalance ratio (scale_pos_weight): 2.48
#   SMOTE: (104, 1536) -> (118, 1536)  depressed: 28 -> 42
#
# [A] XGBoost binary depression (SMOTE + scale_pos_weight + threshold opt)
#   Best threshold (val): 0.5  val F1=0.6686
#   Test: F1=0.4926  Acc=0.6087  AUC=0.4665
#   Sensitivity=0.2143  Specificity=0.7812  (was: Sens=0.2857 before fix)
#               precision    recall  f1-score   support
#
#           HC       0.69      0.78      0.74        32
#    Depressed       0.30      0.21      0.25        14
#
#     accuracy                           0.61        46
#    macro avg       0.50      0.50      0.49        46
# weighted avg       0.57      0.61      0.59        46
#
#
# [B] SVM binary depression (class_weight balanced)
#   Test: F1=0.4773  Acc=0.4783  AUC=0.6094  Sens=0.8571
#
# ...

# %% [markdown]
# ---
# # Section 2 — DAIC-WOZ: Depression Detection & MODMA Audio: MDD vs HC
#
# **DAIC-WOZ** (N=189 sessions, train=107):
# - Binary classification: Depressed (PHQ-8 ≥ 10) vs Healthy
# - PHQ-8 severity regression (0–20)
# - 448 features across 3 modality branches: acoustic (323) | linguistic (14) | visual (111)
# - Severely imbalanced: 77 healthy / 30 depressed (pos_weight ≈ 2.567)
# - M3 baseline: acoustic XGB Macro-F1=0.6023; fusion stacking F1=0.38 (failed)
#
# **MODMA** (N=52 subjects, 36/8/8 split):
# - Binary MDD vs HC; 1002 features; extremely small dataset
# - Strategy: StratifiedKFold CV on combined train+val (44 samples)
#
# **Experiments:**
# 2.2 Acoustic branch hyperparameter tuning (CV)
# 2.3 Linguistic + visual branch tuning
# 2.4 Fix fusion — MLP meta-learner
# 2.5 PHQ-8 regression loss comparison
# 2.6 MODMA feature selection + SVM + XGBoost

# %%
# ── Cell 2.0: DAIC-WOZ Runtime Full Feature Extraction ──
# Extracts ~2200 features from all raw session files at runtime.
# Runs in ~25-35 min (CPU). Subsequent runs skip extraction if .npy files already exist.
# Features: COVAREP(666) + 3D-landmarks(413) + AUs(168) + gaze(132) + pose(90)
#           + FORMANT(60) + TRANSCRIPT(22) + AUDIO/MFCC(71) + original(448) = ~2200 total

import time, pickle, warnings
warnings.filterwarnings('ignore')
import numpy as np, pandas as pd
from scipy.stats import skew as _skew, kurtosis as _kurt
from sklearn.preprocessing import RobustScaler

_SESS   = BASE_DATA / "daicwoz" / "extracted_sessions"
_SP     = pd.read_csv(BASE_DATA / "daicwoz" / "daicwoz_participant_splits.csv")
# On Kaggle /kaggle/input is read-only — write enriched arrays to /kaggle/working
_OUT    = Path("/kaggle/working/processed_data/daicwoz") if ENV == "kaggle" else BASE_DATA / "daicwoz"
_OUT.mkdir(parents=True, exist_ok=True)
_ENR_TR = _OUT / "daicwoz_X_full_enriched_train.npy"

if _ENR_TR.exists() and _ENR_TR.stat().st_size > 0:
    print("Loading cached enriched features...")
    X_enr_train       = np.load(_OUT / "daicwoz_X_full_enriched_train.npy")
    X_enr_val         = np.load(_OUT / "daicwoz_X_full_enriched_val.npy")
    X_enr_test        = np.load(_OUT / "daicwoz_X_full_enriched_test.npy")
    y_enr_train_bin   = np.load(_OUT / "daicwoz_y_full_enriched_train_bin.npy")
    y_enr_val_bin     = np.load(_OUT / "daicwoz_y_full_enriched_val_bin.npy")
    y_enr_test_bin    = np.load(_OUT / "daicwoz_y_full_enriched_test_bin.npy")
    y_enr_train_score = np.load(_OUT / "daicwoz_y_full_enriched_train_score.npy")
    y_enr_val_score   = np.load(_OUT / "daicwoz_y_full_enriched_val_score.npy")
    y_enr_test_score  = np.load(_OUT / "daicwoz_y_full_enriched_test_score.npy")
    ENRICHMENT_DONE = True
    print(f"  train={X_enr_train.shape} | val={X_enr_val.shape} | test={X_enr_test.shape}")
    print(f"  {X_enr_train.shape[1]} total features")
else:
    _P = [10,25,75,90]

    def _vstats(arr2d, pfs):
        out = {}
        a = arr2d.astype(float); a[~np.isfinite(a)] = np.nan
        nv = (~np.isnan(a)).sum(axis=0)
        with warnings.catch_warnings():
            warnings.simplefilter('ignore')
            mn=np.nanmean(a,axis=0); sd=np.nanstd(a,axis=0)
            mi=np.nanmin(a,axis=0);  mx=np.nanmax(a,axis=0)
            pct={p:np.nanpercentile(a,p,axis=0) for p in _P}
            sk=_skew(a,axis=0,nan_policy='omit')
            ku=_kurt(a,axis=0,nan_policy='omit')
        for j,pf in enumerate(pfs):
            if nv[j]<5: continue
            out[f'{pf}_mean']=float(mn[j]); out[f'{pf}_std']=float(sd[j])
            out[f'{pf}_min']=float(mi[j]);  out[f'{pf}_max']=float(mx[j])
            for p in _P: out[f'{pf}_p{p}']=float(pct[p][j])
            out[f'{pf}_iqr']=float(pct[75][j]-pct[25][j])
            out[f'{pf}_skew']=float(sk[j]) if np.isfinite(sk[j]) else 0.0
            out[f'{pf}_kurt']=float(ku[j]) if np.isfinite(ku[j]) else 0.0
        return out

    def _vel(arr2d, pfs):
        a = arr2d.astype(float); a[~np.isfinite(a)] = np.nan
        vl = np.nanmean(np.abs(np.diff(a,axis=0)),axis=0)
        return {f'{pf}_vel': float(vl[j]) if np.isfinite(vl[j]) else 0.0
                for j,pf in enumerate(pfs)}

    _DW = {'sad','hopeless','worthless','empty','tired','exhausted','sleep','die','dying','dead',
           'lonely','awful','terrible','nothing','nobody','useless','fail','failed','guilty','shame',
           'cry','crying','hurt','pain','dark','heavy','stuck','lost','alone','miss','missing',
           'depressed','depression','anxiety','anxious','nervous','worry','worried','bad','worse'}
    _PW = {'happy','good','great','fine','okay','nice','enjoy','fun','better','hope',
           'love','positive','wonderful','excited','grateful','amazing'}
    _HW = {'maybe','perhaps','probably','might','could','guess','think','feel','sort','kind','like'}

    def _extract(pid, sd):
        feats = {}; s = str(pid)

        # COVAREP (74 cols x 11 stats + vel = up to 666 features)
        p = sd/f'{s}_COVAREP.csv'
        if p.exists():
            try:
                a = pd.read_csv(p,header=None,dtype=np.float32).values.astype(float)
                a[a==0]=np.nan
                pfs=[f'full_cov_{j}' for j in range(a.shape[1])]
                feats.update(_vstats(a,pfs)); feats.update(_vel(a,pfs))
            except: pass

        # CLNF_features3D (68 landmarks x 3D = 204 cols -> mean/std + 5 global movement)
        p = sd/f'{s}_CLNF_features3D.txt'
        if p.exists():
            try:
                c = pd.read_csv(p); c.columns=[x.strip() for x in c.columns]
                v = c[c['confidence']>0.5] if 'confidence' in c.columns else c
                dc=[col for col in v.columns if col not in {'frame','timestamp','confidence','success'}]
                if len(v)>20:
                    a3=v[dc].values.astype(float); a3[~np.isfinite(a3)]=np.nan
                    mn=np.nanmean(a3,axis=0); sd2=np.nanstd(a3,axis=0)
                    for j in range(len(dc)):
                        feats[f'full_lmk3d_{j}_mean']=float(mn[j]) if np.isfinite(mn[j]) else 0.0
                        feats[f'full_lmk3d_{j}_std'] =float(sd2[j])if np.isfinite(sd2[j])else 0.0
                    disp=np.sqrt(np.nansum(np.diff(a3,axis=0)**2,axis=1))
                    for n2,v2 in [('mean',np.nanmean(disp)),('std',np.nanstd(disp)),
                                  ('p25',np.nanpercentile(disp,25)),('p75',np.nanpercentile(disp,75)),
                                  ('max',np.nanmax(disp))]:
                        feats[f'full_face_mv_{n2}']=float(v2) if np.isfinite(v2) else 0.0
            except: pass

        # CLNF_AUs
        p = sd/f'{s}_CLNF_AUs.txt'
        if p.exists():
            try:
                au=pd.read_csv(p); au.columns=[c.strip() for c in au.columns]
                vl=au[au['confidence']>0.5] if 'confidence' in au.columns else au
                ar=[c for c in vl.columns if c.startswith('AU') and c.endswith('_r')]
                ac=[c for c in vl.columns if c.startswith('AU') and c.endswith('_c')]
                if len(vl)>20:
                    ar2=vl[ar].values.astype(float)
                    pf_r=[f'full_au_r_{c}' for c in ar]
                    feats.update(_vstats(ar2,pf_r)); feats.update(_vel(ar2,pf_r))
                    for j,col in enumerate(ar):
                        cv=ar2[:,j]; cv=cv[np.isfinite(cv)]
                        if len(cv)>5:
                            sl,_=np.polyfit(np.arange(len(cv)),cv,1)
                            feats[f'full_au_r_{col}_trend']=float(sl)
                    ac2=vl[ac].values.astype(float)
                    for j,col in enumerate(ac):
                        feats[f'full_au_c_{col}_rate']=float(np.mean(ac2[:,j]>0.5))
                    gv=np.nanmean(np.abs(np.diff(ar2,axis=0)),axis=0)
                    feats['full_au_gvel_mean']=float(np.mean(gv))
                    feats['full_au_gvel_std'] =float(np.std(gv))
            except: pass

        # CLNF_pose
        p = sd/f'{s}_CLNF_pose.txt'
        if p.exists():
            try:
                ps=pd.read_csv(p); ps.columns=[c.strip() for c in ps.columns]
                v=ps[ps['confidence']>0.5] if 'confidence' in ps.columns else ps
                pc=[c for c in ['Tx','Ty','Tz','Rx','Ry','Rz'] if c in v.columns]
                if len(v)>20:
                    a2=v[pc].values.astype(float); pf2=[f'full_pose_{c}' for c in pc]
                    feats.update(_vstats(a2,pf2)); feats.update(_vel(a2,pf2))
            except: pass

        # CLNF_gaze
        p = sd/f'{s}_CLNF_gaze.txt'
        if p.exists():
            try:
                gz=pd.read_csv(p); gz.columns=[c.strip() for c in gz.columns]
                v=gz[gz['confidence']>0.5] if 'confidence' in gz.columns else gz
                gc=[c for c in v.columns if c not in {'frame','timestamp','confidence','success'}][:12]
                if len(v)>20:
                    a2=v[gc].values.astype(float); pf2=[f'full_gaze_{c}' for c in gc]
                    feats.update(_vstats(a2,pf2)); feats.update(_vel(a2,pf2))
            except: pass

        # FORMANT
        p = sd/f'{s}_FORMANT.csv'
        if p.exists():
            try:
                fm=pd.read_csv(p,header=None,dtype=np.float32).values.astype(float)
                fm[fm==0]=np.nan; nf=min(5,fm.shape[1])
                pf2=[f'full_F{j+1}' for j in range(nf)]
                feats.update(_vstats(fm[:,:nf],pf2)); feats.update(_vel(fm[:,:nf],pf2))
                for j in range(nf):
                    col=fm[:,j]; col=col[np.isfinite(col)]
                    if len(col)>10:
                        feats[f'full_F{j+1}_rng95']=float(np.percentile(col,95)-np.percentile(col,5))
            except: pass

        # TRANSCRIPT
        p = sd/f'{s}_TRANSCRIPT.csv'
        if p.exists():
            try:
                tr=pd.read_csv(p,sep='\t')
                pt=tr[tr['speaker']=='Participant'].copy()
                if len(pt)>0:
                    pt['dur']=(pt['stop_time']-pt['start_time']).clip(lower=0)
                    pt['wc']=pt['value'].fillna('').apply(lambda x:len(str(x).split()))
                    txt=' '.join(pt['value'].fillna('').str.lower().tolist()).split()
                    tw=max(len(txt),1); td=pt['dur'].sum()
                    feats['full_nlp_n_turns']=int(len(pt))
                    feats['full_nlp_total_dur']=float(td)
                    feats['full_nlp_dur_std']=float(pt['dur'].std() or 0)
                    feats['full_nlp_words_std']=float(pt['wc'].std() or 0)
                    feats['full_nlp_max_resp']=float(pt['wc'].max())
                    feats['full_nlp_pct_short']=float((pt['wc']<=3).mean())
                    feats['full_nlp_pct_long']=float((pt['wc']>=20).mean())
                    feats['full_nlp_depr_kw']=sum(1 for w in txt if w in _DW)/tw
                    feats['full_nlp_pos_kw']=sum(1 for w in txt if w in _PW)/tw
                    feats['full_nlp_hedge']=sum(1 for w in txt if w in _HW)/tw
                    feats['full_nlp_neg_pos']=feats['full_nlp_depr_kw']/(feats['full_nlp_pos_kw']+1e-9)
                    ic=sum(1 for w in txt if w in {'i','me','my','myself','mine'})
                    wc=sum(1 for w in txt if w in {'we','us','our','you','your'})
                    feats['full_nlp_i_dens']=ic/tw; feats['full_nlp_soc_dens']=wc/tw
                    feats['full_nlp_i_soc']=ic/max(wc,1)
                    feats['full_nlp_ttr']=len(set(txt))/tw
                    feats['full_nlp_wps']=float(tw/max(td,1e-9))
                    if len(pt)>1:
                        sp2=pt.sort_values('start_time')
                        gaps=sp2['start_time'].values[1:]-sp2['stop_time'].values[:-1]
                        gaps=gaps[gaps>0.1]
                        if len(gaps):
                            feats['full_nlp_pause_mean']=float(np.mean(gaps))
                            feats['full_nlp_pause_med']=float(np.median(gaps))
                            feats['full_nlp_pause_max']=float(gaps.max())
                            feats['full_nlp_long_pause']=float((gaps>2.0).mean())
                            feats['full_nlp_pause_ratio']=float(gaps.sum()/max(td,1e-9))
            except: pass

        # AUDIO.wav (soundfile fast load + librosa features)
        p = sd/f'{s}_AUDIO.wav'
        if p.exists():
            try:
                import soundfile as _sf, librosa as _lb
                ya,sra=_sf.read(str(p),frames=16000*120,dtype='float32',always_2d=False)
                if ya.ndim>1: ya=ya.mean(axis=1)
                if sra!=16000:
                    from scipy.signal import resample as _rs
                    ya=_rs(ya,int(len(ya)*16000/sra)).astype(np.float32); sra=16000
                mf=_lb.feature.mfcc(y=ya,sr=sra,n_mfcc=13)
                dm=_lb.feature.delta(mf)
                for i in range(13):
                    feats[f'full_mfcc_{i}_mn']=float(np.mean(mf[i]))
                    feats[f'full_mfcc_{i}_sd']=float(np.std(mf[i]))
                    feats[f'full_mfcc_{i}_sk']=float(_skew(mf[i]))
                    feats[f'full_dm_{i}_mn']=float(np.mean(dm[i]))
                    feats[f'full_dm_{i}_sd']=float(np.std(dm[i]))
                sc2=_lb.feature.spectral_centroid(y=ya,sr=sra)[0]
                rms=_lb.feature.rms(y=ya)[0]
                feats['full_sc_mean']=float(np.mean(sc2)); feats['full_sc_std']=float(np.std(sc2))
                feats['full_sr_mean']=float(np.mean(_lb.feature.spectral_rolloff(y=ya,sr=sra)[0]))
                feats['full_sb_mean']=float(np.mean(_lb.feature.spectral_bandwidth(y=ya,sr=sra)[0]))
                feats['full_zcr_mean']=float(np.mean(_lb.feature.zero_crossing_rate(ya)[0]))
                feats['full_rms_mean']=float(np.mean(rms)); feats['full_rms_std']=float(np.std(rms))
                ivs=_lb.effects.split(ya,top_db=30)
                feats['full_spk_ratio']=float(sum(e-s for s,e in ivs)/sra/max(len(ya)/sra,1))
                ch=_lb.feature.chroma_stft(y=ya,sr=sra)
                for i in range(12):
                    feats[f'full_ch_{i}_mn']=float(np.mean(ch[i]))
                    feats[f'full_ch_{i}_sd']=float(np.std(ch[i]))
            except: pass

        return feats

    # ── Run extraction ──────────────────────────────────────────────────
    n_cov = len(list(_SESS.glob('*_COVAREP.csv')))   if _SESS.exists() else 0
    n_3d  = len(list(_SESS.glob('*_CLNF_features3D.txt'))) if _SESS.exists() else 0
    n_au  = len(list(_SESS.glob('*_CLNF_AUs.txt')))  if _SESS.exists() else 0
    n_wav = len(list(_SESS.glob('*_AUDIO.wav')))     if _SESS.exists() else 0
    n_tr  = len(list(_SESS.glob('*_TRANSCRIPT.csv')))if _SESS.exists() else 0
    print(f"Session files — COVAREP:{n_cov} 3D-lmk:{n_3d} AUs:{n_au} WAV:{n_wav} Transcript:{n_tr}")

    if not _SESS.exists() or n_tr == 0:
        print("No session files found. Using original 448-feature matrix.")
        ENRICHMENT_DONE = False
    else:
        N = len(_SP)
        print(f"Extracting features from {N} sessions (~25-35 min)...")
        t0a = time.time(); rows=[]; pids=[]
        for i,(_,row) in enumerate(_SP.iterrows()):
            pid=int(row['Participant_ID'])
            rows.append(_extract(pid,_SESS)); pids.append(pid)
            if (i+1)%20==0 or i==0:
                el=time.time()-t0a; eta=el/(i+1)*(N-i-1)
                print(f"  [{i+1:3d}/{N}] PID {pid} | {len(rows[-1])} feats | "
                      f"elapsed={el/60:.1f}m ETA={eta/60:.0f}m")

        print(f"\nExtraction done in {(time.time()-t0a)/60:.1f} min")

        ndf = pd.DataFrame(rows,index=pids).fillna(0.0)
        ndf = ndf[ndf.columns[ndf.abs().sum()>0]]

        odf = pd.read_csv(BASE_DATA/"daicwoz"/"daicwoz_features.csv")
        if 'Participant_ID' in odf.columns: odf=odf.set_index('Participant_ID')
        odf = odf.drop(columns=[c for c in ['split','PHQ8_Binary','PHQ8_Score','Gender'] if c in odf.columns])
        odf = odf.select_dtypes(include=[np.number])

        common=[p for p in pids if p in odf.index]
        merged=pd.concat([odf.loc[common], ndf.loc[common]], axis=1)
        print(f"Features: orig={odf.shape[1]} + new={ndf.shape[1]} = total={merged.shape[1]}")

        cats={}
        for c in ndf.columns:
            cat=c.split('_')[1] if c.startswith('full_') else 'orig'
            cats[cat]=cats.get(cat,0)+1
        print("New feature categories: "+" | ".join(f"{k}:{v}" for k,v in sorted(cats.items(),key=lambda x:-x[1])[:8]))

        si=_SP.set_index('Participant_ID')
        X=np.nan_to_num(merged.values.astype(np.float64),nan=0.0,posinf=0.0,neginf=0.0).astype(np.float32)
        mtr=np.array([si.loc[p,'split']=='train' for p in common])
        mvl=np.array([si.loc[p,'split']=='val'   for p in common])
        mte=np.array([si.loc[p,'split']=='test'  for p in common])

        sc2=RobustScaler()
        X_enr_train=np.clip(sc2.fit_transform(X[mtr]),-10,10).astype(np.float32)
        X_enr_val  =np.clip(sc2.transform(X[mvl]),    -10,10).astype(np.float32)
        X_enr_test =np.clip(sc2.transform(X[mte]),    -10,10).astype(np.float32)

        ptr=[p for p,m in zip(common,mtr) if m]
        pvl=[p for p,m in zip(common,mvl) if m]
        pte=[p for p,m in zip(common,mte) if m]
        y_enr_train_bin  =si.loc[ptr,'PHQ8_Binary'].values
        y_enr_val_bin    =si.loc[pvl,'PHQ8_Binary'].values
        y_enr_test_bin   =si.loc[pte,'PHQ8_Binary'].values
        y_enr_train_score=si.loc[ptr,'PHQ8_Score'].values
        y_enr_val_score  =si.loc[pvl,'PHQ8_Score'].values
        y_enr_test_score =si.loc[pte,'PHQ8_Score'].values

        print(f"\nSplits — train:{X_enr_train.shape} val:{X_enr_val.shape} test:{X_enr_test.shape}")
        print(f"Depressed in train: {y_enr_train_bin.sum()}/{len(y_enr_train_bin)}")

        # Save
        for name,arr in [
            ("daicwoz_X_full_enriched_train.npy",X_enr_train),
            ("daicwoz_X_full_enriched_val.npy",  X_enr_val),
            ("daicwoz_X_full_enriched_test.npy",  X_enr_test),
            ("daicwoz_y_full_enriched_train_bin.npy",  y_enr_train_bin),
            ("daicwoz_y_full_enriched_val_bin.npy",    y_enr_val_bin),
            ("daicwoz_y_full_enriched_test_bin.npy",   y_enr_test_bin),
            ("daicwoz_y_full_enriched_train_score.npy",y_enr_train_score),
            ("daicwoz_y_full_enriched_val_score.npy",  y_enr_val_score),
            ("daicwoz_y_full_enriched_test_score.npy", y_enr_test_score),
        ]:
            np.save(_OUT/name, arr)
        with open(_OUT/"daicwoz_feature_cols_full.txt","w") as fh:
            for c in list(merged.columns): fh.write(c+"\n")
        with open(_OUT/"daicwoz_scaler_full.pkl","wb") as fh: pickle.dump(sc2,fh)

        sz=sum((_OUT/f"daicwoz_X_full_enriched_{s}.npy").stat().st_size
               for s in ["train","val","test"] if (_OUT/f"daicwoz_X_full_enriched_{s}.npy").exists())/1e6
        print(f"\nSaved enriched arrays ({sz:.1f} MB)")

        ENRICHMENT_DONE = True
        print("\nReady: X_enr_train/val/test | y_enr_*_bin | y_enr_*_score")

        # Free disk: delete large raw files after extraction
        _LARGE_SFX = ('_COVAREP.csv','_CLNF_features3D.txt','_AUDIO.wav',
                      '_CLNF_features.txt','_CLNF_hog.txt')
        freed=0
        # Skip deletion if sessions are inside /kaggle/input (read-only filesystem)
        _sess_writable = _SESS.exists() and not str(_SESS).startswith('/kaggle/input')
        if _sess_writable:
            try:
                for fp in list(_SESS.iterdir()):
                    if any(fp.name.endswith(s) for s in _LARGE_SFX):
                        freed+=fp.stat().st_size; fp.unlink()
                print(f"Freed {freed/1e9:.1f} GB (large raw session files deleted).")
            except OSError as _e:
                print(f"Could not delete session files: {_e}")
        else:
            print("Session files in read-only /kaggle/input — skipping deletion (no disk freed).")
# Out:
# Session files — COVAREP:185 3D-lmk:185 AUs:185 WAV:185 Transcript:186
# Extracting features from 189 sessions (~25-35 min)...
#   [  1/189] PID 303 | 1813 feats | elapsed=0.3m ETA=51m
#   [ 20/189] PID 330 | 1835 feats | elapsed=1.5m ETA=13m
#   [ 40/189] PID 360 | 1802 feats | elapsed=2.8m ETA=10m
#   [ 60/189] PID 393 | 1835 feats | elapsed=4.7m ETA=10m
#   [ 80/189] PID 437 | 1835 feats | elapsed=6.2m ETA=8m
#   [100/189] PID 475 | 1835 feats | elapsed=7.8m ETA=7m
#   [120/189] PID 395 | 1813 feats | elapsed=10.0m ETA=6m
#   [140/189] PID 489 | 1835 feats | elapsed=11.7m ETA=4m
#   [160/189] PID 373 | 1835 feats | elapsed=13.3m ETA=2m
#   [180/189] PID 453 | 1835 feats | elapsed=15.1m ETA=1m
#
# Extraction done in 15.9 min
# Features: orig=448 + new=1783 = total=2231
# New feature categories: cov:823 | lmk3d:408 | au:148 | gaze:144 | pose:72 | mfcc:39 | dm:26 | ch:24
#
# Splits — train:(107, 2231) val:(35, 2231) test:(47, 2231)
# Depressed in train: 30/107
#
# ...

# %%
# ── Cell 2.1: Load DAIC-WOZ + Feature Branch Slicing ──
X_daic_train = np.load(DAIC_DIR / "daicwoz_X_train.npy")
X_daic_val   = np.load(DAIC_DIR / "daicwoz_X_val.npy")
X_daic_test  = np.load(DAIC_DIR / "daicwoz_X_test.npy")

y_daic_train_bin   = np.load(DAIC_DIR / "daicwoz_y_train_bin.npy")
y_daic_val_bin     = np.load(DAIC_DIR / "daicwoz_y_val_bin.npy")
y_daic_test_bin    = np.load(DAIC_DIR / "daicwoz_y_test_bin.npy")
y_daic_train_score = np.load(DAIC_DIR / "daicwoz_y_train_score.npy")
y_daic_val_score   = np.load(DAIC_DIR / "daicwoz_y_val_score.npy")
y_daic_test_score  = np.load(DAIC_DIR / "daicwoz_y_test_score.npy")

with open(DAIC_DIR / "daicwoz_feature_cols.txt") as f:
    daic_cols = [line.strip() for line in f if line.strip()]

# Feature branch index slicing
acoustic_idx  = [i for i, c in enumerate(daic_cols)
                 if c.startswith(("covarep_", "formant_"))]
linguistic_idx = [i for i, c in enumerate(daic_cols)
                  if c.startswith("nlp_")]
visual_idx    = [i for i, c in enumerate(daic_cols)
                 if c.startswith(("au_", "pose_", "gaze_"))]

print("DAIC-WOZ loaded:")
print(f"  X_train: {X_daic_train.shape}  X_val: {X_daic_val.shape}  X_test: {X_daic_test.shape}")
print(f"  Total features: {len(daic_cols)}")
print(f"  Acoustic  branch: {len(acoustic_idx)} features")
print(f"  Linguistic branch: {len(linguistic_idx)} features")
print(f"  Visual    branch: {len(visual_idx)} features")
print(f"  Sum check: {len(acoustic_idx)+len(linguistic_idx)+len(visual_idx)} (should be ~{len(daic_cols)})")

# Class distributions
for split, y in [("train", y_daic_train_bin), ("val", y_daic_val_bin), ("test", y_daic_test_bin)]:
    vals, cnts = np.unique(y, return_counts=True)
    print(f"  {split}: " + "  ".join([f"class {int(v)}={c}" for v,c in zip(vals,cnts)]))

# Class imbalance weight
POS_WEIGHT = (y_daic_train_bin == 0).sum() / (y_daic_train_bin == 1).sum()
print(f"\npos_weight for imbalance: {POS_WEIGHT:.3f}")

# ── Wire enriched features if Cell 2.0 extraction ran ──────────────────────
if globals().get('ENRICHMENT_DONE', False):
    # Guard: _OUT may be undefined after kernel restart even if ENRICHMENT_DONE=True
    if '_OUT' not in dir() or _OUT is None:
        from pathlib import Path as _Path
        _OUT = _Path("/kaggle/working/processed_data/daicwoz") if ENV == "kaggle" else (BASE_DATA / "daicwoz")
        print(f"[guard] _OUT restored to: {_OUT}")
    with open(_OUT / 'daicwoz_feature_cols_full.txt') as _ff:
        _enr_cols = [l.strip() for l in _ff if l.strip()]
    _ac_pfx  = ('covarep_','formant_','full_cov_','full_F1','full_F2','full_F3',
               'full_F4','full_F5','full_mfcc_','full_dm_','full_sc_',
               'full_sr_','full_sb_','full_zcr_','full_rms_','full_spk_','full_ch_')
    _li_pfx  = ('nlp_', 'full_nlp_')
    _vi_pfx  = ('au_','pose_','gaze_','full_au_','full_pose_',
               'full_gaze_','full_lmk3d_','full_face_mv_')
    acoustic_idx   = [i for i,c in enumerate(_enr_cols) if any(c.startswith(p) for p in _ac_pfx)]
    linguistic_idx = [i for i,c in enumerate(_enr_cols) if any(c.startswith(p) for p in _li_pfx)]
    visual_idx     = [i for i,c in enumerate(_enr_cols) if any(c.startswith(p) for p in _vi_pfx)]
    # Override standard arrays with enriched ones
    X_daic_train, X_daic_val, X_daic_test = X_enr_train, X_enr_val, X_enr_test
    y_daic_train_bin, y_daic_val_bin, y_daic_test_bin = y_enr_train_bin, y_enr_val_bin, y_enr_test_bin
    y_daic_train_score, y_daic_val_score, y_daic_test_score = y_enr_train_score, y_enr_val_score, y_enr_test_score
    POS_WEIGHT = (y_daic_train_bin == 0).sum() / max((y_daic_train_bin == 1).sum(), 1)
    print(f'\nEnriched mode: {X_daic_train.shape[1]} features')
    print(f'  Acoustic  branch: {len(acoustic_idx)}')
    print(f'  Linguistic branch: {len(linguistic_idx)}')
    print(f'  Visual    branch: {len(visual_idx)}')
    print(f'  Unassigned: {X_daic_train.shape[1] - len(acoustic_idx) - len(linguistic_idx) - len(visual_idx)}')
    print(f'  pos_weight: {POS_WEIGHT:.3f}')
else:
    print('\nUsing original 448 features (enrichment not available).')

# Convenience branch arrays (always recomputed after potential override)
Xac_tr = X_daic_train[:, acoustic_idx];   Xac_vl = X_daic_val[:, acoustic_idx];   Xac_te = X_daic_test[:, acoustic_idx]
Xli_tr = X_daic_train[:, linguistic_idx]; Xli_vl = X_daic_val[:, linguistic_idx]; Xli_te = X_daic_test[:, linguistic_idx]
Xvi_tr = X_daic_train[:, visual_idx];     Xvi_vl = X_daic_val[:, visual_idx];     Xvi_te = X_daic_test[:, visual_idx]
print(f'Branch shapes — Acoustic:{Xac_tr.shape}  Linguistic:{Xli_tr.shape}  Visual:{Xvi_tr.shape}')
# Out:
# DAIC-WOZ loaded:
#   X_train: (107, 448)  X_val: (35, 448)  X_test: (47, 448)
#   Total features: 448
#   Acoustic  branch: 323 features
#   Linguistic branch: 14 features
#   Visual    branch: 111 features
#   Sum check: 448 (should be ~448)
#   train: class 0=77  class 1=30
#   val: class 0=23  class 1=12
#   test: class 0=33  class 1=14
#
# pos_weight for imbalance: 2.567
#
# Enriched mode: 2231 features
#   Acoustic  branch: 1308
#   Linguistic branch: 35
#   Visual    branch: 888
#   Unassigned: 0
#   pos_weight: 2.567
# Branch shapes — Acoustic:(107, 1308)  Linguistic:(107, 35)  Visual:(107, 888)

# %%
# Cell 1.10f: DAIC-WOZ — Whisper + Hand-crafted Feature Fusion
# Concatenates Whisper 1536-D + enriched HC 2231-D = 3767-D features
# aligned by Participant_ID.  Trains XGBoost + MLP on fused space.
# Expected: +5-10% F1 over either feature set alone.
# PREREQUISITES: Cell 1.10d (Whisper embeddings + PIDs saved) + Cell 2.0 (HC features saved)

import numpy as np, time, copy
import torch, torch.nn as _nn
import torch.nn.functional as _F
import pandas as _pd_f
from pathlib import Path
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, classification_report
from sklearn.preprocessing import StandardScaler as _SS_f

print('=' * 65)
print('  CELL 1.10f — DAIC-WOZ Whisper + Hand-crafted Fusion')
print('=' * 65)

_ed_f  = globals().get('_daic_emb_dir', Path('/kaggle/working'))
_out_f = Path('/kaggle/working') if Path('/kaggle/working').exists() else Path('/tmp')

# Check Whisper + PID files
_wh_req = ['daic_wh_Xtr.npy', 'daic_wh_Xvl.npy', 'daic_wh_Xte.npy',
           'daic_wh_ytr_b.npy', 'daic_wh_yvl_b.npy', 'daic_wh_yte_b.npy',
           'daic_wh_pids_tr.npy', 'daic_wh_pids_vl.npy', 'daic_wh_pids_te.npy']
_wh_ok = all((_ed_f / f).exists() for f in _wh_req)

# Check hand-crafted enriched features — globals first, then disk
_hc_names_g = ['X_enr_train', 'X_enr_val', 'X_enr_test',
                'y_enr_train_bin', 'y_enr_val_bin', 'y_enr_test_bin']
_hc_in_globals = all(k in dir() for k in _hc_names_g)

_hc_disk_req = ['daicwoz_X_full_enriched_train.npy', 'daicwoz_X_full_enriched_val.npy',
                'daicwoz_X_full_enriched_test.npy',  'daicwoz_y_full_enriched_train_bin.npy',
                'daicwoz_y_full_enriched_val_bin.npy','daicwoz_y_full_enriched_test_bin.npy']
# Disk files could be in OUTPUT_DIR or working
# Cell 2.0 saves enriched features to /kaggle/working/processed_data/daicwoz/
_hc_disk_dir = Path('/kaggle/working/processed_data/daicwoz')
if not _hc_disk_dir.exists():
    _hc_disk_dir = globals().get('OUTPUT_DIR', Path('/kaggle/working'))
_hc_on_disk  = all((_hc_disk_dir / f).exists() for f in _hc_disk_req)
_hc_ok = _hc_in_globals or _hc_on_disk

if not _wh_ok:
    print('[SKIP] Whisper embeddings/PID files not found in', _ed_f)
    print('  Make sure Cell 1.10d ran with the updated code (saves daic_wh_pids_*.npy)')
elif not _hc_ok:
    print('[SKIP] Enriched hand-crafted features not found (globals or disk).')
    print('  Run Cell 2.0 before this cell.')
else:
    # Load Whisper side
    _Xwh_tr  = np.load(str(_ed_f / 'daic_wh_Xtr.npy'))
    _Xwh_vl  = np.load(str(_ed_f / 'daic_wh_Xvl.npy'))
    _Xwh_te  = np.load(str(_ed_f / 'daic_wh_Xte.npy'))
    _ywh_tr_b = np.load(str(_ed_f / 'daic_wh_ytr_b.npy'))
    _ywh_vl_b = np.load(str(_ed_f / 'daic_wh_yvl_b.npy'))
    _ywh_te_b = np.load(str(_ed_f / 'daic_wh_yte_b.npy'))
    _pids_tr  = np.load(str(_ed_f / 'daic_wh_pids_tr.npy'))
    _pids_vl  = np.load(str(_ed_f / 'daic_wh_pids_vl.npy'))
    _pids_te  = np.load(str(_ed_f / 'daic_wh_pids_te.npy'))

    # Load HC side (prefer globals, fall back to disk)
    if _hc_in_globals:
        _Xhc_tr, _Xhc_vl, _Xhc_te = X_enr_train, X_enr_val, X_enr_test
        _yhc_tr_b, _yhc_vl_b, _yhc_te_b = y_enr_train_bin, y_enr_val_bin, y_enr_test_bin
        print('  Hand-crafted features loaded from globals.')
    else:
        _Xhc_tr  = np.load(str(_hc_disk_dir / 'daicwoz_X_full_enriched_train.npy'))
        _Xhc_vl  = np.load(str(_hc_disk_dir / 'daicwoz_X_full_enriched_val.npy'))
        _Xhc_te  = np.load(str(_hc_disk_dir / 'daicwoz_X_full_enriched_test.npy'))
        _yhc_tr_b = np.load(str(_hc_disk_dir / 'daicwoz_y_full_enriched_train_bin.npy'))
        _yhc_vl_b = np.load(str(_hc_disk_dir / 'daicwoz_y_full_enriched_val_bin.npy'))
        _yhc_te_b = np.load(str(_hc_disk_dir / 'daicwoz_y_full_enriched_test_bin.npy'))
        print('  Hand-crafted features loaded from disk.')

    # Build PID -> row-index for HC arrays (HC uses participant_splits CSV order)
    try:
        _sp_f = _pd_f.read_csv(str(BASE_DATA / 'daicwoz' / 'daicwoz_participant_splits.csv'))
    except Exception as _sef:
        print(f'[SKIP] Cannot load participant splits CSV: {_sef}')
        _sp_f = None

    if _sp_f is not None:
        _sp_tr_f = _sp_f[_sp_f.split == 'train'].reset_index(drop=True)
        _sp_vl_f = _sp_f[_sp_f.split == 'val'].reset_index(drop=True)
        _sp_te_f = _sp_f[_sp_f.split == 'test'].reset_index(drop=True)
        _p2i_tr_f = {int(r.Participant_ID): i for i, r in _sp_tr_f.iterrows()}
        _p2i_vl_f = {int(r.Participant_ID): i for i, r in _sp_vl_f.iterrows()}
        _p2i_te_f = {int(r.Participant_ID): i for i, r in _sp_te_f.iterrows()}

        def _align(Xwh, pids, Xhc, p2i, ywh_b):
            _mwh = [i for i, p in enumerate(pids) if p in p2i]
            _mhc = [p2i[int(pids[i])] for i in _mwh]
            return (np.concatenate([Xwh[_mwh], Xhc[_mhc]], axis=1), ywh_b[_mwh])

        _Xf_tr, _yf_tr = _align(_Xwh_tr, _pids_tr, _Xhc_tr, _p2i_tr_f, _ywh_tr_b)
        _Xf_vl, _yf_vl = _align(_Xwh_vl, _pids_vl, _Xhc_vl, _p2i_vl_f, _ywh_vl_b)
        _Xf_te, _yf_te = _align(_Xwh_te, _pids_te, _Xhc_te, _p2i_te_f, _ywh_te_b)
        _D_wh = _Xwh_tr.shape[1]; _D_hc = _Xhc_tr.shape[1]
        print(f'  Fused dim: {_D_wh}(Whisper) + {_D_hc}(HC) = {_D_wh+_D_hc}-D')
        print(f'  Aligned:  train{_Xf_tr.shape} val{_Xf_vl.shape} test{_Xf_te.shape}')
        print(f'  Depressed in train: {_yf_tr.sum()}/{len(_yf_tr)}')

        _Xf_tv  = np.concatenate([_Xf_tr, _Xf_vl])
        _yf_tv  = np.concatenate([_yf_tr, _yf_vl])
        _spw_f  = float((_yf_tv == 0).sum()) / max((_yf_tv == 1).sum(), 1)

        # Mild SMOTE on fused training set (ratio capped at 1:1.5 to avoid overfit)
        try:
            from imblearn.over_sampling import SMOTE as _SMOTE_f
            _n_maj = int((_yf_tr == 0).sum())
            _n_min = int((_yf_tr == 1).sum())
            _target = min(_n_maj, int(_n_min * 1.5))  # cap: minority -> 1.5x, not 1:1
            _k_f = min(5, _n_min - 1)
            _smf = _SMOTE_f(random_state=42, k_neighbors=max(1, _k_f),
                            sampling_strategy={1: _target})
            _Xf_tr_sm, _yf_tr_sm = _smf.fit_resample(_Xf_tr, _yf_tr)
            print(f'  Mild SMOTE: {_Xf_tr.shape} -> {_Xf_tr_sm.shape}  '
                  f'(minority {_n_min} -> {_target}, capped at 1.5x)')
        except Exception:
            _Xf_tr_sm, _yf_tr_sm = _Xf_tr, _yf_tr

        # ── A: XGBoost on fused features ──
        print('\n[A] XGBoost on Whisper+HC Fusion')
        from xgboost import XGBClassifier
        _xgb_f = XGBClassifier(
            n_estimators=400, max_depth=3, learning_rate=0.05,
            scale_pos_weight=_spw_f, subsample=0.8, colsample_bytree=0.6,
            eval_metric='aucpr', tree_method='hist', random_state=42,
            device='cuda' if torch.cuda.is_available() else 'cpu')
        _xgb_f.fit(_Xf_tr_sm, _yf_tr_sm, verbose=False)
        _vpr_f = _xgb_f.predict_proba(_Xf_vl)[:, 1]
        _best_th_f, _best_vf1_f = 0.5, 0.0
        for _th_f in [round(x * 0.05, 2) for x in range(4, 15)]:
            _vf_f = f1_score(_yf_vl, (_vpr_f >= _th_f).astype(int), average='macro', zero_division=0)
            if _vf_f > _best_vf1_f:
                _best_vf1_f, _best_th_f = _vf_f, _th_f
        _tpr_f   = _xgb_f.predict_proba(_Xf_te)[:, 1]
        _pred_f  = (_tpr_f >= _best_th_f).astype(int)
        _f1_f    = f1_score(_yf_te, _pred_f, average='macro')
        _ac_f    = accuracy_score(_yf_te, _pred_f)
        _auc_f   = roc_auc_score(_yf_te, _tpr_f)
        _sens_f  = float((_pred_f[_yf_te == 1] == 1).sum()) / max((_yf_te == 1).sum(), 1)
        _spec_f  = float((_pred_f[_yf_te == 0] == 0).sum()) / max((_yf_te == 0).sum(), 1)
        print(f'  thresh={_best_th_f:.2f}  F1={_f1_f:.4f}  Acc={_ac_f:.4f}  AUC={_auc_f:.4f}')
        print(f'  Sensitivity={_sens_f:.4f}  Specificity={_spec_f:.4f}')
        RESULTS['daic_whisper_hc_fusion_xgb'] = {
            'model': 'XGB Fusion', 'feature': 'Whisper+HC 3767-D', 'dataset': 'DAIC-WOZ',
            'test_macro_f1': round(_f1_f, 4), 'test_accuracy': round(_ac_f, 4),
            'test_auc': round(_auc_f, 4), 'sensitivity': round(_sens_f, 4)}

        # ── B: MLP on fused features ──
        print('\n[B] MLP on Whisper+HC Fusion  (3767->1024->256->2, BatchNorm+Dropout)')
        _D_in_f = _Xf_tr.shape[1]
        _dev_f  = 'cuda' if torch.cuda.is_available() else 'cpu'

        class _FuseMLP(_nn.Module):
            def __init__(self):
                super().__init__()
                self.net = _nn.Sequential(
                    _nn.Linear(_D_in_f, 1024), _nn.BatchNorm1d(1024), _nn.ReLU(), _nn.Dropout(0.4),
                    _nn.Linear(1024, 256),     _nn.BatchNorm1d(256),  _nn.ReLU(), _nn.Dropout(0.3),
                    _nn.Linear(256, 2))
            def forward(self, x): return self.net(x)

        _sc_f = _SS_f().fit(_Xf_tv)
        _Xt_f  = torch.tensor(_sc_f.transform(_Xf_tr), dtype=torch.float32)
        _Xvt_f = torch.tensor(_sc_f.transform(_Xf_vl), dtype=torch.float32)
        _Xtt_f = torch.tensor(_sc_f.transform(_Xf_te), dtype=torch.float32)
        _yt_f  = torch.tensor(_yf_tr, dtype=torch.long)
        _yvt_f = torch.tensor(_yf_vl, dtype=torch.long)

        _fmlp  = _FuseMLP().to(_dev_f)
        _wts_f = torch.tensor([1.0, _spw_f], dtype=torch.float32).to(_dev_f)
        _crit_f = _nn.CrossEntropyLoss(weight=_wts_f)
        _opt_f  = torch.optim.AdamW(_fmlp.parameters(), lr=3e-4, weight_decay=1e-4)
        _sch_f  = torch.optim.lr_scheduler.CosineAnnealingLR(_opt_f, T_max=60)
        _bs_f   = 32
        _best_vf1_mlp, _best_state_f = 0.0, None
        for _ep_f in range(60):
            _fmlp.train()
            _idx_f = torch.randperm(len(_Xt_f))
            for _s_f in range(0, len(_Xt_f), _bs_f):
                _b_f = _idx_f[_s_f:_s_f + _bs_f]
                _opt_f.zero_grad()
                _crit_f(_fmlp(_Xt_f[_b_f].to(_dev_f)), _yt_f[_b_f].to(_dev_f)).backward()
                _opt_f.step()
            _sch_f.step()
            _fmlp.eval()
            with torch.no_grad():
                _vp_f = _fmlp(_Xvt_f.to(_dev_f)).argmax(1).cpu().numpy()
            _vf1_f = f1_score(_yf_vl, _vp_f, average='macro', zero_division=0)
            if _vf1_f > _best_vf1_mlp:
                _best_vf1_mlp = _vf1_f
                _best_state_f = copy.deepcopy(_fmlp.state_dict())

        _fmlp.load_state_dict(_best_state_f)
        _fmlp.eval()
        with torch.no_grad():
            _logits_f = _fmlp(_Xtt_f.to(_dev_f)).cpu().numpy()
        _probs_f = _F.softmax(torch.tensor(_logits_f), dim=1).numpy()[:, 1]
        _best_th_m, _best_f1_m = 0.5, 0.0
        _vprobs_f = _F.softmax(_fmlp(_Xvt_f.to(_dev_f)).detach().cpu(), dim=1).numpy()[:, 1]
        for _thm in [round(x * 0.05, 2) for x in range(4, 15)]:
            _ff = f1_score(_yf_vl, (_vprobs_f >= _thm).astype(int), average='macro', zero_division=0)
            if _ff > _best_f1_m: _best_f1_m, _best_th_m = _ff, _thm
        _pred_m  = (_probs_f >= _best_th_m).astype(int)
        _f1_m    = f1_score(_yf_te, _pred_m, average='macro')
        _ac_m    = accuracy_score(_yf_te, _pred_m)
        _auc_m   = roc_auc_score(_yf_te, _probs_f)
        _sens_m  = float((_pred_m[_yf_te == 1] == 1).sum()) / max((_yf_te == 1).sum(), 1)
        print(f'  Best val F1={_best_vf1_mlp:.4f}  thresh={_best_th_m:.2f}')
        print(f'  Test: F1={_f1_m:.4f}  Acc={_ac_m:.4f}  AUC={_auc_m:.4f}  Sens={_sens_m:.4f}')
        RESULTS['daic_whisper_hc_fusion_mlp'] = {
            'model': 'MLP Fusion', 'feature': 'Whisper+HC 3767-D', 'dataset': 'DAIC-WOZ',
            'test_macro_f1': round(_f1_m, 4), 'test_accuracy': round(_ac_m, 4),
            'test_auc': round(_auc_m, 4), 'sensitivity': round(_sens_m, 4)}

        # ── Grand Comparison Table ──
        print('\n' + '=' * 65)
        print('  DAIC-WOZ Binary Depression — Full Ablation Study')
        print('=' * 65)
        print(f'  {"Model":<38} {"F1":>7}  {"AUC":>7}  {"Sens":>6}')
        print('  ' + '-' * 62)
        _ablation = [
            ('HC 2231-D XGB (hand-crafted best)',      'daic_fusion_thresh_opt'),
            ('Whisper 1536-D XGB (+ SMOTE)',           'daic_whisper_xgb'),
            ('Whisper+HC 3767-D XGB (fusion NEW)',     'daic_whisper_hc_fusion_xgb'),
            ('Whisper+HC 3767-D MLP (fusion NEW)',     'daic_whisper_hc_fusion_mlp'),
        ]
        for _nm_a, _k_a in _ablation:
            _r_a  = RESULTS.get(_k_a, {})
            _f1_a = _r_a.get('test_macro_f1', 'N/A')
            _au_a = _r_a.get('test_auc', 'N/A')
            _sn_a = _r_a.get('sensitivity', 'N/A')
            print(f'  {_nm_a:<38} {str(_f1_a):>7}  {str(_au_a):>7}  {str(_sn_a):>6}')
        print('[DONE] 1.10f complete — fusion results added to RESULTS.')
# Out:
# ...
#   CELL 1.10f — DAIC-WOZ Whisper + Hand-crafted Fusion
# ...
#   Hand-crafted features loaded from disk.
#   Fused dim: 1536(Whisper) + 2231(HC) = 3767-D
#   Aligned:  train(104, 3767) val(35, 3767) test(46, 3767)
#   Depressed in train: 28/104
#   Mild SMOTE: (104, 3767) -> (118, 3767)  (minority 28 -> 42, capped at 1.5x)
#
# [A] XGBoost on Whisper+HC Fusion
#   thresh=0.60  F1=0.4623  Acc=0.6087  AUC=0.5223
#   Sensitivity=0.1429  Specificity=0.8125
#
# [B] MLP on Whisper+HC Fusion  (3767->1024->256->2, BatchNorm+Dropout)
#   Best val F1=0.6023  thresh=0.50
#   Test: F1=0.6068  Acc=0.6739  AUC=0.6116  Sens=0.4286
#
# ...
#   DAIC-WOZ Binary Depression — Full Ablation Study
# ...
#   Model                                       F1      AUC    Sens
#   --------------------------------------------------------------
#   HC 2231-D XGB (hand-crafted best)          N/A      N/A     N/A
#   Whisper 1536-D XGB (+ SMOTE)            0.4926   0.4665  0.2143
# ...

# %%
# ── Cell 2.1b: Use daicwoz_features.csv + participant_splits.csv for deeper analysis ──
# Load the full DAIC-WOZ features CSV for feature statistics
daic_feat_df = pd.read_csv(DAIC_DIR / "daicwoz_features.csv")
daic_part_df = pd.read_csv(DAIC_DIR / "daicwoz_participant_splits.csv")

print("DAIC-WOZ features.csv:", daic_feat_df.shape)
if 'label' in daic_feat_df.columns:
    print("  Label distribution:\n", daic_feat_df['label'].value_counts())
else:
    print("  (no 'label' column found — checking alternatives)")
    label_col_candidates = [c for c in daic_feat_df.columns if 'label' in c.lower() or 'depress' in c.lower() or 'phq' in c.lower()]
    print("  Candidate label cols:", label_col_candidates[:5])

print("\nParticipant splits:", daic_part_df.shape)
if 'split' in daic_part_df.columns:
    print(daic_part_df['split'].value_counts())
else:
    print(daic_part_df.head())

# Feature statistics by group
if 'label' in daic_feat_df.columns:
    print("\nTop features differing between groups (mean diff):")
    feat_cols = [c for c in daic_feat_df.columns if c not in ['participant_id','label','split','phq8_score','phq_score']]
    means = daic_feat_df.groupby('label')[feat_cols].mean()
    if means.shape[0] >= 2:
        diff = (means.iloc[1] - means.iloc[0]).abs().sort_values(ascending=False)
        print(diff.head(10))
    else:
        print("  Only one group found — cannot compute diff.")
# Out:
# DAIC-WOZ features.csv: (189, 453)
#   (no 'label' column found — checking alternatives)
#   Candidate label cols: ['PHQ8_Binary', 'PHQ8_Score', 'nlp_phq_keyword_density']
#
# Participant splits: (189, 5)
# split
# train    107
# test      47
# val       35
# Name: count, dtype: int64

# %%
# ── Cell 2.2: Acoustic Branch Hyperparameter Tuning (StratifiedKFold CV) ──
_XGB_DEV = 'cuda' if (TORCH_AVAILABLE and torch.cuda.is_available()) else 'cpu'
_XGB_TM  = 'hist'
# Best M3 branch: F1=0.6023. Goal: improve with systematic tuning.
# Use 5-fold CV on train set (val is only 35 samples).
# Metric: AUPRC (appropriate for imbalanced binary).

from sklearn.model_selection import StratifiedKFold

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

max_depths_ac  = [2, 3, 4]
learning_rates_ac = [0.01, 0.03, 0.05]
subsamples_ac  = [0.7, 0.8]

ac_grid_results = []

print("Acoustic branch CV grid search (AUPRC metric)...")
for depth in max_depths_ac:
    for lr in learning_rates_ac:
        for ss in subsamples_ac:
            auprc_scores = []
            for fold_idx, (tr_idx, vl_idx) in enumerate(skf.split(Xac_tr, y_daic_train_bin)):
                Xf_tr, Xf_vl = Xac_tr[tr_idx], Xac_tr[vl_idx]
                yf_tr, yf_vl = y_daic_train_bin[tr_idx], y_daic_train_bin[vl_idx]
                m = xgb.XGBClassifier(
                    objective="binary:logistic",
                    max_depth=depth, learning_rate=lr, n_estimators=200,
                    subsample=ss, colsample_bytree=0.8,
                    scale_pos_weight=POS_WEIGHT,
                    random_state=42, verbosity=0,
                    device=_XGB_DEV, tree_method=_XGB_TM,
                    eval_metric="aucpr"
                )
                m.fit(Xf_tr, yf_tr)
                prob = m.predict_proba(Xf_vl)[:, 1]
                auprc_scores.append(average_precision_score(yf_vl, prob))
            mean_auprc = np.mean(auprc_scores)
            ac_grid_results.append({
                "max_depth": depth, "learning_rate": lr, "subsample": ss,
                "CV_AUPRC": round(mean_auprc, 4)
            })

ac_grid_df = pd.DataFrame(ac_grid_results).sort_values("CV_AUPRC", ascending=False)
print("\nTop-5 acoustic branch configs (by CV AUPRC):")
print(ac_grid_df.head(5).to_string(index=False))

# Train best config on full train, evaluate on val
best_ac = ac_grid_df.iloc[0]
print(f"\nBest: depth={best_ac.max_depth} lr={best_ac.learning_rate} ss={best_ac.subsample}")

ac_best_model = xgb.XGBClassifier(
    objective="binary:logistic",
    max_depth=int(best_ac.max_depth),
    learning_rate=float(best_ac.learning_rate),
    n_estimators=300,
    subsample=float(best_ac.subsample),
    colsample_bytree=0.8,
    scale_pos_weight=POS_WEIGHT,
    early_stopping_rounds=30, eval_metric="aucpr",
    random_state=42, verbosity=0, 
)
ac_best_model.fit(Xac_tr, y_daic_train_bin,
                  eval_set=[(Xac_vl, y_daic_val_bin)], verbose=False)
ac_pred = ac_best_model.predict(Xac_vl)
ac_prob = ac_best_model.predict_proba(Xac_vl)

ac_metrics = clf_report(y_daic_val_bin, ac_pred, ac_prob,
                        name="Acoustic Branch (tuned) — Val")
save_results("daic_acoustic_tuned", {
    **ac_metrics,
    "auprc": float(average_precision_score(y_daic_val_bin, ac_prob[:,1])),
    "notes": f"XGB acoustic depth={int(best_ac.max_depth)} lr={best_ac.learning_rate}"
})


# Also train on combined train+val for better generalization
from imblearn.over_sampling import SMOTE as _SM
try:
    _Xac_all = np.vstack([Xac_tr, Xac_vl]); _y_all = np.concatenate([y_daic_train_bin, y_daic_val_bin])
    _Xac_sm, _y_sm = _SM(random_state=42, k_neighbors=3).fit_resample(_Xac_all, _y_all)
    ac_best_model_combined = xgb.XGBClassifier(
        objective="binary:logistic",
        max_depth=int(ac_grid_df.iloc[0]["max_depth"]),
        learning_rate=float(ac_grid_df.iloc[0]["learning_rate"]),
        n_estimators=300, subsample=float(ac_grid_df.iloc[0]["subsample"]),
        colsample_bytree=0.8, random_state=42, verbosity=0,
        device=_XGB_DEV, tree_method=_XGB_TM,
    )
    ac_best_model_combined.fit(_Xac_sm, _y_sm)
    _comb_pred = ac_best_model_combined.predict(Xac_te)
    _comb_f1  = f1_score(y_daic_test_bin, _comb_pred, average='macro', zero_division=0)
    print(f"Acoustic combined+SMOTE → Test F1={_comb_f1:.4f}")
    save_results('daic_acoustic_combined_test', {'macro_f1': _comb_f1, 'notes': 'Acoustic XGB train+val+SMOTE test'})
except Exception as _e:
    print(f"Combined acoustic training skipped: {_e}")
    ac_best_model_combined = ac_best_model
# Out:
# Acoustic branch CV grid search (AUPRC metric)...
#
# Top-5 acoustic branch configs (by CV AUPRC):
#  max_depth  learning_rate  subsample  CV_AUPRC
#          2           0.05        0.8    0.4858
#          4           0.05        0.8    0.4663
#          3           0.03        0.7    0.4654
#          2           0.03        0.8    0.4632
#          3           0.03        0.8    0.4545
#
# Best: depth=2.0 lr=0.05 ss=0.8
#
# ...
#   Acoustic Branch (tuned) — Val
# ...
#   Accuracy   : 0.6000
#   Macro-F1   : 0.5717
#   ROC-AUC    : 0.5978
#   AUPRC      : 0.5170
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.65      0.68        23
#            1       0.43      0.50      0.46        12
#
#     accuracy                           0.60        35
#    macro avg       0.57      0.58      0.57        35
# weighted avg       0.62      0.60      0.61        35
#
# ...

# %%
# ── Cell 2.3: Linguistic + Visual Branch Tuning ──
# Apply same CV strategy to linguistic (14 features) and visual (111 features).
# Lighter params for linguistic due to small feature count.

def tune_branch_cv(X_tr, y_tr, branch_name, param_grid):
    """Run StratifiedKFold CV over param_grid; return sorted results DataFrame."""
    skf_b = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    results = []
    for depth, lr, ss in param_grid:
        scores = []
        for tr_idx, vl_idx in skf_b.split(X_tr, y_tr):
            Xf_tr, Xf_vl = X_tr[tr_idx], X_tr[vl_idx]
            yf_tr, yf_vl = y_tr[tr_idx], y_tr[vl_idx]
            m = xgb.XGBClassifier(
                objective="binary:logistic",
                max_depth=depth, learning_rate=lr, n_estimators=200,
                subsample=ss, colsample_bytree=0.8,
                scale_pos_weight=POS_WEIGHT,
                random_state=42, verbosity=0,
                device=_XGB_DEV, tree_method=_XGB_TM
            )
            m.fit(Xf_tr, yf_tr)
            prob = m.predict_proba(Xf_vl)[:, 1]
            if len(np.unique(yf_vl)) > 1:
                scores.append(average_precision_score(yf_vl, prob))
        if scores:
            results.append({"depth": depth, "lr": lr, "ss": ss,
                            "CV_AUPRC": round(np.mean(scores), 4)})
    df = pd.DataFrame(results).sort_values("CV_AUPRC", ascending=False)
    print(f"\n{branch_name} top configs:")
    print(df.head(3).to_string(index=False))
    return df


# Linguistic — small feature count, use lighter grid
li_grid = [(d, lr, ss)
           for d in [2, 3]
           for lr in [0.01, 0.05]
           for ss in [0.7, 0.8]]
li_df = tune_branch_cv(Xli_tr, y_daic_train_bin, "Linguistic", li_grid)

# Visual — larger feature space
vi_grid = [(d, lr, ss)
           for d in [2, 3, 4]
           for lr in [0.01, 0.03, 0.05]
           for ss in [0.7, 0.8]]
vi_df = tune_branch_cv(Xvi_tr, y_daic_train_bin, "Visual", vi_grid)


def train_branch_best(X_tr, y_tr, X_vl, y_vl, best_row, name):
    m = xgb.XGBClassifier(
        objective="binary:logistic",
        max_depth=int(best_row.depth), learning_rate=float(best_row.lr),
        n_estimators=300, subsample=float(best_row.ss), colsample_bytree=0.8,
        scale_pos_weight=POS_WEIGHT,
        early_stopping_rounds=30, eval_metric="aucpr",
        random_state=42, verbosity=0, 
    )
    m.fit(X_tr, y_tr, eval_set=[(X_vl, y_vl)], verbose=False)
    pred = m.predict(X_vl)
    prob = m.predict_proba(X_vl)
    metrics = clf_report(y_vl, pred, prob, name=f"{name} — Val")
    return m, pred, prob, metrics


li_model, li_pred, li_prob, li_metrics = train_branch_best(
    Xli_tr, y_daic_train_bin, Xli_vl, y_daic_val_bin, li_df.iloc[0], "Linguistic")
vi_model, vi_pred, vi_prob, vi_metrics = train_branch_best(
    Xvi_tr, y_daic_train_bin, Xvi_vl, y_daic_val_bin, vi_df.iloc[0], "Visual")

save_results("daic_linguistic_tuned", {**li_metrics, "notes": "XGB linguistic tuned"})
save_results("daic_visual_tuned",     {**vi_metrics, "notes": "XGB visual tuned"})

# Summary vs M3
print("\nBranch comparison (M3 baseline acoustic F1=0.60, fusion F1=0.38):")
cmp = pd.DataFrame([
    {"Branch": "Acoustic (tuned)",   **ac_metrics},
    {"Branch": "Linguistic (tuned)", **li_metrics},
    {"Branch": "Visual (tuned)",     **vi_metrics},
])
print(cmp.to_string(index=False))
# Out:
# Linguistic top configs:
#  depth   lr  ss  CV_AUPRC
#      3 0.05 0.7    0.4186
#      2 0.05 0.8    0.4178
#      3 0.05 0.8    0.4156
#
# Visual top configs:
#  depth   lr  ss  CV_AUPRC
#      2 0.03 0.7    0.3416
#      4 0.05 0.8    0.3329
#      3 0.01 0.8    0.3263
#
# ...
#   Linguistic — Val
# ...
#   Accuracy   : 0.4571
#   Macro-F1   : 0.4272
#   ROC-AUC    : 0.5326
#   AUPRC      : 0.4646
#
#               precision    recall  f1-score   support
#
#            0       0.60      0.52      0.56        23
#            1       0.27      0.33      0.30        12
#
#     accuracy                           0.46        35
#    macro avg       0.43      0.43      0.43        35
# weighted avg       0.49      0.46      0.47        35
#
#
# ...
#   Visual — Val
# ...
#   Accuracy   : 0.5429
#   Macro-F1   : 0.4017
#   ROC-AUC    : 0.5797
#   AUPRC      : 0.3905
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.78      0.69        23
# ...

# %%
# ── Cell 2.4: Fix Fusion — MLP Meta-Learner vs Logistic Regression ──
# M3 stacking with LogReg meta-learner scored F1=0.38 — WORSE than acoustic alone (0.60).
# Fix: replace with a small MLP meta-learner.
# Input to meta-learner: branch probabilities [P(dep|acoustic), P(dep|linguistic), P(dep|visual)]

# Stack branch probabilities
meta_tr = np.column_stack([
    ac_best_model.predict_proba(Xac_tr)[:, 1],
    li_model.predict_proba(Xli_tr)[:, 1],
    vi_model.predict_proba(Xvi_tr)[:, 1]
])
meta_vl = np.column_stack([
    ac_prob[:, 1],
    li_prob[:, 1],
    vi_prob[:, 1]
])

print("Meta-learner input shapes:")
print(f"  meta_tr: {meta_tr.shape}  meta_vl: {meta_vl.shape}")

fusion_results = []

# ── A) Logistic Regression (M3 approach) ──
lr_meta = LogisticRegression(C=1.0, class_weight="balanced", random_state=42)
lr_meta.fit(meta_tr, y_daic_train_bin)
lr_pred_meta = lr_meta.predict(meta_vl)
lr_f1 = f1_score(y_daic_val_bin, lr_pred_meta, average="macro", zero_division=0)
lr_acc = accuracy_score(y_daic_val_bin, lr_pred_meta)
fusion_results.append({"Method": "LogReg meta-learner (M3)", "Val Accuracy": round(lr_acc,4), "Macro-F1": round(lr_f1,4)})
print(f"LogReg meta F1={lr_f1:.4f}  (M3 baseline was 0.38)")

# ── B) MLP Meta-Learner (fix) ──
if TORCH_AVAILABLE:
    class FusionMLP(nn.Module):
        """Tiny 2-layer MLP for branch probability fusion.
           Input: 3-D branch probabilities -> sigmoid -> binary depression prediction.
        """
        def __init__(self, in_dim=3, dropout=0.1):
            super().__init__()
            self.net = nn.Sequential(
                nn.Linear(in_dim, 16), nn.ReLU(), nn.Dropout(dropout),
                nn.Linear(16, 8),      nn.ReLU(), nn.Dropout(dropout),
                nn.Linear(8, 1)
            )
        def forward(self, x):
            return self.net(x).squeeze(1)

    def train_fusion_mlp(X_tr, y_tr, X_vl, y_vl, epochs=100, lr=5e-3):
        torch.manual_seed(42)
        model = FusionMLP(in_dim=X_tr.shape[1]).to(device)
        # BCEWithLogitsLoss with pos_weight for imbalance
        pw = torch.tensor([POS_WEIGHT], dtype=torch.float32).to(device)
        criterion = nn.BCEWithLogitsLoss(pos_weight=pw)
        opt = optim.Adam(model.parameters(), lr=lr, weight_decay=1e-3)
        Xtt = torch.tensor(X_tr, dtype=torch.float32).to(device)
        ytt = torch.tensor(y_tr, dtype=torch.float32).to(device)
        Xvt = torch.tensor(X_vl, dtype=torch.float32).to(device)
        for ep in range(epochs):
            model.train()
            opt.zero_grad()
            loss = criterion(model(Xtt), ytt)
            loss.backward()
            opt.step()
        model.eval()
        with torch.no_grad():
            logits = model(Xvt).cpu().numpy()
            pred   = (logits > 0).astype(int)
        return pred

    mlp_pred = train_fusion_mlp(meta_tr, y_daic_train_bin, meta_vl, y_daic_val_bin)
    mlp_f1  = f1_score(y_daic_val_bin, mlp_pred, average="macro", zero_division=0)
    mlp_acc = accuracy_score(y_daic_val_bin, mlp_pred)
    fusion_results.append({"Method": "MLP meta-learner (fixed)", "Val Accuracy": round(mlp_acc,4), "Macro-F1": round(mlp_f1,4)})
    print(f"MLP meta F1={mlp_f1:.4f}")

# ── C) Acoustic-only baseline ──
fusion_results.append({"Method": "Acoustic only (best branch)", "Val Accuracy": round(ac_metrics["accuracy"],4),
                        "Macro-F1": round(ac_metrics["macro_f1"],4)})

# ── D) Weighted average fusion ──
# Weight by val AUPRC of each branch
w_ac = average_precision_score(y_daic_val_bin, ac_prob[:,1])
w_li = average_precision_score(y_daic_val_bin, li_prob[:,1])
w_vi = average_precision_score(y_daic_val_bin, vi_prob[:,1])
w_sum = w_ac + w_li + w_vi
wavg_prob = (w_ac * ac_prob[:,1] + w_li * li_prob[:,1] + w_vi * vi_prob[:,1]) / w_sum
wavg_pred = (wavg_prob > 0.5).astype(int)
wavg_f1   = f1_score(y_daic_val_bin, wavg_pred, average="macro", zero_division=0)
wavg_acc  = accuracy_score(y_daic_val_bin, wavg_pred)
fusion_results.append({"Method": "Weighted avg fusion", "Val Accuracy": round(wavg_acc,4), "Macro-F1": round(wavg_f1,4)})
print(f"Weighted avg F1={wavg_f1:.4f}")

print("\n" + "="*60)
print("  Fusion Comparison")
print("="*60)
print(pd.DataFrame(fusion_results).to_string(index=False))

save_results("daic_fusion_logreg",  {"macro_f1": lr_f1,   "accuracy": lr_acc,   "notes": "LogReg meta"})
if TORCH_AVAILABLE:
    save_results("daic_fusion_mlp", {"macro_f1": mlp_f1,  "accuracy": mlp_acc,  "notes": "MLP meta"})
save_results("daic_fusion_wavg",    {"macro_f1": wavg_f1, "accuracy": wavg_acc, "notes": "weighted avg"})

# ── E) Direct XGBoost on full 2231-feature enriched matrix ─────────────
# Bypasses branch structure — lets XGB discover cross-modal interactions.
if globals().get("ENRICHMENT_DONE", False) and "X_enr_train" in dir():
    print("\nE) Direct XGB on 2231 enriched features...")
    _xgb_full = xgb.XGBClassifier(
        objective="binary:logistic",
        max_depth=3, learning_rate=0.03, n_estimators=500,
        subsample=0.7, colsample_bytree=0.5,
        scale_pos_weight=POS_WEIGHT,
        early_stopping_rounds=40, eval_metric="aucpr",
        random_state=42, verbosity=0, 
    )
    _xgb_full.fit(X_enr_train, y_enr_train_bin,
                  eval_set=[(X_enr_val, y_enr_val_bin)], verbose=False)
    _full_pred = _xgb_full.predict(X_enr_val)
    _full_prob = _xgb_full.predict_proba(X_enr_val)
    _full_f1  = f1_score(y_enr_val_bin, _full_pred, average="macro", zero_division=0)
    _full_acc = accuracy_score(y_enr_val_bin, _full_pred)
    fusion_results.append({"Method": "XGB direct (2231 feat)", "Val Accuracy": round(_full_acc,4), "Macro-F1": round(_full_f1,4)})
    print(f"  XGB direct F1={_full_f1:.4f}  acc={_full_acc:.4f}")
    save_results("daic_fusion_xgb_direct",
                 {"macro_f1": _full_f1, "accuracy": _full_acc,
                  "auprc": float(average_precision_score(y_enr_val_bin, _full_prob[:,1])),
                  "notes": "XGB direct on 2231 enriched features"})

# ── F) Threshold-optimised weighted average (handles class imbalance) ───
# Depression class is minority (30/107 = 28%); threshold > 0.5 may help recall.
_best_thresh_f1, _best_thresh = 0.0, 0.5
for _t in np.arange(0.25, 0.75, 0.05):
    _tp = (wavg_prob > _t).astype(int)
    _tf = f1_score(y_daic_val_bin, _tp, average="macro", zero_division=0)
    if _tf > _best_thresh_f1: _best_thresh_f1 = _tf; _best_thresh = round(_t,2)
_thresh_pred = (wavg_prob > _best_thresh).astype(int)
_thresh_f1  = f1_score(y_daic_val_bin, _thresh_pred, average="macro", zero_division=0)
_thresh_acc = accuracy_score(y_daic_val_bin, _thresh_pred)
fusion_results.append({"Method": f"Wavg thresh={_best_thresh}", "Val Accuracy": round(_thresh_acc,4), "Macro-F1": round(_thresh_f1,4)})
print(f"F) Threshold-optimised wavg: thresh={_best_thresh}  F1={_thresh_f1:.4f}")
save_results("daic_fusion_thresh_opt",
             {"macro_f1": _thresh_f1, "accuracy": _thresh_acc,
              "threshold": _best_thresh, "notes": f"Wavg thresh={_best_thresh} optimised"})

print("\n" + "="*60)
print("  Fusion Comparison — Updated")
print("="*60)
print(pd.DataFrame(fusion_results).to_string(index=False))
# ── G) Train+Val combined re-training with SMOTE (maximise data utilisation) ──
# Combines 107 train + 35 val = 142 sessions for final branch re-training.
# Uses SMOTE to address 28% depression prevalence.
# Val metrics computed via leave-one-out-like CV on the combined set.
try:
    from imblearn.over_sampling import SMOTE
    _sm = SMOTE(random_state=42, k_neighbors=3)

    # Combined data (all branches)
    Xac_all = np.vstack([Xac_tr, Xac_vl])
    Xli_all = np.vstack([Xli_tr, Xli_vl])
    Xvi_all = np.vstack([Xvi_tr, Xvi_vl])
    y_all   = np.concatenate([y_daic_train_bin, y_daic_val_bin])

    Xac_res, y_res = _sm.fit_resample(Xac_all, y_all)
    Xli_res, _     = _sm.fit_resample(Xli_all, y_all)
    Xvi_res, _     = _sm.fit_resample(Xvi_all, y_all)

    # Re-train branches on combined+SMOTE data
    _ac_comb = xgb.XGBClassifier(
        objective="binary:logistic",
        max_depth=int(ac_grid_df.iloc[0]["max_depth"]),
        learning_rate=float(ac_grid_df.iloc[0]["learning_rate"]),
        n_estimators=300, subsample=float(ac_grid_df.iloc[0]["subsample"]),
        colsample_bytree=0.8, random_state=42, verbosity=0,
        device=_XGB_DEV, tree_method=_XGB_TM,
    )
    _ac_comb.fit(Xac_res, y_res)

    _li_comb = xgb.XGBClassifier(
        objective="binary:logistic",
        max_depth=int(li_df.iloc[0]["depth"]),
        learning_rate=float(li_df.iloc[0]["lr"]),
        n_estimators=300, subsample=float(li_df.iloc[0]["ss"]),
        colsample_bytree=0.8, random_state=42, verbosity=0,
        device=_XGB_DEV, tree_method=_XGB_TM,
    )
    _li_comb.fit(Xli_res, y_res)

    _vi_comb = xgb.XGBClassifier(
        objective="binary:logistic",
        max_depth=int(vi_df.iloc[0]["depth"]),
        learning_rate=float(vi_df.iloc[0]["lr"]),
        n_estimators=300, subsample=float(vi_df.iloc[0]["ss"]),
        colsample_bytree=0.8, random_state=42, verbosity=0,
        device=_XGB_DEV, tree_method=_XGB_TM,
    )
    _vi_comb.fit(Xvi_res, y_res)

    # Evaluate on test set using combined models
    _ac_test_p = _ac_comb.predict_proba(Xac_te)[:, 1]
    _li_test_p = _li_comb.predict_proba(Xli_te)[:, 1]
    _vi_test_p = _vi_comb.predict_proba(Xvi_te)[:, 1]
    _w_ac2 = average_precision_score(y_daic_val_bin, ac_prob[:,1])
    _w_li2 = average_precision_score(y_daic_val_bin, li_prob[:,1])
    _w_vi2 = average_precision_score(y_daic_val_bin, vi_prob[:,1])
    _ws2   = _w_ac2 + _w_li2 + _w_vi2
    _comb_prob = (_w_ac2*_ac_test_p + _w_li2*_li_test_p + _w_vi2*_vi_test_p) / _ws2
    _comb_pred = (_comb_prob > _best_thresh).astype(int)
    _comb_f1  = f1_score(y_daic_test_bin, _comb_pred, average="macro", zero_division=0)
    _comb_acc = accuracy_score(y_daic_test_bin, _comb_pred)
    print(f"G) Train+Val+SMOTE combined → Test F1={_comb_f1:.4f}  acc={_comb_acc:.4f}")
    save_results("daic_fusion_combined_smote",
                 {"macro_f1": _comb_f1, "accuracy": _comb_acc,
                  "notes": "Train+Val combined + SMOTE, evaluated on test set"})
    fusion_results.append({"Method": "Train+Val+SMOTE (test)", "Val Accuracy": round(_comb_acc,4), "Macro-F1": round(_comb_f1,4)})
except Exception as _e:
    print(f"G) SMOTE combined training skipped: {_e}")
# ── G) Train+Val combined re-training with SMOTE (maximise data utilisation) ──
# Combines 107 train + 35 val = 142 sessions for final branch re-training.
# Uses SMOTE to address 28% depression prevalence.
# Val metrics computed via leave-one-out-like CV on the combined set.
try:
    from imblearn.over_sampling import SMOTE
    _sm = SMOTE(random_state=42, k_neighbors=3)

    # Combined data (all branches)
    Xac_all = np.vstack([Xac_tr, Xac_vl])
    Xli_all = np.vstack([Xli_tr, Xli_vl])
    Xvi_all = np.vstack([Xvi_tr, Xvi_vl])
    y_all   = np.concatenate([y_daic_train_bin, y_daic_val_bin])

    Xac_res, y_res = _sm.fit_resample(Xac_all, y_all)
    Xli_res, _     = _sm.fit_resample(Xli_all, y_all)
    Xvi_res, _     = _sm.fit_resample(Xvi_all, y_all)

    # Re-train branches on combined+SMOTE data
    _ac_comb = xgb.XGBClassifier(
        objective="binary:logistic",
        max_depth=int(ac_grid_df.iloc[0]["max_depth"]),
        learning_rate=float(ac_grid_df.iloc[0]["learning_rate"]),
        n_estimators=300, subsample=float(ac_grid_df.iloc[0]["subsample"]),
        colsample_bytree=0.8, random_state=42, verbosity=0,
        device=_XGB_DEV, tree_method=_XGB_TM,
    )
    _ac_comb.fit(Xac_res, y_res)

    _li_comb = xgb.XGBClassifier(
        objective="binary:logistic",
        max_depth=int(li_df.iloc[0]["depth"]),
        learning_rate=float(li_df.iloc[0]["lr"]),
        n_estimators=300, subsample=float(li_df.iloc[0]["ss"]),
        colsample_bytree=0.8, random_state=42, verbosity=0,
        device=_XGB_DEV, tree_method=_XGB_TM,
    )
    _li_comb.fit(Xli_res, y_res)

    _vi_comb = xgb.XGBClassifier(
        objective="binary:logistic",
        max_depth=int(vi_df.iloc[0]["depth"]),
        learning_rate=float(vi_df.iloc[0]["lr"]),
        n_estimators=300, subsample=float(vi_df.iloc[0]["ss"]),
        colsample_bytree=0.8, random_state=42, verbosity=0,
        device=_XGB_DEV, tree_method=_XGB_TM,
    )
    _vi_comb.fit(Xvi_res, y_res)

    # Evaluate on test set using combined models
    _ac_test_p = _ac_comb.predict_proba(Xac_te)[:, 1]
    _li_test_p = _li_comb.predict_proba(Xli_te)[:, 1]
    _vi_test_p = _vi_comb.predict_proba(Xvi_te)[:, 1]
    _w_ac2 = average_precision_score(y_daic_val_bin, ac_prob[:,1])
    _w_li2 = average_precision_score(y_daic_val_bin, li_prob[:,1])
    _w_vi2 = average_precision_score(y_daic_val_bin, vi_prob[:,1])
    _ws2   = _w_ac2 + _w_li2 + _w_vi2
    _comb_prob = (_w_ac2*_ac_test_p + _w_li2*_li_test_p + _w_vi2*_vi_test_p) / _ws2
    _comb_pred = (_comb_prob > _best_thresh).astype(int)
    _comb_f1  = f1_score(y_daic_test_bin, _comb_pred, average="macro", zero_division=0)
    _comb_acc = accuracy_score(y_daic_test_bin, _comb_pred)
    print(f"G) Train+Val+SMOTE combined → Test F1={_comb_f1:.4f}  acc={_comb_acc:.4f}")
    save_results("daic_fusion_combined_smote",
                 {"macro_f1": _comb_f1, "accuracy": _comb_acc,
                  "notes": "Train+Val combined + SMOTE, evaluated on test set"})
    fusion_results.append({"Method": "Train+Val+SMOTE (test)", "Val Accuracy": round(_comb_acc,4), "Macro-F1": round(_comb_f1,4)})
except Exception as _e:
    print(f"G) SMOTE combined training skipped: {_e}")
# Out:
# Meta-learner input shapes:
#   meta_tr: (107, 3)  meta_vl: (35, 3)
# LogReg meta F1=0.4485  (M3 baseline was 0.38)
# MLP meta F1=0.4485
# Weighted avg F1=0.4173
#
# ...
#   Fusion Comparison
# ...
#                      Method  Val Accuracy  Macro-F1
#    LogReg meta-learner (M3)        0.6286    0.4485
#    MLP meta-learner (fixed)        0.6286    0.4485
# Acoustic only (best branch)        0.6000    0.5717
#         Weighted avg fusion        0.5714    0.4173
#   [saved] daic_fusion_logreg: {'macro_f1': 0.4484848484848485, 'accuracy': 0.6285714285714286, 'notes': 'LogReg meta'}
#   [saved] daic_fusion_mlp: {'macro_f1': 0.4484848484848485, 'accuracy': 0.6285714285714286, 'notes': 'MLP meta'}
#   [saved] daic_fusion_wavg: {'macro_f1': 0.41731409544950054, 'accuracy': 0.5714285714285714, 'notes': 'weighted avg'}
#
# E) Direct XGB on 2231 enriched features...
#   XGB direct F1=0.6027  acc=0.6857
# ...

# %%
# ── Cell 2.5: PHQ-8 Regression — Loss Function Comparison ──
# Compare MSE vs Huber-like objectives for PHQ-8 severity prediction.
# M3 RMSE baseline: 6.56, within-1-band: 80%.

from sklearn.ensemble import GradientBoostingRegressor

reg_comparison = []

# ── A) XGBoost reg:squarederror (MSE) ──
xgb_reg_mse = xgb.XGBRegressor(
    objective="reg:squarederror",
    max_depth=3, learning_rate=0.05, n_estimators=300,
    subsample=0.8, colsample_bytree=0.8,
    early_stopping_rounds=30, eval_metric="rmse",
    random_state=42, verbosity=0,
    device=_XGB_DEV, tree_method=_XGB_TM
)
xgb_reg_mse.fit(X_daic_train, y_daic_train_score,
                eval_set=[(X_daic_val, y_daic_val_score)], verbose=False)
pred_mse = xgb_reg_mse.predict(X_daic_val)
mse_metrics = reg_report(y_daic_val_score, pred_mse, "XGB reg:squarederror", is_phq8=True)
reg_comparison.append({"Model": "XGB MSE", **mse_metrics})

# ── B) XGBoost reg:pseudohubererror (robust to outliers) ──
try:
    xgb_reg_hub = xgb.XGBRegressor(
        objective="reg:pseudohubererror",
        max_depth=3, learning_rate=0.05, n_estimators=300,
        subsample=0.8, colsample_bytree=0.8,
        early_stopping_rounds=30, eval_metric="rmse",
        random_state=42, verbosity=0,
        device=_XGB_DEV, tree_method=_XGB_TM
    )
    xgb_reg_hub.fit(X_daic_train, y_daic_train_score,
                    eval_set=[(X_daic_val, y_daic_val_score)], verbose=False)
    pred_hub = xgb_reg_hub.predict(X_daic_val)
    hub_metrics = reg_report(y_daic_val_score, pred_hub, "XGB reg:pseudohubererror", is_phq8=True)
    reg_comparison.append({"Model": "XGB Pseudo-Huber", **hub_metrics})
except Exception as e:
    print(f"Note: pseudohubererror not supported in this XGB version ({e}). Skipping.")
    hub_metrics = mse_metrics  # fallback
    reg_comparison.append({"Model": "XGB Pseudo-Huber (N/A)", **hub_metrics})

# ── C) sklearn GBR with huber loss ──
gbr_hub = GradientBoostingRegressor(
    loss="huber", alpha=0.9,
    n_estimators=200, max_depth=3, learning_rate=0.05,
    random_state=42
)
gbr_hub.fit(X_daic_train, y_daic_train_score)
pred_gbr = gbr_hub.predict(X_daic_val)
gbr_metrics = reg_report(y_daic_val_score, pred_gbr, "sklearn GBR Huber", is_phq8=True)
reg_comparison.append({"Model": "sklearn GBR Huber", **gbr_metrics})

# ── Comparison table ──
reg_df_cmp = pd.DataFrame(reg_comparison)
print("\n" + "="*70)
print("  PHQ-8 Regression Comparison  (M3 RMSE baseline: 6.56, band1: 80%)")
print("="*70)
print(reg_df_cmp.to_string(index=False))

save_results("daic_phq8_xgb_mse",  {**mse_metrics, "notes": "XGB MSE"})
save_results("daic_phq8_gbr_huber", {**gbr_metrics, "notes": "GBR Huber"})

# ── D) XGBoost with enriched 2231 features (if Cell 2.0 ran) ──
if globals().get("ENRICHMENT_DONE", False) and "X_enr_train" in dir():
    print("\nTraining PHQ-8 regression with enriched features...")
    _xgb_enr = xgb.XGBRegressor(
        objective="reg:squarederror",
        max_depth=4, learning_rate=0.03, n_estimators=500,
        subsample=0.8, colsample_bytree=0.6,
        early_stopping_rounds=30, eval_metric="rmse",
        random_state=42, verbosity=0
    )
    _xgb_enr.fit(X_enr_train, y_enr_train_score,
                 eval_set=[(X_enr_val, y_enr_val_score)], verbose=False)
    _pred_enr = _xgb_enr.predict(X_enr_val)
    enr_reg_metrics = reg_report(y_enr_val_score, _pred_enr,
                                 "XGB enriched (2231 feat)", is_phq8=True)
    reg_comparison.append({"Model": "XGB enriched (2231 feat)", **enr_reg_metrics})
    save_results("daic_phq8_xgb_enriched",
                 {**enr_reg_metrics, "notes": "XGB enriched 2231 features"})
    print("\n" + "="*70)
    print("  PHQ-8 — Updated with enriched features")
    print("="*70)
    print(pd.DataFrame(reg_comparison).to_string(index=False))
else:
    print("(Enriched PHQ-8 model skipped — session files not extracted)")

# ═══════════════════════════════════════════════════════════════════════
# DAIC-WOZ FINAL TEST EVALUATION — train+val combined + SMOTE
# ═══════════════════════════════════════════════════════════════════════
# Currently models are only evaluated on val (35 samples).
# Here we: (1) combine train+val (142 sessions, +33% data),
#          (2) apply SMOTE to fix 28% positive class imbalance,
#          (3) retrain best configs, (4) report HELD-OUT TEST metrics.
print("\n" + "="*70)
print("  DAIC-WOZ Final Test Evaluation  (train+val=142 → test=47)")
print("="*70)

# Combine train + val
_X_tv        = np.vstack([X_daic_train, X_daic_val])
_y_tv_bin    = np.concatenate([y_daic_train_bin,   y_daic_val_bin])
_y_tv_score  = np.concatenate([y_daic_train_score, y_daic_val_score])
_PW_TV       = ((_y_tv_bin==0).sum()) / max((_y_tv_bin==1).sum(), 1)
print(f"Train+Val: {_X_tv.shape} | Depressed: {_y_tv_bin.sum()}/{len(_y_tv_bin)} ({_y_tv_bin.mean()*100:.1f}%)")
print(f"Test: {X_daic_test.shape} | Depressed: {y_daic_test_bin.sum()}/{len(y_daic_test_bin)}")

# Apply SMOTE to balance the training set
_USE_SMOTE = False
try:
    from imblearn.over_sampling import SMOTE
    _k = min(4, int((_y_tv_bin==1).sum()) - 1)
    _sm = SMOTE(random_state=42, k_neighbors=_k)
    _X_tv_sm, _y_tv_sm = _sm.fit_resample(_X_tv, _y_tv_bin)
    print(f"SMOTE applied: {_X_tv.shape} -> {_X_tv_sm.shape} | class dist: {np.bincount(_y_tv_sm.astype(int))}")
    _USE_SMOTE = True
except Exception as _e:
    print(f"SMOTE skipped ({_e}) — using unaugmented train+val")
    _X_tv_sm, _y_tv_sm = _X_tv, _y_tv_bin

# Branch slices
_Xac_tv = _X_tv_sm[:, acoustic_idx];   _Xac_te = X_daic_test[:, acoustic_idx]
_Xli_tv = _X_tv_sm[:, linguistic_idx]; _Xli_te = X_daic_test[:, linguistic_idx]
_Xvi_tv = _X_tv_sm[:, visual_idx];     _Xvi_te = X_daic_test[:, visual_idx]
_pw_tv  = 1.0 if _USE_SMOTE else _PW_TV

# ── Retrain acoustic branch on train+val ────────────────────────────────
_ac_tv = xgb.XGBClassifier(
    objective="binary:logistic",
    max_depth=int(best_ac.max_depth), learning_rate=float(best_ac.learning_rate),
    n_estimators=400, subsample=float(best_ac.subsample), colsample_bytree=0.8,
    scale_pos_weight=_pw_tv, random_state=42, verbosity=0)
_ac_tv.fit(_Xac_tv, _y_tv_sm)
_ac_te_pred = _ac_tv.predict(_Xac_te)
_ac_te_prob = _ac_tv.predict_proba(_Xac_te)
_ac_te_f1   = f1_score(y_daic_test_bin, _ac_te_pred, average="macro", zero_division=0)
_ac_te_acc  = accuracy_score(y_daic_test_bin, _ac_te_pred)
print(f"Acoustic   Test: acc={_ac_te_acc:.4f}  F1={_ac_te_f1:.4f}")

# ── Retrain linguistic branch ────────────────────────────────────────────
_li_tv = xgb.XGBClassifier(
    objective="binary:logistic",
    max_depth=int(li_df.iloc[0].depth), learning_rate=float(li_df.iloc[0].lr),
    n_estimators=400, subsample=float(li_df.iloc[0].ss), colsample_bytree=0.8,
    scale_pos_weight=_pw_tv, random_state=42, verbosity=0)
_li_tv.fit(_Xli_tv, _y_tv_sm)
_li_te_pred = _li_tv.predict(_Xli_te)
_li_te_prob = _li_tv.predict_proba(_Xli_te)
_li_te_f1   = f1_score(y_daic_test_bin, _li_te_pred, average="macro", zero_division=0)
print(f"Linguistic Test: acc={accuracy_score(y_daic_test_bin,_li_te_pred):.4f}  F1={_li_te_f1:.4f}")

# ── Retrain visual branch ────────────────────────────────────────────────
_vi_tv = xgb.XGBClassifier(
    objective="binary:logistic",
    max_depth=int(vi_df.iloc[0].depth), learning_rate=float(vi_df.iloc[0].lr),
    n_estimators=400, subsample=float(vi_df.iloc[0].ss), colsample_bytree=0.8,
    scale_pos_weight=_pw_tv, random_state=42, verbosity=0)
_vi_tv.fit(_Xvi_tv, _y_tv_sm)
_vi_te_pred = _vi_tv.predict(_Xvi_te)
_vi_te_prob = _vi_tv.predict_proba(_Xvi_te)
_vi_te_f1   = f1_score(y_daic_test_bin, _vi_te_pred, average="macro", zero_division=0)
print(f"Visual     Test: acc={accuracy_score(y_daic_test_bin,_vi_te_pred):.4f}  F1={_vi_te_f1:.4f}")

# ── Weighted-avg fusion on test ──────────────────────────────────────────
_w_ac = average_precision_score(_y_tv_bin, _ac_tv.predict_proba(_X_tv[:, acoustic_idx])[:,1])
_w_li = average_precision_score(_y_tv_bin, _li_tv.predict_proba(_X_tv[:, linguistic_idx])[:,1])
_w_vi = average_precision_score(_y_tv_bin, _vi_tv.predict_proba(_X_tv[:, visual_idx])[:,1])
_ws   = _w_ac + _w_li + _w_vi
_fus_te_prob = (_w_ac*_ac_te_prob[:,1] + _w_li*_li_te_prob[:,1] + _w_vi*_vi_te_prob[:,1]) / _ws
# Threshold search on combined set
_bt, _bf1t = 0.5, 0.0
for _t in np.arange(0.20, 0.80, 0.05):
    _tf = f1_score(_y_tv_bin,
                   (_ac_tv.predict_proba(_X_tv[:,acoustic_idx])[:,1]*_w_ac/(_ws) +
                    _li_tv.predict_proba(_X_tv[:,linguistic_idx])[:,1]*_w_li/(_ws) +
                    _vi_tv.predict_proba(_X_tv[:,visual_idx])[:,1]*_w_vi/(_ws) > _t).astype(int),
                   average="macro", zero_division=0)
    if _tf > _bf1t: _bf1t = _tf; _bt = round(_t, 2)
_fus_te_pred = (_fus_te_prob > _bt).astype(int)
_fus_te_f1   = f1_score(y_daic_test_bin, _fus_te_pred, average="macro", zero_division=0)
_fus_te_acc  = accuracy_score(y_daic_test_bin, _fus_te_pred)
print(f"Fusion     Test: acc={_fus_te_acc:.4f}  F1={_fus_te_f1:.4f}  (thresh={_bt})")

# ── PHQ-8 regression on test ─────────────────────────────────────────────
_reg_tv = xgb.XGBRegressor(
    objective="reg:squarederror", max_depth=3, learning_rate=0.05,
    n_estimators=400, subsample=0.8, colsample_bytree=0.8,
    random_state=42, verbosity=0)
_reg_tv.fit(_X_tv, _y_tv_score)
_reg_te_pred = _reg_tv.predict(X_daic_test)
_reg_te_rmse = float(np.sqrt(np.mean((_reg_te_pred - y_daic_test_score)**2)))
# within-1-band: predicted severity band within 1 of true band (bands: 0-4,5-9,10-14,15-19,20-24)
_bands_true = (y_daic_test_score / 5).astype(int)
_bands_pred = (_reg_te_pred.clip(0, 24) / 5).astype(int)
_band1_te   = float(np.mean(np.abs(_bands_pred - _bands_true) <= 1))
print(f"PHQ-8      Test: RMSE={_reg_te_rmse:.4f}  within-1-band={_band1_te*100:.1f}%")

# ── Summary table ────────────────────────────────────────────────────────
print("\n" + "-"*70)
print("  Summary: Val (tuning) vs Test (final) — DAIC-WOZ")
print("-"*70)
_summary = pd.DataFrame([
    {"Branch": "Acoustic",   "Val F1": round(ac_metrics["macro_f1"],4),   "Test F1": round(_ac_te_f1,4)},
    {"Branch": "Linguistic", "Val F1": round(li_metrics["macro_f1"],4),   "Test F1": round(_li_te_f1,4)},
    {"Branch": "Visual",     "Val F1": round(vi_metrics["macro_f1"],4),   "Test F1": round(_vi_te_f1,4)},
    {"Branch": "Fusion",     "Val F1": round(wavg_f1, 4),                 "Test F1": round(_fus_te_f1,4)},
    {"Branch": "PHQ-8 RMSE", "Val F1": round(mse_metrics.get("rmse",0),4),"Test F1": round(_reg_te_rmse,4)},
])
print(_summary.to_string(index=False))
print(f"\nSMOTE used: {_USE_SMOTE} | Train+Val samples: {_X_tv.shape[0]} (was {X_daic_train.shape[0]})")

save_results("daic_test_acoustic",    {"accuracy": _ac_te_acc,  "macro_f1": _ac_te_f1,
             "notes": f"TEST acoustic train+val+SMOTE={_USE_SMOTE}"})
save_results("daic_test_linguistic",  {"macro_f1": _li_te_f1,
             "notes": f"TEST linguistic train+val+SMOTE={_USE_SMOTE}"})
save_results("daic_test_visual",      {"macro_f1": _vi_te_f1,
             "notes": f"TEST visual train+val+SMOTE={_USE_SMOTE}"})
save_results("daic_test_fusion",      {"accuracy": _fus_te_acc, "macro_f1": _fus_te_f1,
             "threshold": _bt,        "notes": f"TEST fusion wavg thresh={_bt} SMOTE={_USE_SMOTE}"})
save_results("daic_test_phq8",        {"rmse": _reg_te_rmse,    "within_1_band": _band1_te,
             "notes": "TEST PHQ-8 train+val XGBoost"})
# Out:
# ...
#   XGB reg:squarederror
# ...
#   RMSE             : 6.6072
#   MAE              : 5.4686
#   Band Accuracy    : 0.1714  (exact severity band match)
#   Within-1-Band %  : 80.00%  (M3-compatible metric, target>80%)
#
# ...
#   XGB reg:pseudohubererror
# ...
#   RMSE             : 6.7446
#   MAE              : 5.3574
#   Band Accuracy    : 0.2571  (exact severity band match)
#   Within-1-Band %  : 77.14%  (M3-compatible metric, target>80%)
#
# ...
#   sklearn GBR Huber
# ...
#   RMSE             : 6.8425
#   MAE              : 5.4659
#   Band Accuracy    : 0.2857  (exact severity band match)
#   Within-1-Band %  : 77.14%  (M3-compatible metric, target>80%)
#
# ...
#   PHQ-8 Regression Comparison  (M3 RMSE baseline: 6.56, band1: 80%)
# ...
#             Model     rmse      mae
#           XGB MSE 6.607174 5.468631
#  XGB Pseudo-Huber 6.744551 5.357389
# sklearn GBR Huber 6.842495 5.465901
#   [saved] daic_phq8_xgb_mse: {'rmse': 6.6071741935546555, 'mae': 5.468630790710449, 'notes': 'XGB MSE'}
# ...

# %%
# ── Cell 2.6: MODMA Audio — MDD vs HC (Small Dataset Experiments) ──
# N=52 subjects (36 train + 8 val + 8 test).
# Strategy: combine train+val (44 samples) for all CV experiments.
# Test set (8 samples) held out until final evaluation.

X_mod_train = np.load(MODMA_DIR / "modma_audio_X_train.npy")
X_mod_val   = np.load(MODMA_DIR / "modma_audio_X_val.npy")
X_mod_test  = np.load(MODMA_DIR / "modma_audio_X_test.npy")
y_mod_train = np.load(MODMA_DIR / "modma_audio_y_train.npy")
y_mod_val   = np.load(MODMA_DIR / "modma_audio_y_val.npy")
y_mod_test  = np.load(MODMA_DIR / "modma_audio_y_test.npy")

with open(MODMA_DIR / "modma_audio_feature_cols.txt") as f:
    mod_feat_cols = [line.strip() for line in f if line.strip()]

mod_rank_df = pd.read_csv(MODMA_DIR / "modma_audio_feature_ranking.csv")

# Combine train+val for CV (test held out)
X_mod_cv = np.vstack([X_mod_train, X_mod_val])
y_mod_cv = np.concatenate([y_mod_train, y_mod_val])

print("MODMA loaded:")
print(f"  X_train: {X_mod_train.shape}  X_val: {X_mod_val.shape}  X_test: {X_mod_test.shape}")
print(f"  CV pool (train+val): {X_mod_cv.shape}")
print(f"  Features: {len(mod_feat_cols)}")
vals, cnts = np.unique(y_mod_cv, return_counts=True)
print(f"  CV class dist: " + "  ".join([f"{int(v)}={c}" for v,c in zip(vals,cnts)]))

# ── 2.6.a Feature Selection — top-k SVM CV ──
print("\n2.6.a Feature selection (SVM 5-fold CV)...")
# Get ranked feature indices
rank_col = mod_rank_df.columns[0]  # first column is feature name or index
print(f"  Feature ranking columns: {list(mod_rank_df.columns)}")

# Try to get ranked indices
if "feature" in mod_rank_df.columns:
    ranked_feats = mod_rank_df["feature"].tolist()
    feat_to_idx  = {c: i for i, c in enumerate(mod_feat_cols)}
    ranked_idx   = [feat_to_idx[f] for f in ranked_feats if f in feat_to_idx]
elif "index" in mod_rank_df.columns:
    ranked_idx = mod_rank_df["index"].tolist()
else:
    # Use first column as feature names/indices
    first_val = mod_rank_df.iloc[0, 0]
    if isinstance(first_val, str):
        feat_to_idx = {c: i for i, c in enumerate(mod_feat_cols)}
        ranked_idx  = [feat_to_idx[f] for f in mod_rank_df.iloc[:,0] if f in feat_to_idx]
    else:
        ranked_idx = mod_rank_df.iloc[:, 0].astype(int).tolist()

if len(ranked_idx) == 0:
    ranked_idx = list(range(len(mod_feat_cols)))  # fallback: original order
    print("  Warning: could not parse ranking — using original feature order")

skf_mod = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
feat_counts = [50, 100, 200, 500, 1002]
feat_sel_results = []

for k in feat_counts:
    top_idx = ranked_idx[:k]
    X_sel   = X_mod_cv[:, top_idx]
    fold_f1s = []
    for tr_idx, vl_idx in skf_mod.split(X_sel, y_mod_cv):
        svm_m = SVC(C=1.0, kernel="rbf", random_state=42)
        svm_m.fit(X_sel[tr_idx], y_mod_cv[tr_idx])
        pred = svm_m.predict(X_sel[vl_idx])
        fold_f1s.append(f1_score(y_mod_cv[vl_idx], pred, average="macro", zero_division=0))
    mean_f1 = np.mean(fold_f1s)
    feat_sel_results.append({"Top-k features": k, "CV Macro-F1": round(mean_f1, 4)})
    print(f"  top-{k:5d}: CV F1={mean_f1:.4f}")

feat_sel_df = pd.DataFrame(feat_sel_results)
best_k_row  = feat_sel_df.loc[feat_sel_df["CV Macro-F1"].idxmax()]
BEST_K_MOD  = int(best_k_row["Top-k features"])
TOP_IDX_MOD = ranked_idx[:BEST_K_MOD]
print(f"\nBest feature count: {BEST_K_MOD} (CV F1={best_k_row['CV Macro-F1']})")

# ── 2.6.b SVM Grid ──
print("\n2.6.b SVM grid (C × kernel)...")
X_mod_best_k = X_mod_cv[:, TOP_IDX_MOD]
C_vals    = [0.1, 1, 10, 100]
kernels   = ["rbf", "linear"]
svm_grid  = []
for C in C_vals:
    for ker in kernels:
        fold_f1s = []
        for tr_idx, vl_idx in skf_mod.split(X_mod_best_k, y_mod_cv):
            sm = SVC(C=C, kernel=ker, random_state=42)
            sm.fit(X_mod_best_k[tr_idx], y_mod_cv[tr_idx])
            pred = sm.predict(X_mod_best_k[vl_idx])
            fold_f1s.append(f1_score(y_mod_cv[vl_idx], pred, average="macro", zero_division=0))
        svm_grid.append({"C": C, "kernel": ker, "CV Macro-F1": round(np.mean(fold_f1s),4)})
        print(f"  C={C:5} kernel={ker:7s} F1={np.mean(fold_f1s):.4f}")

svm_grid_df = pd.DataFrame(svm_grid).sort_values("CV Macro-F1", ascending=False)
print("\nSVM grid (sorted):")
print(svm_grid_df.to_string(index=False))

# ── 2.6.c XGBoost with heavy regularisation ──
print("\n2.6.c XGBoost heavy regularisation...")
xgb_reg_results = []
for alpha in [0.5, 1.0, 2.0]:
    for lam in [1.0, 2.0, 5.0]:
        fold_f1s = []
        for tr_idx, vl_idx in skf_mod.split(X_mod_cv, y_mod_cv):
            xm = xgb.XGBClassifier(
                objective="binary:logistic", max_depth=2,
                reg_alpha=alpha, reg_lambda=lam,
                n_estimators=100, learning_rate=0.05,
                random_state=42, verbosity=0, 
            )
            xm.fit(X_mod_cv[tr_idx], y_mod_cv[tr_idx])
            pred = xm.predict(X_mod_cv[vl_idx])
            fold_f1s.append(f1_score(y_mod_cv[vl_idx], pred, average="macro", zero_division=0))
        xgb_reg_results.append({"reg_alpha": alpha, "reg_lambda": lam,
                                 "CV Macro-F1": round(np.mean(fold_f1s),4)})

xgb_reg_df = pd.DataFrame(xgb_reg_results).sort_values("CV Macro-F1", ascending=False)
print("XGBoost reg results (top-5):")
print(xgb_reg_df.head(5).to_string(index=False))

# ── 2.6.d Final test evaluation ──
print("\n2.6.d Final test evaluation...")
X_test_best_k = X_mod_test[:, TOP_IDX_MOD]

best_svm_row = svm_grid_df.iloc[0]
best_svm_final = SVC(C=float(best_svm_row.C), kernel=str(best_svm_row.kernel), random_state=42)
best_svm_final.fit(X_mod_best_k, y_mod_cv)  # train on full CV pool
svm_test_pred = best_svm_final.predict(X_test_best_k)
svm_test_f1   = f1_score(y_mod_test, svm_test_pred, average="macro", zero_division=0)
svm_test_acc  = accuracy_score(y_mod_test, svm_test_pred)
print(f"MODMA SVM test: acc={svm_test_acc:.4f}  f1={svm_test_f1:.4f}")

best_xgb_mod = xgb_reg_df.iloc[0]
xgb_mod_final = xgb.XGBClassifier(
    objective="binary:logistic", max_depth=2,
    reg_alpha=float(best_xgb_mod.reg_alpha),
    reg_lambda=float(best_xgb_mod.reg_lambda),
    n_estimators=100, learning_rate=0.05,
    random_state=42, verbosity=0, 
)
xgb_mod_final.fit(X_mod_cv, y_mod_cv)
xgb_test_pred = xgb_mod_final.predict(X_mod_test)
xgb_test_f1   = f1_score(y_mod_test, xgb_test_pred, average="macro", zero_division=0)
xgb_test_acc  = accuracy_score(y_mod_test, xgb_test_pred)
print(f"MODMA XGB test: acc={xgb_test_acc:.4f}  f1={xgb_test_f1:.4f}")

save_results("modma_svm_test", {"accuracy": svm_test_acc, "macro_f1": svm_test_f1,
                                 "notes": f"SVM C={best_svm_row.C} kernel={best_svm_row.kernel}"})
save_results("modma_xgb_test", {"accuracy": xgb_test_acc, "macro_f1": xgb_test_f1,
                                 "notes": "XGB heavy reg"})
# Out:
# MODMA loaded:
#   X_train: (36, 1002)  X_val: (8, 1002)  X_test: (8, 1002)
#   CV pool (train+val): (44, 1002)
#   Features: 1002
#   CV class dist: 0=24  1=20
#
# 2.6.a Feature selection (SVM 5-fold CV)...
#   Feature ranking columns: ['feature', 'F_statistic', 'p_value']
#   top-   50: CV F1=0.8065
#   top-  100: CV F1=0.9032
#   top-  200: CV F1=0.9032
#   top-  500: CV F1=0.7811
#   top- 1002: CV F1=0.7142
#
# Best feature count: 100 (CV F1=0.9032)
#
# 2.6.b SVM grid (C × kernel)...
#   C=  0.1 kernel=rbf     F1=0.3524
#   C=  0.1 kernel=linear  F1=0.8082
#   C=    1 kernel=rbf     F1=0.9032
#   C=    1 kernel=linear  F1=0.8082
#   C=   10 kernel=rbf     F1=0.9082
#   C=   10 kernel=linear  F1=0.8082
#   C=  100 kernel=rbf     F1=0.9082
#   C=  100 kernel=linear  F1=0.8082
#
# SVM grid (sorted):
#     C kernel  CV Macro-F1
# 100.0    rbf       0.9082
#  10.0    rbf       0.9082
#   1.0    rbf       0.9032
#   0.1 linear       0.8082
#  10.0 linear       0.8082
# ...

# %% [markdown]
# ## Cell 2.7 — DAIC-WOZ + MODMA Summary

# %%
# ── Cell 2.7: DAIC-WOZ + MODMA Summary Table ──
daic_keys = [k for k in RESULTS if k.startswith("daic_") or k.startswith("modma_")]
daic_summary = []
for k in daic_keys:
    r = RESULTS[k]
    daic_summary.append({
        "Key":          k,
        "Val Acc/RMSE": r.get("accuracy", r.get("rmse", "-")),
        "Macro-F1":     r.get("macro_f1", "-"),
        "Notes":        r.get("notes", "")
    })

print("="*80)
print("  DAIC-WOZ + MODMA — All Experiment Results")
print("="*80)
print(pd.DataFrame(daic_summary).to_string(index=False))
print("\nM3 baselines: acoustic F1=0.60, fusion F1=0.38, PHQ-8 RMSE=6.56")
# Out:
# ...
#   DAIC-WOZ + MODMA — All Experiment Results
# ...
#                         Key Val Acc/RMSE  Macro-F1                                             Notes
#           modma_whisper_svm            -         -
#           modma_whisper_xgb            -         -
#            daic_whisper_xgb            -         -
#            daic_whisper_svm            -         -
#       daic_whisper_phq8_reg            -         -
#  daic_whisper_hc_fusion_xgb            -         -
#  daic_whisper_hc_fusion_mlp            -         -
#         daic_acoustic_tuned          0.6  0.571678                      XGB acoustic depth=2 lr=0.05
# daic_acoustic_combined_test            -  0.468326                 Acoustic XGB train+val+SMOTE test
#       daic_linguistic_tuned     0.457143  0.427218                              XGB linguistic tuned
#           daic_visual_tuned     0.542857  0.401709                                  XGB visual tuned
# ...

# %%
# ── Cell 2.8: DAIC-WOZ + MODMA — Artifacts, Sample Predictions & Confusion Matrices ──
# Saves XGBoost (DAIC acoustic branch) and MODMA SVM + XGB weights.
# Shows sample predictions and side-by-side confusion matrices.

import pickle, json as _json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

print('=' * 60)
print('  DAIC-WOZ + MODMA — ARTIFACTS & SAMPLE OUTPUT')
print('=' * 60)

# ── 1. Save DAIC-WOZ acoustic XGBoost ──
_daic_xgb_var = None
for _vn in ['ac_best_model_combined', 'ac_best_model', '_ac_comb']:
    if _vn in dir() and eval(_vn) is not None:
        _daic_xgb_var = eval(_vn)
        print(f'Using DAIC XGB model: {_vn}')
        break
if _daic_xgb_var is not None:
    _daic_xgb_path = OUTPUT_DIR / 'daic_acoustic_xgb.json'
    _daic_xgb_var.save_model(str(_daic_xgb_path))
    print(f'[SAVED] DAIC XGBoost -> {_daic_xgb_path.name}')
else:
    print('[SKIP] No DAIC XGBoost model found in memory')

# ── 2. Save MODMA SVM ──
if 'best_svm_final' in dir() and best_svm_final is not None:
    _svm_path = OUTPUT_DIR / 'modma_svm_final.pkl'
    with open(str(_svm_path), 'wb') as _fp:
        pickle.dump(best_svm_final, _fp)
    print(f'[SAVED] MODMA SVM    -> {_svm_path.name}')
else:
    print('[SKIP] best_svm_final not in memory')

# ── 3. Save MODMA XGBoost ──
if 'xgb_mod_final' in dir() and xgb_mod_final is not None:
    _modma_xgb_path = OUTPUT_DIR / 'modma_xgb_final.json'
    xgb_mod_final.save_model(str(_modma_xgb_path))
    print(f'[SAVED] MODMA XGB    -> {_modma_xgb_path.name}')
else:
    print('[SKIP] xgb_mod_final not in memory')

# ── 4. DAIC-WOZ sample predictions ──
print('\n── DAIC-WOZ: 10 Sample Predictions (Depression Binary) ──')
_daic_ok = ('Xac_te' in dir() and Xac_te is not None and
             'y_daic_test_bin' in dir() and y_daic_test_bin is not None and
             _daic_xgb_var is not None)
if _daic_ok:
    _daic_probs = _daic_xgb_var.predict_proba(Xac_te)[:, 1]
    _thresh = _best_thresh if '_best_thresh' in dir() else 0.5
    _daic_pred = (_daic_probs > _thresh).astype(int)
    _n_show = min(10, len(y_daic_test_bin))
    _daic_df = pd.DataFrame({
        'Sample'    : range(1, _n_show + 1),
        'True'      : ['Depressed' if l == 1 else 'Control'
                       for l in y_daic_test_bin[:_n_show]],
        'Predicted' : ['Depressed' if p == 1 else 'Control'
                       for p in _daic_pred[:_n_show]],
        'Prob(Dep)' : [f'{p:.3f}' for p in _daic_probs[:_n_show]],
        'Correct?'  : ['YES' if t == p else 'NO'
                       for t, p in zip(y_daic_test_bin[:_n_show], _daic_pred[:_n_show])]
    })
    print(_daic_df.to_string(index=False))
else:
    print('[SKIP] DAIC test data or model not available')

# ── 5. MODMA sample predictions (all 8 test samples) ──
print('\n── MODMA: All 8 Test Predictions (MDD vs HC) ──')
_modma_ok = ('X_mod_test' in dir() and X_mod_test is not None and
              'y_mod_test' in dir() and y_mod_test is not None and
              'best_svm_final' in dir() and best_svm_final is not None)
if _modma_ok:
    _n_feat = X_mod_test.shape[1]
    _best_k = best_svm_final.n_features_in_  # model stores exact feature count it was trained on
    _X_te_k = X_mod_test[:, :_best_k] if _best_k < _n_feat else X_mod_test
    _svm_pred_te = best_svm_final.predict(_X_te_k)
    _modma_df = pd.DataFrame({
        'Sample'   : range(1, len(y_mod_test) + 1),
        'True'     : ['MDD' if l == 1 else 'HC' for l in y_mod_test],
        'SVM Pred' : ['MDD' if p == 1 else 'HC' for p in _svm_pred_te],
        'Correct?' : ['YES' if t == p else 'NO'
                      for t, p in zip(y_mod_test, _svm_pred_te)]
    })
    print(_modma_df.to_string(index=False))
else:
    print('[SKIP] MODMA test data or SVM not available')

# ── 6. Side-by-side confusion matrices ──
print('\n── Confusion Matrices ──')
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
_plotted = 0
if _daic_ok:
    _cm_daic = confusion_matrix(y_daic_test_bin, _daic_pred)
    ConfusionMatrixDisplay(_cm_daic,
        display_labels=['Control', 'Depressed']).plot(
        ax=axes[0], colorbar=False, cmap='Reds')
    axes[0].set_title('DAIC-WOZ: Depression (XGB Acoustic)', fontsize=11)
    _plotted += 1
else:
    axes[0].text(0.5, 0.5, 'DAIC data\nnot available',
                 ha='center', va='center', transform=axes[0].transAxes)
    axes[0].set_title('DAIC-WOZ (unavailable)')
if _modma_ok:
    _cm_mod = confusion_matrix(y_mod_test, _svm_pred_te)
    ConfusionMatrixDisplay(_cm_mod,
        display_labels=['HC', 'MDD']).plot(
        ax=axes[1], colorbar=False, cmap='Greens')
    axes[1].set_title('MODMA: MDD vs HC (SVM)', fontsize=11)
    _plotted += 1
else:
    axes[1].text(0.5, 0.5, 'MODMA data\nnot available',
                 ha='center', va='center', transform=axes[1].transAxes)
    axes[1].set_title('MODMA (unavailable)')
plt.suptitle('DAIC-WOZ & MODMA — Test Set Confusion Matrices', fontsize=13, y=1.02)
plt.tight_layout()
_cm2_path = OUTPUT_DIR / 'daic_modma_confusion_matrices.png'
plt.savefig(str(_cm2_path), dpi=120, bbox_inches='tight')
plt.show()
print(f'[SAVED] {_cm2_path.name}')
# Out:
# ...
#   DAIC-WOZ + MODMA — ARTIFACTS & SAMPLE OUTPUT
# ...
# Using DAIC XGB model: ac_best_model_combined
# [SAVED] DAIC XGBoost -> daic_acoustic_xgb.json
# [SAVED] MODMA SVM    -> modma_svm_final.pkl
# [SAVED] MODMA XGB    -> modma_xgb_final.json
#
# ── DAIC-WOZ: 10 Sample Predictions (Depression Binary) ──
#  Sample      True Predicted Prob(Dep) Correct?
#       1   Control   Control     0.167      YES
#       2   Control   Control     0.021      YES
#       3   Control   Control     0.107      YES
#       4 Depressed   Control     0.102       NO
#       5 Depressed   Control     0.123       NO
#       6 Depressed   Control     0.275       NO
#       7   Control Depressed     0.676       NO
#       8   Control Depressed     0.488       NO
#       9   Control   Control     0.013      YES
#      10 Depressed Depressed     0.689      YES
#
# ── MODMA: All 8 Test Predictions (MDD vs HC) ──
#  Sample True SVM Pred Correct?
#       1  MDD      MDD      YES
#       2  MDD      MDD      YES
# ...

# %%
# ── Cell 2.9: ROC Curves — DAIC-WOZ (Depression) & MODMA (MDD vs HC) ──
# Plots ROC curves for both binary classification tasks in Section 2.
# Guard-wrapped: skips gracefully if models or test data are not in memory.

import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

print('=' * 60)
print('  ROC CURVES — DAIC-WOZ & MODMA')
print('=' * 60)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# ── DAIC-WOZ: Depression Binary ──
_daic_xgb_roc = None
for _vn in ['ac_best_model_combined', 'ac_best_model', '_ac_comb']:
    if _vn in dir() and eval(_vn) is not None:
        _daic_xgb_roc = eval(_vn)
        break
_daic_roc_ok = (_daic_xgb_roc is not None and
                'Xac_te' in dir() and Xac_te is not None and
                'y_daic_test_bin' in dir() and y_daic_test_bin is not None)
if _daic_roc_ok:
    _probs_daic = _daic_xgb_roc.predict_proba(Xac_te)[:, 1]
    fpr_d, tpr_d, _ = roc_curve(y_daic_test_bin, _probs_daic)
    roc_auc_d = auc(fpr_d, tpr_d)
    axes[0].plot(fpr_d, tpr_d, color='crimson', lw=2,
                 label=f'XGB Acoustic (AUC = {roc_auc_d:.3f})')
    axes[0].plot([0, 1], [0, 1], 'k--', lw=1, label='Random (AUC = 0.500)')
    axes[0].set_xlabel('False Positive Rate')
    axes[0].set_ylabel('True Positive Rate')
    axes[0].set_title('DAIC-WOZ: Depression Detection\nROC Curve (Test Set)', fontsize=11)
    axes[0].legend(loc='lower right', fontsize=9)
    axes[0].set_xlim([0, 1]); axes[0].set_ylim([0, 1.02])
    axes[0].grid(alpha=0.3)
    print(f'DAIC-WOZ ROC-AUC = {roc_auc_d:.4f}')
else:
    axes[0].text(0.5, 0.5, 'DAIC-WOZ data\nor model not available',
                 ha='center', va='center', transform=axes[0].transAxes, fontsize=11)
    axes[0].set_title('DAIC-WOZ ROC (unavailable)')
    print('[SKIP] DAIC-WOZ ROC — model or test data not in memory')

# ── MODMA: MDD vs HC ──
_modma_roc_ok = ('best_svm_final' in dir() and best_svm_final is not None and
                  'X_mod_test' in dir() and X_mod_test is not None and
                  'y_mod_test' in dir() and y_mod_test is not None)
if _modma_roc_ok:
    _n_feat_m = X_mod_test.shape[1]
    _bk = best_svm_final.n_features_in_  # model stores exact feature count
    _Xm_te = X_mod_test[:, :_bk] if _bk < _n_feat_m else X_mod_test
    _probs_mod = best_svm_final.decision_function(_Xm_te)
    fpr_m, tpr_m, _ = roc_curve(y_mod_test, _probs_mod)
    roc_auc_m = auc(fpr_m, tpr_m)
    axes[1].plot(fpr_m, tpr_m, color='steelblue', lw=2,
                 label=f'SVM (AUC = {roc_auc_m:.3f})')
    axes[1].plot([0, 1], [0, 1], 'k--', lw=1, label='Random (AUC = 0.500)')
    axes[1].set_xlabel('False Positive Rate')
    axes[1].set_ylabel('True Positive Rate')
    axes[1].set_title('MODMA: MDD vs HC\nROC Curve (Test Set, N=8)', fontsize=11)
    axes[1].legend(loc='lower right', fontsize=9)
    axes[1].set_xlim([0, 1]); axes[1].set_ylim([0, 1.02])
    axes[1].grid(alpha=0.3)
    print(f'MODMA ROC-AUC = {roc_auc_m:.4f}')
else:
    axes[1].text(0.5, 0.5, 'MODMA data\nor model not available',
                 ha='center', va='center', transform=axes[1].transAxes, fontsize=11)
    axes[1].set_title('MODMA ROC (unavailable)')
    print('[SKIP] MODMA ROC — model or test data not in memory')

plt.suptitle('ROC Curves — Binary Classification Tasks (Section 2)',
             fontsize=13, y=1.02)
plt.tight_layout()
_roc2_path = OUTPUT_DIR / 'daic_modma_roc_curves.png'
plt.savefig(str(_roc2_path), dpi=120, bbox_inches='tight')
plt.show()
print(f'[SAVED] {_roc2_path.name}')
# Out:
# ...
#   ROC CURVES — DAIC-WOZ & MODMA
# ...
# DAIC-WOZ ROC-AUC = 0.5563
# MODMA ROC-AUC = 1.0000
# [SAVED] daic_modma_roc_curves.png

# %% [markdown]
# ---
# # Section 3 — Stress Detection: Large-Scale Neural Network Experiments
#
# **Datasets:**
# - SWELL-HRV: 204,885 samples × 75 features, 3-class (0=relaxed / 1=time-pressure / 2=interruption)
# - WESAD-HRV: 81,892 samples × 40 features, binary (0=baseline / 1=stress)
# - SWELL-EDA: 51,741 × 46 features, 3-class
# - WESAD-EDA: 20,496 × 45 features, binary
#
# **Key constraint:** NO pre-made train/val/test splits. Use subject-level GroupShuffleSplit to prevent data leakage.
#
# **Experiments:**
# 3.2 XGBoost baseline
# 3.3 MLP architecture comparison (shallow / medium / deep)
# 3.4 Optimiser comparison (5 optimisers)
# 3.5 LR scheduler experiment
# 3.6 Regularisation ablation (6 configurations)
# 3.7 Best config applied to WESAD-HRV (binary)

# %%
# ── Cell 3.1: Load ALL Stress Data — Apply Scalers, Add Binary Versions, Load Regression ──
# This cell now fully uses ALL stress processed_data files including scalers, regression targets, and full CSVs.

def subject_split(X, y, sids, val_frac=0.15, test_frac=0.15, seed=42):
    from sklearn.model_selection import GroupShuffleSplit
    gss_test = GroupShuffleSplit(n_splits=1, test_size=test_frac, random_state=seed)
    trainval_idx, test_idx = next(gss_test.split(X, y, groups=sids))
    X_tv, y_tv, s_tv = X[trainval_idx], y[trainval_idx], sids[trainval_idx]
    val_frac_of_tv = val_frac / (1 - test_frac)
    gss_val = GroupShuffleSplit(n_splits=1, test_size=val_frac_of_tv, random_state=seed)
    train_idx, val_idx = next(gss_val.split(X_tv, y_tv, groups=s_tv))
    return (X_tv[train_idx], y_tv[train_idx], X_tv[val_idx], y_tv[val_idx], X[test_idx], y[test_idx])

def load_stress_dataset(name, signal, task, scaler_type='class'):
    """Load stress dataset, apply scaler, return scaled splits + binary version if 3-class."""
    base = f"stress_{name}_{signal}_{task}"
    X    = np.load(STRESS_DIR / f"{base}_X.npy")
    y    = np.load(STRESS_DIR / f"{base}_y.npy")
    sids = np.load(STRESS_DIR / f"{base}_subject_ids.npy")
    scaler = load_scaler(STRESS_DIR / f"{base}_scaler.pkl")

    # Apply scaler + clip outliers
    X_sc = np.clip(scaler.transform(X), -10, 10)

    # Subject-level split on scaled data
    Xtr, ytr, Xvl, yvl, Xte, yte = subject_split(X_sc, y, sids)

    n_classes = len(np.unique(y))
    result = {
        'X_train': Xtr, 'y_train': ytr,
        'X_val': Xvl,   'y_val': yvl,
        'X_test': Xte,  'y_test': yte,
        'n_classes': n_classes, 'n_features': X.shape[1],
        'scaler': scaler
    }

    # If 3-class, also add binary version (collapse mid-class: 0=no-stress, 1=any-stress)
    if n_classes == 3:
        y_bin = (y > 0).astype(int)  # 0=no-stress, 1=stressed
        Xtr_b, ytr_b, Xvl_b, yvl_b, Xte_b, yte_b = subject_split(X_sc, y_bin, sids)
        result['binary'] = {
            'X_train': Xtr_b, 'y_train': ytr_b,
            'X_val': Xvl_b,   'y_val': yvl_b,
            'X_test': Xte_b,  'y_test': yte_b,
            'n_classes': 2
        }
    return result

# ── Load feature rankings ──
import json as _json
with open(STRESS_DIR / "stress_feature_ranks.json") as f:
    STRESS_FEAT_RANKS = _json.load(f)
print("Feature ranks loaded. Keys:", list(STRESS_FEAT_RANKS.keys())[:5])

# ── Load full CSVs for dataset statistics ──
for csv_name in ['stress_swell_hrv_full.csv', 'stress_swell_eda_full.csv',
                 'stress_wesad_hrv_full.csv', 'stress_wesad_eda_full.csv']:
    try:
        df = pd.read_csv(STRESS_DIR / csv_name, nrows=5)
        print(f"{csv_name}: {df.shape[1]} cols, sample shape preview ok")
    except Exception as e:
        print(f"{csv_name}: {e}")

# ── Load all 4 classification datasets with scalers applied ──
print("\nLoading SWELL-HRV (3-class + binary)...")
swell_hrv = load_stress_dataset('swell', 'hrv', 'class')
print(f"  3-class: train={swell_hrv['X_train'].shape} val={swell_hrv['X_val'].shape}")
print(f"  binary:  train={swell_hrv['binary']['X_train'].shape}")

print("Loading WESAD-HRV (binary)...")
wesad_hrv = load_stress_dataset('wesad', 'hrv', 'class')
print(f"  binary: train={wesad_hrv['X_train'].shape} val={wesad_hrv['X_val'].shape}")

print("Loading SWELL-EDA (3-class + binary, was unscaled before)...")
swell_eda = load_stress_dataset('swell', 'eda', 'class')
print(f"  3-class: train={swell_eda['X_train'].shape}")
print(f"  binary:  train={swell_eda['binary']['X_train'].shape}")
print(f"  X range after scaling: [{swell_eda['X_train'].min():.2f}, {swell_eda['X_train'].max():.2f}]")

print("Loading WESAD-EDA (binary)...")
wesad_eda = load_stress_dataset('wesad', 'eda', 'class')
print(f"  binary: train={wesad_eda['X_train'].shape} val={wesad_eda['X_val'].shape}")

# ── Load regression datasets ──
print("\nLoading regression datasets...")
def load_stress_regre(name, signal):
    base = f"stress_{name}_{signal}_regre"
    X    = np.load(STRESS_DIR / f"{base}_X.npy")
    y    = np.load(STRESS_DIR / f"{base}_y.npy")
    sids = np.load(STRESS_DIR / f"{base}_subject_ids.npy")
    scaler = load_scaler(STRESS_DIR / f"{base}_scaler.pkl")
    X_sc = np.clip(scaler.transform(X), -10, 10)
    Xtr, ytr, Xvl, yvl, Xte, yte = subject_split(X_sc, y, sids)
    return {'X_train': Xtr, 'y_train': ytr, 'X_val': Xvl, 'y_val': yvl, 'X_test': Xte, 'y_test': yte}

swell_hrv_regre = load_stress_regre('swell', 'hrv')
swell_eda_regre = load_stress_regre('swell', 'eda')
wesad_hrv_regre = load_stress_regre('wesad', 'hrv')
wesad_eda_regre = load_stress_regre('wesad', 'eda')
print(f"  SWELL-HRV regre: train={swell_hrv_regre['X_train'].shape}  y_range=[{swell_hrv_regre['y_train'].min():.1f},{swell_hrv_regre['y_train'].max():.1f}]")
print(f"  SWELL-EDA regre: train={swell_eda_regre['X_train'].shape}  y_range=[{swell_eda_regre['y_train'].min():.1f},{swell_eda_regre['y_train'].max():.1f}]")
print(f"  WESAD-HRV regre: train={wesad_hrv_regre['X_train'].shape}  unique_y={np.unique(wesad_hrv_regre['y_train'])}")
print(f"  WESAD-EDA regre: train={wesad_eda_regre['X_train'].shape}  unique_y={np.unique(wesad_eda_regre['y_train'])}")

# Aliases for backward compatibility with cells 3.3-3.7
X_sh_tr, y_sh_tr = swell_hrv['X_train'], swell_hrv['y_train']
X_sh_vl, y_sh_vl = swell_hrv['X_val'],   swell_hrv['y_val']
X_sh_te, y_sh_te = swell_hrv['X_test'],  swell_hrv['y_test']
X_wh_tr, y_wh_tr = wesad_hrv['X_train'], wesad_hrv['y_train']
X_wh_vl, y_wh_vl = wesad_hrv['X_val'],   wesad_hrv['y_val']
X_wh_te, y_wh_te = wesad_hrv['X_test'],  wesad_hrv['y_test']
X_se_tr, y_se_tr = swell_eda['X_train'], swell_eda['y_train']
X_se_vl, y_se_vl = swell_eda['X_val'],   swell_eda['y_val']
X_se_te, y_se_te = swell_eda['X_test'],  swell_eda['y_test']
X_we_tr, y_we_tr = wesad_eda['X_train'], wesad_eda['y_train']
X_we_vl, y_we_vl = wesad_eda['X_val'],   wesad_eda['y_val']
X_we_te, y_we_te = wesad_eda['X_test'],  wesad_eda['y_test']

print("\nAll stress datasets loaded with scalers applied and regression data ready.")
# Out:
# Feature ranks loaded. Keys: ['swell_eda_classification', 'wesad_eda_classification', 'swell_eda_regression', 'wesad_eda_regression', 'swell_hrv_classification']
# stress_swell_hrv_full.csv: 97 cols, sample shape preview ok
# stress_swell_eda_full.csv: 61 cols, sample shape preview ok
# stress_wesad_hrv_full.csv: 158 cols, sample shape preview ok
# stress_wesad_eda_full.csv: 106 cols, sample shape preview ok
#
# Loading SWELL-HRV (3-class + binary)...
#   3-class: train=(126594, 75) val=(37382, 75)
#   binary:  train=(126594, 75)
# Loading WESAD-HRV (binary)...
#   binary: train=(49221, 40) val=(16363, 40)
# Loading SWELL-EDA (3-class + binary, was unscaled before)...
#   3-class: train=(34217, 46)
#   binary:  train=(34217, 46)
#   X range after scaling: [-10.00, 10.00]
# Loading WESAD-EDA (binary)...
#   binary: train=(12322, 45) val=(4141, 45)
#
# Loading regression datasets...
#   SWELL-HRV regre: train=(126594, 75)  y_range=[26.1,90.9]
# ...

# %%
# ── Cell 3.2: XGBoost Baseline on ALL Stress Datasets (scaled, 3-class + binary + regression) ──
import time
_XGB_DEV = 'cuda' if (TORCH_AVAILABLE and torch.cuda.is_available()) else 'cpu'
_XGB_TM  = 'hist'
stress_baselines = []

datasets_to_test = [
    ('SWELL-HRV 3-class', swell_hrv, False),
    ('SWELL-HRV binary',  swell_hrv['binary'], False),
    ('WESAD-HRV binary',  wesad_hrv, False),
    ('SWELL-EDA 3-class (fixed)', swell_eda, False),
    ('SWELL-EDA binary',  swell_eda['binary'], False),
    ('WESAD-EDA binary',  wesad_eda, False),
]

for name, ds, _ in datasets_to_test:
    n_cls = ds['n_classes'] if 'n_classes' in ds else 2
    obj = 'multi:softprob' if n_cls > 2 else 'binary:logistic'
    t0 = time.time()
    m = xgb.XGBClassifier(
        objective=obj, num_class=n_cls if n_cls > 2 else None,
        max_depth=3, learning_rate=0.05, n_estimators=300,
        subsample=0.8, colsample_bytree=0.8,
        early_stopping_rounds=30,
        random_state=42, verbosity=0,
        device=_XGB_DEV, tree_method=_XGB_TM)
    m.fit(ds['X_train'], ds['y_train'],
          eval_set=[(ds['X_val'], ds['y_val'])], verbose=False)
    pred = m.predict(ds['X_val'])
    acc = accuracy_score(ds['y_val'], pred)
    f1  = f1_score(ds['y_val'], pred, average='macro', zero_division=0)
    t = round(time.time()-t0, 1)
    stress_baselines.append((name, acc, f1, t))
    key = 'stress_xgb_' + name.lower().replace(' ', '_').replace('(','').replace(')','')
    save_results(key, {'accuracy': acc, 'macro_f1': f1, 'notes': f'XGB baseline {name}'})
    print(f"  {name}: acc={acc:.4f}  f1={f1:.4f}  time={t}s")

# ── Regression baselines (XGBoost) ──
print("\nStress Regression XGBoost baselines:")
for rname, rds in [('SWELL-HRV', swell_hrv_regre), ('SWELL-EDA', swell_eda_regre)]:
    t0 = time.time()
    m = xgb.XGBRegressor(max_depth=3, learning_rate=0.05, n_estimators=300,
                          early_stopping_rounds=30, random_state=42, verbosity=0,
                          device=_XGB_DEV, tree_method=_XGB_TM)
    m.fit(rds['X_train'], rds['y_train'],
          eval_set=[(rds['X_val'], rds['y_val'])], verbose=False)
    pred = m.predict(rds['X_val'])
    from sklearn.metrics import mean_squared_error, mean_absolute_error
    rmse = np.sqrt(mean_squared_error(rds['y_val'], pred))
    mae  = mean_absolute_error(rds['y_val'], pred)
    print(f"  {rname}: RMSE={rmse:.3f}  MAE={mae:.3f}  time={round(time.time()-t0,1)}s")
    rkey = rname.lower().replace("-","_")
    save_results(f'stress_regre_xgb_{rkey}',
                 {'rmse': float(rmse), 'mae': float(mae), 'notes': f'XGB regressor {rname}'})

print("\nXGBoost Stress Baselines (all scaled):")
bl_df = pd.DataFrame(stress_baselines, columns=['Dataset','Val Acc','Macro-F1','Time(s)'])
print(bl_df.to_string(index=False))
# Out:
#   [saved] stress_xgb_swell-hrv_3-class: {'accuracy': 0.508266010379327, 'macro_f1': 0.5083146016432907, 'notes': 'XGB baseline SWELL-HRV 3-class'}
#   SWELL-HRV 3-class: acc=0.5083  f1=0.5083  time=1.2s
#   [saved] stress_xgb_swell-hrv_binary: {'accuracy': 0.6786421272270077, 'macro_f1': 0.40428040987394626, 'notes': 'XGB baseline SWELL-HRV binary'}
#   SWELL-HRV binary: acc=0.6786  f1=0.4043  time=0.9s
#   [saved] stress_xgb_wesad-hrv_binary: {'accuracy': 0.9171301106154128, 'macro_f1': 0.9169786085691922, 'notes': 'XGB baseline WESAD-HRV binary'}
#   WESAD-HRV binary: acc=0.9171  f1=0.9170  time=0.3s
#   [saved] stress_xgb_swell-eda_3-class_fixed: {'accuracy': 0.4128003806804663, 'macro_f1': 0.3783337282828841, 'notes': 'XGB baseline SWELL-EDA 3-class (fixed)'}
#   SWELL-EDA 3-class (fixed): acc=0.4128  f1=0.3783  time=0.3s
#   [saved] stress_xgb_swell-eda_binary: {'accuracy': 0.7256721389483702, 'macro_f1': 0.42051564869709085, 'notes': 'XGB baseline SWELL-EDA binary'}
# ...

# %%
# ── Cell 3.3: PyTorch MLP — Architecture Experiment (SWELL-HRV) ──
# Compare 3 architectures on SWELL-HRV (75 features, 3 classes).
# Shallow vs Medium vs Deep; same training budget (50 epochs).

# Uses properly scaled swell_hrv data (scalers applied in cell 3.1)
DEVICE = device if 'device' in dir() else torch.device('cpu')  # alias
if not TORCH_AVAILABLE:
    print("WARNING: PyTorch not available — skipping MLP cells.")
else:
    class StressMLP(nn.Module):
        """Configurable MLP with BatchNorm + ReLU + Dropout for stress detection."""
        def __init__(self, in_dim, hidden_dims, n_classes, dropout=0.3, use_bn=True):
            super().__init__()
            layers = []
            prev = in_dim
            for h in hidden_dims:
                layers.append(nn.Linear(prev, h))
                if use_bn:
                    layers.append(nn.BatchNorm1d(h))
                layers.append(nn.ReLU())
                layers.append(nn.Dropout(dropout))
                prev = h
            layers.append(nn.Linear(prev, n_classes))
            self.net = nn.Sequential(*layers)

        def forward(self, x):
            return self.net(x)

    N_CLASSES_SH = 3
    IN_DIM_SH    = swell_hrv['n_features']  # 75
    EPOCHS_ARCH  = 50
    BATCH_S      = 256  # larger batch for big datasets

    arch_configs = [
        ("Shallow",  [64]),
        ("Medium",   [128, 64]),
        ("Deep",     [256, 128, 64, 32]),
    ]

    sh_loader_tr, sh_loader_vl = make_loaders(
        X_sh_tr, y_sh_tr, X_sh_vl, y_sh_vl, batch=BATCH_S)

    arch_histories = {}
    arch_final     = []

    for arch_name, hidden in arch_configs:
        print(f"\nTraining {arch_name} MLP {[IN_DIM_SH]+hidden+[N_CLASSES_SH]}...")
        torch.manual_seed(42)
        model = StressMLP(IN_DIM_SH, hidden, N_CLASSES_SH, dropout=0.3).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)

        tl_h, vl_h, ta_h, va_h = [], [], [], []
        for epoch in range(1, EPOCHS_ARCH + 1):
            tl, ta = torch_train_epoch(model, sh_loader_tr, criterion, optimizer, device)
            vl, va, vf1 = torch_eval_epoch(model, sh_loader_vl, criterion, device)
            tl_h.append(tl); vl_h.append(vl)
            ta_h.append(ta); va_h.append(va)
            if epoch % 10 == 0:
                print(f"  E{epoch:3d}: tr_loss={tl:.4f} vl_loss={vl:.4f} val_acc={va:.4f} val_f1={vf1:.4f}")

        arch_histories[arch_name] = (tl_h, vl_h, ta_h, va_h)
        arch_final.append({"Architecture": arch_name, "Hidden Dims": str(hidden),
                           "Val Accuracy": round(va,4), "Val Macro-F1": round(vf1,4)})
        save_results(f"stress_mlp_arch_{arch_name.lower()}",
                     {"accuracy": float(va), "macro_f1": float(vf1),
                      "notes": f"StressMLP {arch_name}"})

    # Plot training/val accuracy curves for all 3 architectures
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))
    colors_a = ["tab:blue", "tab:orange", "tab:green"]
    for (arch_name, (tl_h, vl_h, ta_h, va_h)), col in zip(arch_histories.items(), colors_a):
        ep = range(1, EPOCHS_ARCH+1)
        ax1.plot(ep, tl_h, "--", color=col, alpha=0.5)
        ax1.plot(ep, vl_h, "-",  color=col, label=arch_name)
        ax2.plot(ep, ta_h, "--", color=col, alpha=0.5)
        ax2.plot(ep, va_h, "-",  color=col, label=arch_name)
    ax1.set_title("SWELL-HRV — Architecture Loss Curves", fontweight="bold")
    ax1.set_xlabel("Epoch"); ax1.set_ylabel("Loss"); ax1.legend()
    ax2.set_title("SWELL-HRV — Architecture Accuracy Curves", fontweight="bold")
    ax2.set_xlabel("Epoch"); ax2.set_ylabel("Accuracy"); ax2.legend()
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "stress_mlp_arch_comparison.png", bbox_inches="tight")
    plt.show()

    print("\nArchitecture Final Results:")
    print(pd.DataFrame(arch_final).to_string(index=False))

    # Pick best architecture for next experiments
    best_arch_row = max(arch_final, key=lambda r: r["Val Macro-F1"])
    BEST_ARCH_SH  = dict(zip(["Shallow","Medium","Deep"],
                              [[64],[128,64],[256,128,64,32]]))[best_arch_row["Architecture"]]
    print(f"\nBest architecture: {best_arch_row['Architecture']} {BEST_ARCH_SH}")

    # ── Aggressive regularisation search (fix gap=0.70 overfitting) ─────────
    # Root cause: deep MLP memorises 126K train samples; val from diff subjects.
    # Strategy: much simpler arch [64] + very high dropout + very high wd + low LR.
    print('\nAggressive reg search (arch=[64], targeting train-val gap < 0.40)...')
    _agg_cfgs = [
        ('do=0.5 wd=1e-2',  0.5, 1e-2),
        ('do=0.7 wd=1e-2',  0.7, 1e-2),
        ('do=0.5 wd=0.1',   0.5, 0.1),
        ('do=0.7 wd=0.1',   0.7, 0.1),
        ('do=0.5 wd=0.5',   0.5, 0.5),
    ]
    _agg_rows = []
    _best_agg_f1, _best_agg_name = 0.0, None
    for _cname, _do, _wd in _agg_cfgs:
        torch.manual_seed(42)
        _m = StressMLP(IN_DIM_SH, [64], N_CLASSES_SH, dropout=_do, use_bn=True).to(device)
        _o = optim.AdamW(_m.parameters(), lr=2e-4, weight_decay=_wd)
        _c = nn.CrossEntropyLoss(label_smoothing=0.1)
        _bf1, _pat = 0.0, 0
        for _ep in range(150):
            # Add input-noise augmentation: perturbs training samples each epoch
            _m.train()
            for _xb, _yb in sh_loader_tr:
                _xb = _xb.to(device) + 0.05 * torch.randn_like(_xb.to(device))
                _o.zero_grad()
                _c(_m(_xb), _yb.to(device)).backward()
                _o.step()
            _, _va, _vf1 = torch_eval_epoch(_m, sh_loader_vl, _c, device)
            if _vf1 > _bf1: _bf1 = _vf1; _pat = 0
            else:
                _pat += 1
                if _pat >= 25: break
        _, _tra, _ = torch_eval_epoch(_m, sh_loader_tr, _c, device)
        _, _vla, _vf = torch_eval_epoch(_m, sh_loader_vl, _c, device)
        _gap = _tra - _vla
        _agg_rows.append({'Config': _cname, 'Train': round(_tra,4),
                          'Val': round(_vla,4), 'F1': round(_vf,4), 'Gap': round(_gap,4)})
        print(f'  {_cname:18s}: tr={_tra:.4f} vl={_vla:.4f} gap={_gap:.4f} f1={_vf:.4f}')
        if _vf > _best_agg_f1: _best_agg_f1 = _vf; _best_agg_name = _cname
        save_results(f'stress_swell_agg_{_cname[:10].replace(" ","_")}',
                     {'accuracy': float(_vla), 'macro_f1': float(_vf),
                      'train_val_gap': float(_gap), 'notes': f'SWELL aggressive {_cname}'})
    print(f'\nBest aggressive config: {_best_agg_name}  F1={_best_agg_f1:.4f}')
    print(pd.DataFrame(_agg_rows).to_string(index=False))
# Out:
# Training Shallow MLP [75, 64, 3]...
#   E 10: tr_loss=0.2127 vl_loss=8.2486 val_acc=0.2959 val_f1=0.2683
#   E 20: tr_loss=0.1458 vl_loss=10.9872 val_acc=0.3161 val_f1=0.2619
#   E 30: tr_loss=0.1236 vl_loss=11.8137 val_acc=0.2711 val_f1=0.2216
#   E 40: tr_loss=0.1111 vl_loss=12.2084 val_acc=0.3041 val_f1=0.2512
#   E 50: tr_loss=0.1026 vl_loss=11.8643 val_acc=0.3326 val_f1=0.2779
#   [saved] stress_mlp_arch_shallow: {'accuracy': 0.3326199775292922, 'macro_f1': 0.2778622207203662, 'notes': 'StressMLP Shallow'}
#
# Training Medium MLP [75, 128, 64, 3]...
#   E 10: tr_loss=0.1072 vl_loss=10.4452 val_acc=0.3375 val_f1=0.3079
#   E 20: tr_loss=0.0737 vl_loss=12.0301 val_acc=0.2802 val_f1=0.2535
#   E 30: tr_loss=0.0660 vl_loss=11.5528 val_acc=0.3017 val_f1=0.2680
#   E 40: tr_loss=0.0572 vl_loss=12.1821 val_acc=0.3055 val_f1=0.2778
#   E 50: tr_loss=0.0552 vl_loss=12.3085 val_acc=0.3083 val_f1=0.2800
# ...

# %%
# ── Cell 3.4: Optimiser Comparison (SWELL-HRV — Large Data) ──
# Fix medium architecture. Compare 5 optimisers over 50 epochs.

# Uses properly scaled swell_hrv data (scalers applied in cell 3.1)
if not TORCH_AVAILABLE:
    print("WARNING: PyTorch not available — skipping cell 3.4.")
else:
    FIXED_HIDDEN_S = BEST_ARCH_SH

    opt_configs_s = [
        ("SGD",          lambda p: optim.SGD(p, lr=0.01)),
        ("SGD+Momentum", lambda p: optim.SGD(p, lr=0.01, momentum=0.9)),
        ("Adam",         lambda p: optim.Adam(p, lr=1e-3)),
        ("AdamW",        lambda p: optim.AdamW(p, lr=1e-3, weight_decay=1e-4)),
        ("RMSprop",      lambda p: optim.RMSprop(p, lr=1e-3)),
    ]

    EPOCHS_ARCH = 30  # reduced from 50 for speed
    opt_hist_s = {}
    opt_final_s = []

    for opt_name, opt_fn in opt_configs_s:
        print(f"\nSWELL-HRV training with {opt_name}...")
        torch.manual_seed(42)
        model = StressMLP(IN_DIM_SH, FIXED_HIDDEN_S, N_CLASSES_SH, dropout=0.3).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = opt_fn(model.parameters())

        tl_h, vl_h, ta_h, va_h = [], [], [], []
        for epoch in range(1, EPOCHS_ARCH + 1):
            tl, ta = torch_train_epoch(model, sh_loader_tr, criterion, optimizer, device)
            vl, va, vf1 = torch_eval_epoch(model, sh_loader_vl, criterion, device)
            tl_h.append(tl); vl_h.append(vl)
            ta_h.append(ta); va_h.append(va)
            if epoch % 10 == 0:
                print(f"  E{epoch:3d}: tr_loss={tl:.4f} vl_loss={vl:.4f} val_acc={va:.4f} f1={vf1:.4f}")

        opt_hist_s[opt_name] = (tl_h, vl_h, ta_h, va_h)
        opt_final_s.append({"Optimiser": opt_name,
                             "Val Accuracy": round(va,4),
                             "Val Macro-F1": round(vf1,4)})
        save_results(f"stress_opt_{opt_name[:6].lower().replace('+','_')}",
                     {"accuracy": float(va), "macro_f1": float(vf1),
                      "notes": f"StressMLP opt={opt_name}"})

    # Plot loss + accuracy curves
    fig, axes = plt.subplots(1, 2, figsize=(16, 5))
    colors_5 = ["tab:blue","tab:orange","tab:green","tab:red","tab:purple"]
    for (opt_name, (tl_h, vl_h, ta_h, va_h)), col in zip(opt_hist_s.items(), colors_5):
        ep = range(1, EPOCHS_ARCH+1)
        axes[0].plot(ep, vl_h, label=opt_name, color=col)
        axes[1].plot(ep, va_h, label=opt_name, color=col)
    axes[0].set_title("SWELL-HRV — Val Loss by Optimiser", fontweight="bold")
    axes[0].set_xlabel("Epoch"); axes[0].set_ylabel("Val Loss"); axes[0].legend(fontsize=9)
    axes[1].set_title("SWELL-HRV — Val Accuracy by Optimiser", fontweight="bold")
    axes[1].set_xlabel("Epoch"); axes[1].set_ylabel("Val Accuracy"); axes[1].legend(fontsize=9)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "stress_optimiser_comparison.png", bbox_inches="tight")
    plt.show()

    print("\nOptimiser Final Results:")
    opt_df_s = pd.DataFrame(opt_final_s)
    print(opt_df_s.to_string(index=False))

    BEST_OPT_S = opt_df_s.loc[opt_df_s["Val Macro-F1"].idxmax(), "Optimiser"]
    print(f"\nBest optimiser: {BEST_OPT_S}")
# Out:
# SWELL-HRV training with SGD...
#   E 10: tr_loss=0.5258 vl_loss=3.5291 val_acc=0.3379 f1=0.2870
#   E 20: tr_loss=0.3491 vl_loss=4.3006 val_acc=0.2814 f1=0.2456
#   E 30: tr_loss=0.2609 vl_loss=4.8417 val_acc=0.3089 f1=0.2780
#   [saved] stress_opt_sgd: {'accuracy': 0.30894548178267617, 'macro_f1': 0.277979573688071, 'notes': 'StressMLP opt=SGD'}
#
# SWELL-HRV training with SGD+Momentum...
#   E 10: tr_loss=0.2220 vl_loss=5.4267 val_acc=0.3302 f1=0.3023
#   E 20: tr_loss=0.1227 vl_loss=7.4649 val_acc=0.3025 f1=0.2709
#   E 30: tr_loss=0.0937 vl_loss=7.6413 val_acc=0.3317 f1=0.3066
#   [saved] stress_opt_sgd_mo: {'accuracy': 0.3316836980364882, 'macro_f1': 0.3066086435316897, 'notes': 'StressMLP opt=SGD+Momentum'}
#
# SWELL-HRV training with Adam...
#   E 10: tr_loss=0.0690 vl_loss=8.1076 val_acc=0.3022 f1=0.2741
#   E 20: tr_loss=0.0424 vl_loss=9.4245 val_acc=0.3043 f1=0.2773
#   E 30: tr_loss=0.0312 vl_loss=9.7556 val_acc=0.3182 f1=0.2906
# ...

# %%
# ── Cell 3.5: LR Scheduler Experiment (SWELL-HRV) ──
# Fix AdamW. Compare 4 schedules over 60 epochs.
# Plot val loss curves + LR over time.

# Uses properly scaled swell_hrv data (scalers applied in cell 3.1)
if not TORCH_AVAILABLE:
    print("WARNING: PyTorch not available — skipping cell 3.5.")
else:
    EPOCHS_SCH_S = 30

    sch_configs_s = [
        ("No Scheduler",    None),
        ("CosineAnnealing", lambda opt: optim.lr_scheduler.CosineAnnealingLR(opt, T_max=EPOCHS_SCH_S)),
        ("ReduceOnPlateau", lambda opt: optim.lr_scheduler.ReduceLROnPlateau(opt, mode="min", patience=5, factor=0.5)),
    ]

    sch_hist_s = {}
    sch_final_s = []

    for sch_name, sch_fn in sch_configs_s:
        print(f"\nSWELL-HRV training with {sch_name}...")
        torch.manual_seed(42)
        model = StressMLP(IN_DIM_SH, FIXED_HIDDEN_S, N_CLASSES_SH, dropout=0.3).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
        scheduler = sch_fn(optimizer) if sch_fn is not None else None

        tl_h, vl_h, ta_h, va_h, lr_h = [], [], [], [], []
        for epoch in range(1, EPOCHS_SCH_S + 1):
            tl, ta = torch_train_epoch(model, sh_loader_tr, criterion, optimizer, device)
            vl, va, vf1 = torch_eval_epoch(model, sh_loader_vl, criterion, device)
            tl_h.append(tl); vl_h.append(vl)
            ta_h.append(ta); va_h.append(va)
            lr_h.append(optimizer.param_groups[0]["lr"])
            if scheduler is not None:
                if isinstance(scheduler, optim.lr_scheduler.ReduceLROnPlateau):
                    scheduler.step(vl)
                else:
                    scheduler.step()
            if epoch % 15 == 0:
                print(f"  E{epoch:3d}: vl={vl:.4f} va={va:.4f} f1={vf1:.4f} lr={lr_h[-1]:.6f}")

        sch_hist_s[sch_name] = (tl_h, vl_h, ta_h, va_h, lr_h)
        sch_final_s.append({"Scheduler": sch_name,
                             "Val Accuracy": round(va,4),
                             "Best Val F1":  round(max(f1_score(
                                 [1],[1], average="macro"),vf1),4),  # vf1 already computed
                             "Final LR": f"{lr_h[-1]:.6f}"})
        save_results(f"stress_sch_{sch_name[:10].replace(' ','_').lower()}",
                     {"accuracy": float(va), "macro_f1": float(vf1),
                      "notes": f"scheduler={sch_name}"})

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))
    colors_s4 = ["tab:blue","tab:orange","tab:green","tab:red"]
    for (sch_name, (tl_h, vl_h, ta_h, va_h, lr_h)), col in zip(sch_hist_s.items(), colors_s4):
        ep = range(1, EPOCHS_SCH_S+1)
        ax1.plot(ep, vl_h, label=sch_name, color=col)
        ax2.plot(ep, lr_h, label=sch_name, color=col)
    ax1.set_title("SWELL-HRV — Val Loss per Scheduler", fontweight="bold")
    ax1.set_xlabel("Epoch"); ax1.set_ylabel("Val Loss"); ax1.legend(fontsize=9)
    ax2.set_title("SWELL-HRV — LR Over Time", fontweight="bold")
    ax2.set_xlabel("Epoch"); ax2.set_ylabel("Learning Rate"); ax2.legend(fontsize=9)
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "stress_scheduler_comparison.png", bbox_inches="tight")
    plt.show()

    print("\nScheduler Final Results:")
    sch_df_s = pd.DataFrame(sch_final_s)
    print(sch_df_s.to_string(index=False))

    # Best scheduler
    BEST_SCH_S = sch_df_s.loc[sch_df_s["Val Accuracy"].idxmax(), "Scheduler"]
    print(f"\nBest scheduler: {BEST_SCH_S}")
# Out:
# SWELL-HRV training with No Scheduler...
#   E 15: vl=8.3669 va=0.3320 f1=0.3110 lr=0.001000
#   E 30: vl=10.8493 va=0.3112 f1=0.2847 lr=0.001000
#   [saved] stress_sch_no_schedul: {'accuracy': 0.31116580172275426, 'macro_f1': 0.28474461011908603, 'notes': 'scheduler=No Scheduler'}
#
# SWELL-HRV training with CosineAnnealing...
#   E 15: vl=9.0962 va=0.3011 f1=0.2673 lr=0.000552
#   E 30: vl=10.0291 va=0.3038 f1=0.2724 lr=0.000003
#   [saved] stress_sch_cosineanne: {'accuracy': 0.30378256915092827, 'macro_f1': 0.27236090409475866, 'notes': 'scheduler=CosineAnnealing'}
#
# SWELL-HRV training with ReduceOnPlateau...
#   E 15: vl=8.7143 va=0.3040 f1=0.2734 lr=0.000250
#   E 30: vl=9.6007 va=0.3020 f1=0.2697 lr=0.000063
#   [saved] stress_sch_reduceonpl: {'accuracy': 0.30199026269327484, 'macro_f1': 0.26969509632954297, 'notes': 'scheduler=ReduceOnPlateau'}
# Scheduler Final Results:
#       Scheduler  Val Accuracy  Best Val F1 Final LR
# ...

# %%
# ── Cell 3.6: Regularisation Ablation (SWELL-HRV) ──
# 6 configs: progressive addition of Dropout, L2, BatchNorm.
# Measure: val accuracy, val macro-F1, train-val accuracy gap (overfitting indicator).

# Uses properly scaled swell_hrv data (scalers applied in cell 3.1)
if not TORCH_AVAILABLE:
    print("WARNING: PyTorch not available — skipping cell 3.6.")
else:
    EPOCHS_ABL = 30

    abl_configs = [
        # (name,  dropout, weight_decay, use_bn)
        ("No Reg (baseline)",           0.0, 0,    False),
        ("+ Dropout(0.3)",              0.3, 0,    False),
        ("+ L2 (wd=1e-4)",             0.0, 1e-4, False),
        ("+ BatchNorm",                 0.0, 0,    True),
        ("+ Dropout + L2",             0.3, 1e-4, False),
        ("+ Dropout + L2 + BN (Full)", 0.3, 1e-4, True),
    ]

    abl_results = []

    for cfg_name, do, wd, use_bn in abl_configs:
        torch.manual_seed(42)
        model = StressMLP(IN_DIM_SH, FIXED_HIDDEN_S, N_CLASSES_SH,
                          dropout=do, use_bn=use_bn).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=wd)
        for epoch in range(EPOCHS_ABL):
            torch_train_epoch(model, sh_loader_tr, criterion, optimizer, device)

        # Eval on both train and val to measure overfitting gap
        _, tr_acc, tr_f1 = torch_eval_epoch(model, sh_loader_tr, criterion, device)
        _, vl_acc, vl_f1 = torch_eval_epoch(model, sh_loader_vl, criterion, device)
        gap = tr_acc - vl_acc

        abl_results.append({
            "Config":           cfg_name,
            "Train Acc":        round(tr_acc, 4),
            "Val Acc":          round(vl_acc, 4),
            "Val Macro-F1":     round(vl_f1, 4),
            "Train-Val Gap":    round(gap, 4)
        })
        print(f"  [{cfg_name[:30]:30s}] tr_acc={tr_acc:.4f} vl_acc={vl_acc:.4f} gap={gap:.4f} f1={vl_f1:.4f}")
        save_results(f"stress_abl_{cfg_name[:15].replace(' ','_').replace('+','').lower()}",
                     {"accuracy": float(vl_acc), "macro_f1": float(vl_f1),
                      "train_val_gap": float(gap), "notes": cfg_name})

    abl_df = pd.DataFrame(abl_results)
    print("\n" + "="*80)
    print("  SWELL-HRV Regularisation Ablation Results")
    print("="*80)
    print(abl_df.to_string(index=False))

    # Bar chart of val accuracy and gap
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 5))
    labels = [r["Config"].replace(" (Full)","\n(Full)") for r in abl_results]
    x = np.arange(len(labels))
    ax1.bar(x, abl_df["Val Acc"], color="steelblue")
    ax1.set_xticks(x); ax1.set_xticklabels(labels, rotation=30, ha="right", fontsize=8)
    ax1.set_title("Val Accuracy by Regularisation Config", fontweight="bold")
    ax1.set_ylabel("Val Accuracy")
    ax2.bar(x, abl_df["Train-Val Gap"], color="tomato")
    ax2.set_xticks(x); ax2.set_xticklabels(labels, rotation=30, ha="right", fontsize=8)
    ax2.set_title("Train-Val Gap (lower = less overfitting)", fontweight="bold")
    ax2.set_ylabel("Train Acc - Val Acc")
    plt.tight_layout()
    plt.savefig(OUTPUT_DIR / "stress_reg_ablation.png", bbox_inches="tight")
    plt.show()
# Out:
#   [No Reg (baseline)             ] tr_acc=0.9981 vl_acc=0.3067 gap=0.6914 f1=0.2835
#   [saved] stress_abl_no_reg_(baselin: {'accuracy': 0.3066984109999465, 'macro_f1': 0.2834994186249243, 'train_val_gap': 0.6913899660163418, 'notes': 'No Reg (baseline)'}
#   [+ Dropout(0.3)                ] tr_acc=0.9938 vl_acc=0.2961 gap=0.6977 f1=0.2674
#   [saved] stress_abl__dropout(0.3): {'accuracy': 0.2960515756246322, 'macro_f1': 0.26743285724917054, 'train_val_gap': 0.6977238007755131, 'notes': '+ Dropout(0.3)'}
#   [+ L2 (wd=1e-4)                ] tr_acc=0.9977 vl_acc=0.3142 gap=0.6835 f1=0.2900
#   [saved] stress_abl__l2_(wd=1e-4): {'accuracy': 0.3142421486276818, 'macro_f1': 0.2899520344470385, 'train_val_gap': 0.6834828620363307, 'notes': '+ L2 (wd=1e-4)'}
#   [+ BatchNorm                   ] tr_acc=0.9992 vl_acc=0.3371 gap=0.6621 f1=0.3191
# ...

# %%
# Cell 3.6b: SWELL-HRV — XGBoost Tuned + SMOTE (3-class stress)
# Addresses MLP overfitting problem: train-val gap=0.69, best MLP F1=0.319
# XGBoost + SMOTE + tuned depth/regularisation targets F1 > 0.55

import numpy as np, time
import torch
from pathlib import Path
from sklearn.metrics import f1_score, accuracy_score, classification_report

print('=' * 65)
print('  CELL 3.6b — SWELL-HRV: XGBoost Tuned + SMOTE (3-class)')
print('=' * 65)

# Load SWELL-HRV data from aliases set in Cell 3.1
_swell_ok = all(k in dir() for k in ['X_sh_tr', 'y_sh_tr', 'X_sh_vl', 'y_sh_vl',
                                      'X_sh_te', 'y_sh_te'])
if not _swell_ok:
    # Try dict access
    _swell_ok = 'swell_hrv' in dir()

if not _swell_ok:
    print('[SKIP] SWELL-HRV data not found — run Cell 3.1 first.')
else:
    if 'X_sh_tr' in dir():
        _Xs_tr, _ys_tr = X_sh_tr, y_sh_tr
        _Xs_vl, _ys_vl = X_sh_vl, y_sh_vl
        _Xs_te, _ys_te = X_sh_te, y_sh_te
    else:
        _Xs_tr, _ys_tr = swell_hrv['X_train'], swell_hrv['y_train']
        _Xs_vl, _ys_vl = swell_hrv['X_val'],   swell_hrv['y_val']
        _Xs_te, _ys_te = swell_hrv['X_test'],   swell_hrv['y_test']

    print(f'  SWELL-HRV: train{_Xs_tr.shape} val{_Xs_vl.shape} test{_Xs_te.shape}')
    print(f'  Class dist train: {np.bincount(_ys_tr.astype(int))}')

    # SMOTE to balance 3 classes on training set
    try:
        from imblearn.over_sampling import SMOTE as _SMOTE_s
        _min_cls = int(np.bincount(_ys_tr.astype(int)).min())
        _k_s = min(5, _min_cls - 1)
        _sms = _SMOTE_s(random_state=42, k_neighbors=max(1, _k_s))
        _Xs_tr_sm, _ys_tr_sm = _sms.fit_resample(_Xs_tr, _ys_tr.astype(int))
        print(f'  SMOTE: {_Xs_tr.shape} -> {_Xs_tr_sm.shape}  '
              f'dist: {np.bincount(_ys_tr_sm)}')
        _smote_sw_ok = True
    except Exception as _swe:
        print(f'  [WARN] SMOTE failed ({_swe}), using original data')
        _Xs_tr_sm, _ys_tr_sm = _Xs_tr, _ys_tr.astype(int)
        _smote_sw_ok = False

    _Xs_tv   = np.concatenate([_Xs_tr, _Xs_vl])
    _ys_tv   = np.concatenate([_ys_tr, _ys_vl]).astype(int)
    _ys_tr_i = _ys_tr.astype(int)
    _ys_vl_i = _ys_vl.astype(int)
    _ys_te_i = _ys_te.astype(int)

    # ── XGBoost tuned sweep on val ──
    from xgboost import XGBClassifier
    _dev_sw = 'cuda' if torch.cuda.is_available() else 'cpu'
    _configs = [
        dict(n_estimators=500, max_depth=4, learning_rate=0.05,
             subsample=0.8, colsample_bytree=0.7,
             min_child_weight=5, reg_alpha=0.1, reg_lambda=1.5),
        dict(n_estimators=300, max_depth=3, learning_rate=0.1,
             subsample=0.8, colsample_bytree=0.8,
             min_child_weight=10, reg_alpha=0.5, reg_lambda=2.0),
        dict(n_estimators=700, max_depth=3, learning_rate=0.03,
             subsample=0.7, colsample_bytree=0.6,
             min_child_weight=20, reg_alpha=1.0, reg_lambda=2.0),
    ]
    _best_vf1_sw, _best_cfg_sw = 0.0, None
    print('\n  Tuning XGBoost configs (val F1):')
    for _ci, _cfg in enumerate(_configs):
        _xgb_sw = XGBClassifier(**_cfg, objective='multi:softprob', num_class=3,
                                 eval_metric='mlogloss', tree_method='hist',
                                 random_state=42, device=_dev_sw)
        _xgb_sw.fit(_Xs_tr_sm, _ys_tr_sm, verbose=False)
        _vp_sw = _xgb_sw.predict(_Xs_vl)
        _vf_sw = f1_score(_ys_vl_i, _vp_sw, average='macro')
        print(f'    config {_ci+1}: val F1={_vf_sw:.4f}  (depth={_cfg["max_depth"]} lr={_cfg["learning_rate"]})')
        if _vf_sw > _best_vf1_sw:
            _best_vf1_sw, _best_cfg_sw = _vf_sw, _cfg

    print(f'  Best config: depth={_best_cfg_sw["max_depth"]} lr={_best_cfg_sw["learning_rate"]}  val F1={_best_vf1_sw:.4f}')

    # Retrain best config on train+val with SMOTE
    try:
        _min_tv = int(np.bincount(_ys_tv).min())
        _k_tv   = min(5, _min_tv - 1)
        _smtv   = _SMOTE_s(random_state=42, k_neighbors=max(1, _k_tv))
        _Xs_tv_sm, _ys_tv_sm = _smtv.fit_resample(_Xs_tv, _ys_tv)
    except Exception:
        _Xs_tv_sm, _ys_tv_sm = _Xs_tv, _ys_tv

    _xgb_final_sw = XGBClassifier(**_best_cfg_sw, objective='multi:softprob', num_class=3,
                                   eval_metric='mlogloss', tree_method='hist',
                                   random_state=42, device=_dev_sw)
    _t0_sw = time.time()
    _xgb_final_sw.fit(_Xs_tv_sm, _ys_tv_sm, verbose=False)
    _pt_sw  = _xgb_final_sw.predict(_Xs_te)
    _tf_sw  = f1_score(_ys_te_i, _pt_sw, average='macro')
    _ta_sw  = accuracy_score(_ys_te_i, _pt_sw)
    print(f'  Final (train+val+SMOTE -> test): F1={_tf_sw:.4f}  Acc={_ta_sw:.4f}  ({time.time()-_t0_sw:.1f}s)')
    print(classification_report(_ys_te_i, _pt_sw, target_names=['Low', 'Med', 'High']))

    RESULTS['swell_hrv_xgb_smote'] = {
        'model': 'XGBoost+SMOTE', 'feature': 'HRV 75-feat', 'dataset': 'SWELL-HRV 3-class',
        'test_macro_f1': round(_tf_sw, 4), 'test_accuracy': round(_ta_sw, 4)}

    # ── Also fix SWELL-HRV binary (was 0.4043 F1 — suspicious low for binary) ──
    print('\n  SWELL-HRV Binary (low/high stress vs medium):')
    _ys_tr_bin = (swell_hrv['binary']['y_train'] if 'swell_hrv' in dir()
                  else ((_ys_tr >= 2).astype(int)))
    _ys_vl_bin = (swell_hrv['binary']['y_val'] if 'swell_hrv' in dir()
                  else ((_ys_vl >= 2).astype(int)))
    _ys_te_bin = (swell_hrv['binary']['y_test'] if 'swell_hrv' in dir()
                  else ((_ys_te >= 2).astype(int)))
    _Xs_tr_bin = (swell_hrv['binary']['X_train'] if 'swell_hrv' in dir() else _Xs_tr)
    _Xs_vl_bin = (swell_hrv['binary']['X_val']   if 'swell_hrv' in dir() else _Xs_vl)
    _Xs_te_bin = (swell_hrv['binary']['X_test']  if 'swell_hrv' in dir() else _Xs_te)
    _Xs_tv_bin = np.concatenate([_Xs_tr_bin, _Xs_vl_bin])
    _ys_tv_bin = np.concatenate([_ys_tr_bin, _ys_vl_bin])
    _spw_sw    = float((_ys_tv_bin == 0).sum()) / max((_ys_tv_bin == 1).sum(), 1)
    try:
        _sm_bin = _SMOTE_s(random_state=42, k_neighbors=min(5, int((_ys_tr_bin==1).sum())-1))
        _Xs_bin_sm, _ys_bin_sm = _sm_bin.fit_resample(_Xs_tr_bin, _ys_tr_bin)
    except Exception:
        _Xs_bin_sm, _ys_bin_sm = _Xs_tr_bin, _ys_tr_bin
    _xgb_bin_sw = XGBClassifier(n_estimators=400, max_depth=3, learning_rate=0.05,
                                  scale_pos_weight=_spw_sw, subsample=0.8, colsample_bytree=0.7,
                                  eval_metric='aucpr', tree_method='hist', random_state=42,
                                  device=_dev_sw)
    _xgb_bin_sw.fit(np.concatenate([_Xs_bin_sm, _Xs_vl_bin]),
                    np.concatenate([_ys_bin_sm, _ys_vl_bin]), verbose=False)
    _pt_bin_sw = _xgb_bin_sw.predict(_Xs_te_bin)
    _tf_bin    = f1_score(_ys_te_bin, _pt_bin_sw, average='macro')
    _ta_bin    = accuracy_score(_ys_te_bin, _pt_bin_sw)
    print(f'  XGBoost+SMOTE binary: F1={_tf_bin:.4f}  Acc={_ta_bin:.4f}  (baseline was 0.4043)')
    RESULTS['swell_hrv_xgb_smote_binary'] = {
        'model': 'XGBoost+SMOTE', 'feature': 'HRV 75-feat', 'dataset': 'SWELL-HRV binary',
        'test_macro_f1': round(_tf_bin, 4), 'test_accuracy': round(_ta_bin, 4)}

    print('\n  Summary:')
    print(f'    MLP best 3-class F1  = 0.3191  (BatchNorm, severe overfitting)')
    print(f'    XGBoost+SMOTE 3-class F1 = {_tf_sw:.4f}')
    print(f'    XGBoost binary baseline F1 = 0.4043')
    print(f'    XGBoost+SMOTE binary F1    = {_tf_bin:.4f}')
    print('[DONE] swell_hrv_xgb_smote results added to RESULTS.')
# Out:
# ...
#   CELL 3.6b — SWELL-HRV: XGBoost Tuned + SMOTE (3-class)
# ...
#   SWELL-HRV: train(126594, 75) val(37382, 75) test(40909, 75)
#   Class dist train: [43449 40725 42420]
#   SMOTE: (126594, 75) -> (130347, 75)  dist: [43449 43449 43449]
#
#   Tuning XGBoost configs (val F1):
#     config 1: val F1=0.3347  (depth=4 lr=0.05)
#     config 2: val F1=0.3372  (depth=3 lr=0.1)
#     config 3: val F1=0.3630  (depth=3 lr=0.03)
#   Best config: depth=3 lr=0.03  val F1=0.3630
#   Final (train+val+SMOTE -> test): F1=0.3294  Acc=0.3515  (6.1s)
#               precision    recall  f1-score   support
#
#          Low       0.35      0.56      0.43     12833
#          Med       0.41      0.38      0.40     14681
#         High       0.24      0.12      0.16     13395
#
#     accuracy                           0.35     40909
#    macro avg       0.33      0.35      0.33     40909
# weighted avg       0.34      0.35      0.33     40909
#
#
#   SWELL-HRV Binary (low/high stress vs medium):
# ...

# %%
# ── Cell 3.7: Apply Best Stress Config to WESAD-HRV (binary stress, 81K samples) ──
# Transfer best architecture + regularisation to WESAD-HRV binary classification.

# Uses properly scaled wesad_hrv data (scalers applied in cell 3.1)
if not TORCH_AVAILABLE:
    print("WARNING: PyTorch not available — skipping cell 3.7.")
else:
    # Self-healing: reload if kernel was restarted after cell 3.1
    if 'wesad_hrv' not in dir() or wesad_hrv is None:
        print("wesad_hrv not found — reloading from disk...")
        wesad_hrv = load_stress_dataset('wesad', 'hrv', 'class')
        X_wh_tr, y_wh_tr = wesad_hrv['X_train'], wesad_hrv['y_train']
        X_wh_vl, y_wh_vl = wesad_hrv['X_val'],   wesad_hrv['y_val']
        X_wh_te, y_wh_te = wesad_hrv['X_test'],  wesad_hrv['y_test']
    if 'FIXED_HIDDEN_S' not in dir():
        FIXED_HIDDEN_S = [128, 64]
        print("FIXED_HIDDEN_S not found — using default [128, 64]")
    IN_DIM_WH    = wesad_hrv['n_features']   # 40
    N_CLASSES_WH = 2

    wh_loader_tr, wh_loader_vl = make_loaders(
        X_wh_tr, y_wh_tr, X_wh_vl, y_wh_vl, batch=256)

    print(f"WESAD-HRV: in_dim={IN_DIM_WH}, n_classes={N_CLASSES_WH}")
    print(f"Using best SWELL config: arch={FIXED_HIDDEN_S}, dropout=0.3, wd=1e-4, AdamW")

    # ── Architecture search ───────────────────────────────────────────────
    _wh_archs = {
        'SWELL-best': FIXED_HIDDEN_S,
        'Wider':      [128, 64],
        'Deep':       [128, 64, 32],
        'Deeper':     [256, 128, 64],
        'Shallow':    [64],
    }
    _wh_best_f1, _wh_best_arch_name, _wh_best_hidden = 0.0, 'SWELL-best', FIXED_HIDDEN_S
    print('WESAD-HRV architecture search...')
    for _aname, _ahid in _wh_archs.items():
        torch.manual_seed(42)
        _m = StressMLP(IN_DIM_WH, _ahid, N_CLASSES_WH, dropout=0.3, use_bn=True).to(device)
        _o = optim.AdamW(_m.parameters(), lr=1e-3, weight_decay=1e-4)
        _s = optim.lr_scheduler.CosineAnnealingLR(_o, T_max=100)
        _crit = nn.CrossEntropyLoss()
        _bf1, _pat = 0.0, 0
        for _ep in range(100):
            torch_train_epoch(_m, wh_loader_tr, _crit, _o, device)
            _, _va, _vf1 = torch_eval_epoch(_m, wh_loader_vl, _crit, device)
            _s.step()
            if _vf1 > _bf1: _bf1 = _vf1; _pat = 0
            else:
                _pat += 1
                if _pat >= 20: break
        print(f'  {_aname:15s} {str(_ahid):22s} val_F1={_bf1:.4f}')
        if _bf1 > _wh_best_f1:
            _wh_best_f1, _wh_best_arch_name, _wh_best_hidden = _bf1, _aname, _ahid
    print(f'Best WESAD-HRV arch: {_wh_best_arch_name} {_wh_best_hidden}  F1={_wh_best_f1:.4f}')

    # ── Full training with best arch (100 epochs + early stopping) ──────────
    print(f'\nFull training: {_wh_best_arch_name} {_wh_best_hidden}, AdamW, CosineAnneal')
    torch.manual_seed(42)
    model_wh = StressMLP(IN_DIM_WH, _wh_best_hidden, N_CLASSES_WH,
                          dropout=0.3, use_bn=True).to(device)
    criterion_wh = nn.CrossEntropyLoss()
    optimizer_wh = optim.AdamW(model_wh.parameters(), lr=1e-3, weight_decay=1e-4)
    scheduler_wh = optim.lr_scheduler.CosineAnnealingLR(optimizer_wh, T_max=100)

    tl_h, vl_h, ta_h, va_h = [], [], [], []
    _best_val_f1_wh, _pat_wh = 0.0, 0
    for epoch in range(1, 101):
        tl, ta = torch_train_epoch(model_wh, wh_loader_tr, criterion_wh, optimizer_wh, device)
        vl, va, vf1 = torch_eval_epoch(model_wh, wh_loader_vl, criterion_wh, device)
        tl_h.append(tl); vl_h.append(vl)
        ta_h.append(ta); va_h.append(va)
        scheduler_wh.step()
        if vf1 > _best_val_f1_wh: _best_val_f1_wh = vf1; _pat_wh = 0
        else:
            _pat_wh += 1
            if _pat_wh >= 20: break
        if epoch % 20 == 0:
            print(f"  E{epoch:3d}: vl={vl:.4f} va={va:.4f} f1={vf1:.4f}")

    # Final test evaluation
    wh_loader_te = DataLoader(
        TensorDataset(torch.tensor(X_wh_te, dtype=torch.float32),
                      torch.tensor(y_wh_te, dtype=torch.long)),
        batch_size=256, shuffle=False)
    _, te_acc, te_f1 = torch_eval_epoch(model_wh, wh_loader_te, criterion_wh, device)
    print(f"\nWESAD-HRV Test: accuracy={te_acc:.4f}  macro-F1={te_f1:.4f}")

    plot_training_curves(tl_h, vl_h, ta_h, va_h,
                         title="WESAD-HRV MLP (best config)",
                         save_path=OUTPUT_DIR / "wesad_hrv_best_training.png")

    save_results("stress_wesad_hrv_mlp_test",
                 {"accuracy": float(te_acc), "macro_f1": float(te_f1),
                  "notes": f"WESAD-HRV MLP best arch={_wh_best_arch_name} {_wh_best_hidden}"})
# Out:
# WESAD-HRV: in_dim=40, n_classes=2
# Using best SWELL config: arch=[256, 128, 64, 32], dropout=0.3, wd=1e-4, AdamW
# WESAD-HRV architecture search...
#   SWELL-best      [256, 128, 64, 32]     val_F1=0.8097
#   Wider           [128, 64]              val_F1=0.8536
#   Deep            [128, 64, 32]          val_F1=0.8085
#   Deeper          [256, 128, 64]         val_F1=0.8288
#   Shallow         [64]                   val_F1=0.8041
# Best WESAD-HRV arch: Wider [128, 64]  F1=0.8536
#
# Full training: Wider [128, 64], AdamW, CosineAnneal
#   E 20: vl=1.4118 va=0.7229 f1=0.7028
#
# WESAD-HRV Test: accuracy=0.7409  macro-F1=0.7409
#   [saved] stress_wesad_hrv_mlp_test: {'accuracy': 0.7408633799362276, 'macro_f1': 0.7408621171364339, 'notes': 'WESAD-HRV MLP best arch=Wider [128, 64]'}

# %%
# ── Cell 3.7b: WESAD-EDA MLP Experiment (binary stress, 20K samples, 45 features) ──
# WESAD-EDA was only given XGB baseline before. Now fully experiment with MLP.
if not TORCH_AVAILABLE:
    print("PyTorch not available — skipping.")
else:
    # Self-healing: reload if kernel was restarted after cell 3.1
    if 'wesad_eda' not in dir() or wesad_eda is None:
        print("wesad_eda not found — reloading from disk...")
        wesad_eda = load_stress_dataset('wesad', 'eda', 'class')
    eda_in  = wesad_eda['n_features']   # 45
    eda_cls = wesad_eda['n_classes']     # 2

    tr_ld_eda, vl_ld_eda = make_loaders(
        wesad_eda['X_train'], wesad_eda['y_train'],
        wesad_eda['X_val'],   wesad_eda['y_val'], batch=256)

    print(f"WESAD-EDA: in_dim={eda_in}, n_classes={eda_cls}, train={wesad_eda['X_train'].shape}")

    # Quick architecture search
    archs = {'Shallow':[32], 'Medium':[64,32], 'Deep':[128,64,32]}
    eda_results = []
    for arch_name, hidden in archs.items():
        torch.manual_seed(42)
        model = StressMLP(eda_in, hidden, eda_cls, dropout=0.3, use_bn=False).to(DEVICE)
        opt   = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
        crit  = nn.CrossEntropyLoss()
        best_f1, patience, wait = 0, 15, 0
        for ep in range(80):
            torch_train_epoch(model, tr_ld_eda, crit, opt, DEVICE)
            vl_loss, vl_acc, vl_f1 = torch_eval_epoch(model, vl_ld_eda, crit, DEVICE)
            if vl_f1 > best_f1:
                best_f1 = vl_f1; wait = 0
            else:
                wait += 1
                if wait >= patience: break
        eda_results.append((arch_name, hidden, best_f1))
        print(f"  {arch_name} {hidden}: best val F1={best_f1:.4f}")
        save_results(f'stress_wesad_eda_mlp_{arch_name.lower()}',
                     {'macro_f1': best_f1, 'notes': f'WESAD-EDA MLP {arch_name}'})

    # Best on test
    best_arch = max(eda_results, key=lambda x: x[2])
    print(f"\nBest WESAD-EDA arch: {best_arch[0]} {best_arch[1]}  val F1={best_arch[2]:.4f}")

    # Final test evaluation
    torch.manual_seed(42)
    best_model = StressMLP(eda_in, best_arch[1], eda_cls, dropout=0.3, use_bn=False).to(DEVICE)
    opt2 = optim.AdamW(best_model.parameters(), lr=1e-3, weight_decay=1e-4)
    crit2 = nn.CrossEntropyLoss()
    te_ld_eda = DataLoader(TensorDataset(
        torch.tensor(wesad_eda['X_test'], dtype=torch.float32),
        torch.tensor(wesad_eda['y_test'], dtype=torch.long)), batch_size=256)
    for ep in range(60):
        torch_train_epoch(best_model, tr_ld_eda, crit2, opt2, DEVICE)
    _, te_acc, te_f1 = torch_eval_epoch(best_model, te_ld_eda, crit2, DEVICE)
    print(f"WESAD-EDA Test: acc={te_acc:.4f}  F1={te_f1:.4f}")
    save_results('stress_wesad_eda_mlp_test', {'accuracy': te_acc, 'macro_f1': te_f1,
                  'notes': 'WESAD-EDA MLP best arch test'})
# Out:
# WESAD-EDA: in_dim=45, n_classes=2, train=(12322, 45)
#   Shallow [32]: best val F1=0.6590
#   [saved] stress_wesad_eda_mlp_shallow: {'macro_f1': 0.6590195406079352, 'notes': 'WESAD-EDA MLP Shallow'}
#   Medium [64, 32]: best val F1=0.7088
#   [saved] stress_wesad_eda_mlp_medium: {'macro_f1': 0.7087639435121555, 'notes': 'WESAD-EDA MLP Medium'}
#   Deep [128, 64, 32]: best val F1=0.6164
#   [saved] stress_wesad_eda_mlp_deep: {'macro_f1': 0.6163759583718248, 'notes': 'WESAD-EDA MLP Deep'}
#
# Best WESAD-EDA arch: Medium [64, 32]  val F1=0.7088
# WESAD-EDA Test: acc=0.5542  F1=0.5521
#   [saved] stress_wesad_eda_mlp_test: {'accuracy': 0.5541780312422514, 'macro_f1': 0.5521258066428834, 'notes': 'WESAD-EDA MLP best arch test'}

# %% [markdown]
# ## Cell 3.8 — Stress Detection Summary

# %%
# ── Cell 3.7c: Stress Regression — SWELL + WESAD Continuous Intensity ──
# Predict exact stress intensity scores using MLP regression.
# SWELL-HRV: continuous 26-90; WESAD-HRV/EDA: binary-ish continuous labels.
if not TORCH_AVAILABLE:
    print("PyTorch not available — skipping.")
else:
    # Regression MLP
    class StressRegressorMLP(nn.Module):
        def __init__(self, in_dim, hidden_dims, dropout=0.3):
            super().__init__()
            layers = []
            prev = in_dim
            for h in hidden_dims:
                layers += [nn.Linear(prev, h), nn.ReLU(), nn.Dropout(dropout)]
                prev = h
            layers.append(nn.Linear(prev, 1))
            self.net = nn.Sequential(*layers)
        def forward(self, x): return self.net(x).squeeze(1)

    regre_in = swell_hrv_regre['X_train'].shape[1]  # 75

    # DataLoaders for regression
    def make_regre_loaders(X_tr, y_tr, X_vl, y_vl, batch=512):
        tr_ds = TensorDataset(torch.tensor(X_tr, dtype=torch.float32),
                              torch.tensor(y_tr, dtype=torch.float32))
        vl_ds = TensorDataset(torch.tensor(X_vl, dtype=torch.float32),
                              torch.tensor(y_vl, dtype=torch.float32))
        return (DataLoader(tr_ds, batch_size=batch, shuffle=True),
                DataLoader(vl_ds, batch_size=batch, shuffle=False))

    tr_ld_r, vl_ld_r = make_regre_loaders(
        swell_hrv_regre['X_train'], swell_hrv_regre['y_train'],
        swell_hrv_regre['X_val'],   swell_hrv_regre['y_val'])

    # ── SWELL-HRV regression: compare MSE vs Huber ──
    results_regre = []
    for loss_name, crit_fn in [('MSE', nn.MSELoss()), ('Huber_delta5', nn.HuberLoss(delta=5.0))]:
        torch.manual_seed(42)
        model = StressRegressorMLP(regre_in, [128, 64, 32], dropout=0.3).to(DEVICE)
        opt_r = optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-4)
        best_rmse, patience_r, wait_r = float('inf'), 10, 0
        for ep in range(40):
            model.train()
            for Xb, yb in tr_ld_r:
                Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
                opt_r.zero_grad(); loss = crit_fn(model(Xb), yb); loss.backward(); opt_r.step()
            model.eval()
            preds, trues = [], []
            with torch.no_grad():
                for Xb, yb in vl_ld_r:
                    preds.extend(model(Xb.to(DEVICE)).cpu().numpy())
                    trues.extend(yb.numpy())
            rmse = float(np.sqrt(np.mean((np.array(preds) - np.array(trues))**2)))
            if rmse < best_rmse:
                best_rmse = rmse; wait_r = 0
            else:
                wait_r += 1
                if wait_r >= patience_r: break
            if (ep+1) % 20 == 0:
                print(f"  [SWELL-HRV {loss_name}] Ep {ep+1}: val RMSE={rmse:.3f}")
        mae = float(np.mean(np.abs(np.array(preds) - np.array(trues))))
        results_regre.append(('SWELL-HRV ' + loss_name, best_rmse, mae))
        save_results(f'stress_swell_hrv_regre_{loss_name}',
                     {'rmse': best_rmse, 'mae': mae, 'notes': f'SWELL-HRV regression {loss_name}'})

    print("\nSWELL-HRV Stress Regression Results:")
    for rn, rmse, mae in results_regre:
        print(f"  {rn}: RMSE={rmse:.3f}  MAE={mae:.3f}")

    # ── SWELL-EDA regression ──
    print("\nSWELL-EDA Stress Regression:")
    tr_ld_e, vl_ld_e = make_regre_loaders(
        swell_eda_regre['X_train'], swell_eda_regre['y_train'],
        swell_eda_regre['X_val'],   swell_eda_regre['y_val'])
    torch.manual_seed(42)
    m_eda = StressRegressorMLP(swell_eda_regre['X_train'].shape[1], [64, 32], dropout=0.3).to(DEVICE)
    opt_e = optim.AdamW(m_eda.parameters(), lr=1e-3, weight_decay=1e-4)
    best_rmse_e, patience_e, wait_e = float('inf'), 10, 0
    for ep in range(40):
        m_eda.train()
        for Xb, yb in tr_ld_e:
            Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
            opt_e.zero_grad(); loss = nn.HuberLoss(delta=5.0)(m_eda(Xb), yb); loss.backward(); opt_e.step()
        m_eda.eval()
        preds_e, trues_e = [], []
        with torch.no_grad():
            for Xb, yb in vl_ld_e:
                preds_e.extend(m_eda(Xb.to(DEVICE)).cpu().numpy()); trues_e.extend(yb.numpy())
        rmse_e = float(np.sqrt(np.mean((np.array(preds_e) - np.array(trues_e))**2)))
        if rmse_e < best_rmse_e:
            best_rmse_e = rmse_e; wait_e = 0
        else:
            wait_e += 1
            if wait_e >= patience_e: break
    mae_e = float(np.mean(np.abs(np.array(preds_e) - np.array(trues_e))))
    print(f"  SWELL-EDA: RMSE={best_rmse_e:.3f}  MAE={mae_e:.3f}")
    save_results('stress_swell_eda_regre_mlp', {'rmse': best_rmse_e, 'mae': mae_e, 'notes': 'SWELL-EDA regression Huber MLP'})

    # ── WESAD-HRV regression ──
    print("\nWESAD-HRV Stress Regression:")
    tr_ld_wh, vl_ld_wh = make_regre_loaders(
        wesad_hrv_regre['X_train'], wesad_hrv_regre['y_train'],
        wesad_hrv_regre['X_val'],   wesad_hrv_regre['y_val'])
    torch.manual_seed(42)
    m_wh = StressRegressorMLP(wesad_hrv_regre['X_train'].shape[1], [128, 64], dropout=0.3).to(DEVICE)
    opt_wh = optim.AdamW(m_wh.parameters(), lr=1e-3, weight_decay=1e-4)
    best_rmse_wh, patience_wh, wait_wh = float('inf'), 10, 0
    for ep in range(40):
        m_wh.train()
        for Xb, yb in tr_ld_wh:
            Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
            opt_wh.zero_grad(); loss = nn.HuberLoss(delta=1.0)(m_wh(Xb), yb); loss.backward(); opt_wh.step()
        m_wh.eval()
        preds_wh, trues_wh = [], []
        with torch.no_grad():
            for Xb, yb in vl_ld_wh:
                preds_wh.extend(m_wh(Xb.to(DEVICE)).cpu().numpy()); trues_wh.extend(yb.numpy())
        rmse_wh = float(np.sqrt(np.mean((np.array(preds_wh) - np.array(trues_wh))**2)))
        if rmse_wh < best_rmse_wh:
            best_rmse_wh = rmse_wh; wait_wh = 0
        else:
            wait_wh += 1
            if wait_wh >= patience_wh: break
    mae_wh = float(np.mean(np.abs(np.array(preds_wh) - np.array(trues_wh))))
    print(f"  WESAD-HRV: RMSE={best_rmse_wh:.3f}  MAE={mae_wh:.3f}")
    save_results('stress_wesad_hrv_regre_mlp', {'rmse': best_rmse_wh, 'mae': mae_wh, 'notes': 'WESAD-HRV regression Huber MLP'})

    # ── WESAD-EDA regression ──
    print("\nWESAD-EDA Stress Regression:")
    tr_ld_we, vl_ld_we = make_regre_loaders(
        wesad_eda_regre['X_train'], wesad_eda_regre['y_train'],
        wesad_eda_regre['X_val'],   wesad_eda_regre['y_val'])
    torch.manual_seed(42)
    m_we = StressRegressorMLP(wesad_eda_regre['X_train'].shape[1], [64, 32], dropout=0.3).to(DEVICE)
    opt_we = optim.AdamW(m_we.parameters(), lr=1e-3, weight_decay=1e-4)
    best_rmse_we, patience_we, wait_we = float('inf'), 10, 0
    for ep in range(40):
        m_we.train()
        for Xb, yb in tr_ld_we:
            Xb, yb = Xb.to(DEVICE), yb.to(DEVICE)
            opt_we.zero_grad(); loss = nn.HuberLoss(delta=1.0)(m_we(Xb), yb); loss.backward(); opt_we.step()
        m_we.eval()
        preds_we, trues_we = [], []
        with torch.no_grad():
            for Xb, yb in vl_ld_we:
                preds_we.extend(m_we(Xb.to(DEVICE)).cpu().numpy()); trues_we.extend(yb.numpy())
        rmse_we = float(np.sqrt(np.mean((np.array(preds_we) - np.array(trues_we))**2)))
        if rmse_we < best_rmse_we:
            best_rmse_we = rmse_we; wait_we = 0
        else:
            wait_we += 1
            if wait_we >= patience_we: break
    mae_we = float(np.mean(np.abs(np.array(preds_we) - np.array(trues_we))))
    print(f"  WESAD-EDA: RMSE={best_rmse_we:.3f}  MAE={mae_we:.3f}")
    save_results('stress_wesad_eda_regre_mlp', {'rmse': best_rmse_we, 'mae': mae_we, 'notes': 'WESAD-EDA regression Huber MLP'})

    # ── Summary ──
    print("\n=== Stress Regression Summary ===")
    _regre_summary = [
        ('SWELL-HRV MSE',      results_regre[0][1], results_regre[0][2]),
        ('SWELL-HRV Huber',    results_regre[1][1], results_regre[1][2]),
        ('SWELL-EDA Huber',    best_rmse_e,         mae_e),
        ('WESAD-HRV Huber',    best_rmse_wh,        mae_wh),
        ('WESAD-EDA Huber',    best_rmse_we,        mae_we),
    ]
    print(f"  {'Dataset':<22} {'RMSE':>8} {'MAE':>8}")
    for name, rmse, mae in _regre_summary:
        print(f"  {name:<22} {rmse:>8.3f} {mae:>8.3f}")
# Out:
#   [saved] stress_swell_hrv_regre_MSE: {'rmse': 10.176373481750488, 'mae': 9.786590576171875, 'notes': 'SWELL-HRV regression MSE'}
#   [SWELL-HRV Huber_delta5] Ep 20: val RMSE=12.476
#   [saved] stress_swell_hrv_regre_Huber_delta5: {'rmse': 10.08147144317627, 'mae': 10.085274696350098, 'notes': 'SWELL-HRV regression Huber_delta5'}
#
# SWELL-HRV Stress Regression Results:
#   SWELL-HRV MSE: RMSE=10.176  MAE=9.787
#   SWELL-HRV Huber_delta5: RMSE=10.081  MAE=10.085
#
# SWELL-EDA Stress Regression:
#   SWELL-EDA: RMSE=12.865  MAE=11.246
#   [saved] stress_swell_eda_regre_mlp: {'rmse': 12.86451530456543, 'mae': 11.246285438537598, 'notes': 'SWELL-EDA regression Huber MLP'}
#
# WESAD-HRV Stress Regression:
#   WESAD-HRV: RMSE=1.090  MAE=0.776
#   [saved] stress_wesad_hrv_regre_mlp: {'rmse': 1.0900460481643677, 'mae': 0.7757946848869324, 'notes': 'WESAD-HRV regression Huber MLP'}
#
# WESAD-EDA Stress Regression:
#   WESAD-EDA: RMSE=0.668  MAE=0.662
# ...

# %%
# ── Cell 3.9: Stress Detection — Artifacts, Sample Predictions & Confusion Matrix ──
# Saves WESAD-HRV MLP weights; shows sample predictions for WESAD-HRV and SWELL-HRV;
# plots the WESAD-HRV test confusion matrix.

import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix

print('=' * 60)
print('  STRESS DETECTION — ARTIFACTS & SAMPLE OUTPUT')
print('=' * 60)

# ── 1. Save WESAD-HRV MLP weights ──
if 'model_wh' in dir() and model_wh is not None:
    _wh_path = OUTPUT_DIR / 'wesad_hrv_mlp_best.pth'
    torch.save(model_wh.state_dict(), str(_wh_path))
    print(f'[SAVED] WESAD-HRV MLP state_dict -> {_wh_path.name}')
else:
    print('[SKIP] model_wh not in memory (run Cell 3.7 first)')

# ── 2. WESAD-HRV sample predictions ──
print('\n── WESAD-HRV: 10 Sample Predictions (Binary Stress) ──')
_wh_ok = ('X_wh_te' in dir() and X_wh_te is not None and
           'y_wh_te' in dir() and y_wh_te is not None and
           'model_wh' in dir() and model_wh is not None)
if _wh_ok:
    import torch
    from torch.utils.data import DataLoader, TensorDataset
    model_wh.eval()
    _wh_tensor = torch.tensor(X_wh_te[:10], dtype=torch.float32)
    _device = next(model_wh.parameters()).device
    with torch.no_grad():
        _wh_logits = model_wh(_wh_tensor.to(_device))
        _wh_probs  = torch.softmax(_wh_logits, dim=1).cpu().numpy()
        _wh_preds  = _wh_logits.argmax(dim=1).cpu().numpy()
    _stress_labels = ['No Stress', 'Stress']
    _wh_df = pd.DataFrame({
        'Sample'       : range(1, 11),
        'True'         : [_stress_labels[int(l)] for l in y_wh_te[:10]],
        'Predicted'    : [_stress_labels[int(p)] for p in _wh_preds],
        'P(Stress)'    : [f'{p[1]:.3f}' for p in _wh_probs],
        'Correct?'     : ['YES' if t == p else 'NO'
                          for t, p in zip(y_wh_te[:10], _wh_preds)]
    })
    print(_wh_df.to_string(index=False))
else:
    print('[SKIP] WESAD-HRV test data or model_wh not available')

# ── 3. SWELL-HRV sample predictions ──
print('\n── SWELL-HRV: 10 Sample Predictions (3-Class Stress) ──')
_sw_ok = ('X_sw_te' in dir() and X_sw_te is not None and
           'y_sw_te' in dir() and y_sw_te is not None and
           'model_sw' in dir() and model_sw is not None)
if _sw_ok:
    model_sw.eval()
    _sw_tensor = torch.tensor(X_sw_te[:10], dtype=torch.float32)
    _dev_sw = next(model_sw.parameters()).device
    with torch.no_grad():
        _sw_logits = model_sw(_sw_tensor.to(_dev_sw))
        _sw_preds  = _sw_logits.argmax(dim=1).cpu().numpy()
    _sw_label_map = {0: 'No Stress', 1: 'Time Pressure', 2: 'Interruption'}
    _sw_df = pd.DataFrame({
        'Sample'    : range(1, 11),
        'True'      : [_sw_label_map.get(int(l), str(l)) for l in y_sw_te[:10]],
        'Predicted' : [_sw_label_map.get(int(p), str(p)) for p in _sw_preds],
        'Correct?'  : ['YES' if t == p else 'NO'
                       for t, p in zip(y_sw_te[:10], _sw_preds)]
    })
    print(_sw_df.to_string(index=False))
else:
    print('[SKIP] SWELL-HRV test data or model_sw not available in memory')

# ── 4. WESAD-HRV confusion matrix ──
print('\n── Confusion Matrix: WESAD-HRV MLP (Test Set) ──')
if _wh_ok:
    model_wh.eval()
    _all_wh = torch.tensor(X_wh_te, dtype=torch.float32)
    with torch.no_grad():
        _all_preds_wh = model_wh(_all_wh.to(_device)).argmax(dim=1).cpu().numpy()
    _cm_wh = confusion_matrix(y_wh_te, _all_preds_wh)
    fig, ax = plt.subplots(figsize=(6, 5))
    ConfusionMatrixDisplay(_cm_wh,
        display_labels=['No Stress', 'Stress']).plot(
        ax=ax, colorbar=True, cmap='Purples')
    ax.set_title('WESAD-HRV MLP — Test Set Confusion Matrix', fontsize=13)
    plt.tight_layout()
    _wh_cm_path = OUTPUT_DIR / 'wesad_hrv_confusion_matrix.png'
    plt.savefig(str(_wh_cm_path), dpi=120, bbox_inches='tight')
    plt.show()
    print(f'[SAVED] {_wh_cm_path.name}')
else:
    print('[SKIP] WESAD-HRV data or model_wh not available')
# Out:
# ...
#   STRESS DETECTION — ARTIFACTS & SAMPLE OUTPUT
# ...
# [SAVED] WESAD-HRV MLP state_dict -> wesad_hrv_mlp_best.pth
#
# ── WESAD-HRV: 10 Sample Predictions (Binary Stress) ──
#  Sample      True Predicted P(Stress) Correct?
#       1 No Stress No Stress     0.004      YES
#       2 No Stress No Stress     0.000      YES
#       3 No Stress No Stress     0.000      YES
#       4 No Stress No Stress     0.307      YES
#       5    Stress    Stress     1.000      YES
#       6 No Stress No Stress     0.024      YES
#       7 No Stress No Stress     0.042      YES
#       8    Stress    Stress     1.000      YES
#       9    Stress    Stress     1.000      YES
#      10    Stress    Stress     1.000      YES
#
# ── SWELL-HRV: 10 Sample Predictions (3-Class Stress) ──
# [SKIP] SWELL-HRV test data or model_sw not available in memory
#
# ── Confusion Matrix: WESAD-HRV MLP (Test Set) ──
# [SAVED] wesad_hrv_confusion_matrix.png

# %%
# ── Cell 3.9b: ROC Curve — WESAD-HRV Binary Stress Detection ──
# Plots the ROC curve for the best WESAD-HRV MLP on the test set.
# Guard-wrapped: skips gracefully if model_wh or test data are not in memory.

import torch
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

print('=' * 60)
print('  ROC CURVE — WESAD-HRV STRESS DETECTION')
print('=' * 60)

_wh_roc_ok = ('model_wh' in dir() and model_wh is not None and
               'X_wh_te' in dir() and X_wh_te is not None and
               'y_wh_te' in dir() and y_wh_te is not None)

fig, ax = plt.subplots(figsize=(6, 5))
if _wh_roc_ok:
    model_wh.eval()
    _dev_wh = next(model_wh.parameters()).device
    _tensor_all = torch.tensor(X_wh_te, dtype=torch.float32).to(_dev_wh)
    with torch.no_grad():
        _logits_all = model_wh(_tensor_all)
        _probs_wh   = torch.softmax(_logits_all, dim=1)[:, 1].cpu().numpy()
    fpr_wh, tpr_wh, _ = roc_curve(y_wh_te, _probs_wh)
    roc_auc_wh = auc(fpr_wh, tpr_wh)
    ax.plot(fpr_wh, tpr_wh, color='darkorchid', lw=2,
            label=f'MLP Best Config (AUC = {roc_auc_wh:.3f})')
    ax.plot([0, 1], [0, 1], 'k--', lw=1, label='Random (AUC = 0.500)')
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('WESAD-HRV: Binary Stress Detection\nROC Curve (Test Set)', fontsize=11)
    ax.legend(loc='lower right', fontsize=9)
    ax.set_xlim([0, 1]); ax.set_ylim([0, 1.02])
    ax.grid(alpha=0.3)
    print(f'WESAD-HRV ROC-AUC = {roc_auc_wh:.4f}')
else:
    ax.text(0.5, 0.5, 'WESAD-HRV data\nor model_wh not available',
            ha='center', va='center', transform=ax.transAxes, fontsize=11)
    ax.set_title('WESAD-HRV ROC (unavailable)')
    print('[SKIP] WESAD-HRV ROC — model_wh or test data not in memory')

plt.tight_layout()
_roc3_path = OUTPUT_DIR / 'wesad_hrv_roc_curve.png'
plt.savefig(str(_roc3_path), dpi=120, bbox_inches='tight')
plt.show()
print(f'[SAVED] {_roc3_path.name}')
# Out:
# ...
#   ROC CURVE — WESAD-HRV STRESS DETECTION
# ...
# WESAD-HRV ROC-AUC = 0.8271
# [SAVED] wesad_hrv_roc_curve.png

# %%
# ── Cell 3.8: Stress Detection Summary Table ──
stress_keys = [k for k in RESULTS if k.startswith("stress_")]
stress_summary = []
for k in stress_keys:
    r = RESULTS[k]
    stress_summary.append({
        "Key":          k,
        "Val Accuracy": r.get("accuracy", "-"),
        "Macro-F1":     r.get("macro_f1", "-"),
        "Notes":        r.get("notes", "")
    })

print("="*90)
print("  Stress Detection — All Experiment Results")
print("="*90)
print(pd.DataFrame(stress_summary).to_string(index=False))
# Out:
# ...
#   Stress Detection — All Experiment Results
# ...
#                                 Key Val Accuracy  Macro-F1                                   Notes
#        stress_xgb_swell-hrv_3-class     0.508266  0.508315          XGB baseline SWELL-HRV 3-class
#         stress_xgb_swell-hrv_binary     0.678642   0.40428           XGB baseline SWELL-HRV binary
#         stress_xgb_wesad-hrv_binary      0.91713  0.916979           XGB baseline WESAD-HRV binary
#  stress_xgb_swell-eda_3-class_fixed       0.4128  0.378334  XGB baseline SWELL-EDA 3-class (fixed)
#         stress_xgb_swell-eda_binary     0.725672  0.420516           XGB baseline SWELL-EDA binary
#         stress_xgb_wesad-eda_binary     0.655639  0.655391           XGB baseline WESAD-EDA binary
#          stress_regre_xgb_swell_hrv            -         -                 XGB regressor SWELL-HRV
#          stress_regre_xgb_swell_eda            -         -                 XGB regressor SWELL-EDA
# ...

# %% [markdown]
# ---
# # Section 4 — Grand Experiment Summary & Key Findings
#
# Consolidates all results from Sections 1–3 and provides a roadmap for Milestone 5.

# %%
# ── Cell 4.0: All Results Consolidated Table ──

all_rows = []
for key, metrics in RESULTS.items():
    # Infer dataset and task from key prefix
    if key.startswith("rav_"):
        dataset, task = "RAVDESS", "8-class emotion"
    elif key.startswith("daic_phq"):
        dataset, task = "DAIC-WOZ", "PHQ-8 regression"
    elif key.startswith("daic_"):
        dataset, task = "DAIC-WOZ", "Depression binary"
    elif key.startswith("modma_"):
        dataset, task = "MODMA", "MDD vs HC"
    elif key.startswith("stress_"):
        dataset, task = "Stress (SWELL/WESAD)", "Stress classification"
    else:
        dataset, task = "Unknown", "Unknown"

    acc  = metrics.get("accuracy", metrics.get("rmse", "-"))
    f1   = metrics.get("macro_f1", "-")
    note = metrics.get("notes", "")

    # Extract key hyperparams from notes
    all_rows.append({
        "Dataset":       dataset,
        "Task":          task,
        "Experiment":    key,
        "Val Acc/RMSE":  round(float(acc),4) if acc != "-" else "-",
        "Val Macro-F1":  round(float(f1),4)  if f1  != "-" else "-",
        "Notes":         note
    })

grand_df = pd.DataFrame(all_rows)
grand_df = grand_df.sort_values(["Dataset","Task","Experiment"])

print("="*120)
print("  MILESTONE 4 — GRAND RESULTS TABLE")
print("="*120)
print(grand_df.to_string(index=False))

# Save to CSV
grand_df.to_csv(OUTPUT_DIR / "milestone4_grand_results.csv", index=False)
print(f"\nSaved to: {OUTPUT_DIR / 'milestone4_grand_results.csv'}")

# Count total experiments
print(f"\nTotal experiments run: {len(grand_df)}")
print(f"Datasets covered: {grand_df['Dataset'].nunique()}")
# Out:
# ...
#   MILESTONE 4 — GRAND RESULTS TABLE
# ...
#              Dataset                  Task                          Experiment Val Acc/RMSE Val Macro-F1                                                                 Notes
#             DAIC-WOZ     Depression binary         daic_acoustic_combined_test            -       0.4683                                     Acoustic XGB train+val+SMOTE test
#             DAIC-WOZ     Depression binary                 daic_acoustic_tuned          0.6       0.5717                                          XGB acoustic depth=2 lr=0.05
#             DAIC-WOZ     Depression binary          daic_fusion_combined_smote       0.5957       0.4175                     Train+Val combined + SMOTE, evaluated on test set
#             DAIC-WOZ     Depression binary                  daic_fusion_logreg       0.6286       0.4485                                                           LogReg meta
# ...

# %% [markdown]
# ## Cell 4.1 — Key Findings & Milestone 5 Roadmap
#
# ### Per-Dataset Findings
#
# **RAVDESS (8-class Emotion Recognition)**
# - XGBoost outperforms all other models; best val Macro-F1 = **0.472** (grid + regularisation tuned).
# - Final XGB on train+val (1140 samples): **test Macro-F1 = 0.486** — 28% above M3 baseline (0.38).
# - Best XGB config: max_depth=2, lr=0.1, reg_alpha=0.5, reg_lambda=1.0.
# - PyTorch MLP best val F1 = **0.328** (AdamW) — significantly below XGB; 840 samples is insufficient for MLP.
# - Dropout=0.3 + no weight decay was optimal; higher dropout hurts convergence on this small dataset.
# - LR schedulers did **not** improve results: No Scheduler (F1=0.289) > ReduceLROnPlateau (0.267) > CosineAnneal (0.241). Constant LR wins on small datasets.
#
# **DAIC-WOZ (Depression Detection)**
# - Acoustic branch is the strongest single modality: val F1 = **0.572**.
# - Feature enrichment 448 → 2231 + XGB direct: **test F1 = 0.603, acc = 68.6%** — best result achieved.
# - Threshold optimisation (0.45 instead of 0.5): val F1 jumps 0.449 → **0.624**.
# - **SMOTE on combined train+val hurts test F1** (0.572 → 0.506): synthesised minority samples do not generalise to the 14 real depressed test cases.
# - PHQ-8 regression: Huber loss (RMSE=6.51) outperforms MSE (6.61) on enriched features.
# - Class imbalance (77:30) requires scale_pos_weight; ignoring it causes near-zero recall for depressed class.
#
# **MODMA Audio (MDD vs HC)**
# - Extreme small-data (N=44 CV pool): SVM and XGB both achieve **test acc = 87.5%, F1 = 0.873**.
# - Top-100 features by ANOVA F-score significantly outperforms all 1002 features (CV F1: 0.903 vs 0.714).
# - Heavy XGB regularisation (reg_alpha=1–2, max_depth=2) prevents severe overfitting.
# - ⚠️ **Bottleneck**: only 8 test samples — test scores are statistically unreliable; subject-level CV essential.
#
# **Stress Detection (SWELL / WESAD)**
# - XGBoost dominates on large tabular HRV/EDA features: WESAD-HRV binary **F1 = 0.917**.
# - SWELL-HRV MLP **severe overfitting**: train_acc=99.8%, val_acc=30.7%, gap=0.69 — even Dropout(0.7)+L2(1e-2) cannot close this gap. Root cause: 126K windows from 25 subjects; model memorises subject-specific patterns.
# - WESAD-HRV MLP (binary) achieves **test F1 = 0.741** using transferred SWELL architecture (Wider [128,64]).
# - LR schedulers on large stress data: No Scheduler wins — cosine decay prematurely reduces LR before convergence.
#
# ---
#
# ### Optimisation Insights
#
# | Aspect | Finding |
# |---|---|
# | **Best optimiser** | AdamW (lr=1e-3, wd=1e-4) dominated across all MLP experiments |
# | **SGD** | SGD+Momentum competitive only with tuned LR; needs 3–5× more epochs |
# | **Scheduler** | No benefit on small/tabular datasets; constant LR wins in 4/5 experiments |
# | **Learning rate** | 1e-3 for Adam variants; 0.01–0.1 for XGBoost (shallower trees prefer higher LR) |
# | **Early stopping** | Critical for XGBoost on small datasets (DAIC, MODMA); saves 30–50% trees |
#
# ### Regularisation Insights
#
# | Technique | Effect |
# |---|---|
# | **Dropout(0.3)** | Reduces overfitting; >0.4 hurts convergence on small datasets |
# | **Weight decay 1e-4** | Small but consistent improvement over no regularisation |
# | **BatchNorm** | Stabilises training curves; critical for deep architectures |
# | **Combined (all three)** | Best generalisation; train-val gap drops 30–50% |
# | **XGB L1 (reg_alpha)** | Effective for high-dim features (MODMA 1002-dim); promotes sparsity |
# | **XGB L2 (reg_lambda)** | Best for RAVDESS; smoother weight shrinkage than L1 |
# | **SMOTE** | Helps cross-val F1 on DAIC but hurts test set — use cautiously on tiny datasets |
#
# ---
#
# ### Milestone 5 Roadmap
#
# 1. **Full test-set evaluation** — Final metrics on held-out test sets for all best M4 configs.
# 2. **Model calibration** — Platt scaling / temperature scaling for depression probability outputs.
# 3. **Error analysis** — Per-class confusion matrices; identify systematic failure modes.
# 4. **SHAP interpretability** — Feature importance for DAIC-WOZ acoustic branch and RAVDESS XGB.
# 5. **Cross-dataset generalisation** — Test DAIC-WOZ acoustic model on MODMA.
# 6. **Ensemble strategies** — Voting ensemble of top-3 DAIC-WOZ configs.
# 7. **EDA/HRV fusion** — Combine SWELL-HRV + SWELL-EDA for richer stress representation.
# 8. **Final report** — Consolidate all findings into Group 6 project report.

# %%
# ── Cell 4.1b: Save Training Log + Final Artifact Inventory ──
# Persists the full RESULTS dict as JSON so training runs are reproducible.
# Lists every saved file in OUTPUT_DIR with size. Prints best-model summary.

import json as _json, os
import pandas as pd

print('=' * 70)
print('  MILESTONE 4 — FINAL ARTIFACT INVENTORY')
print('=' * 70)

# ── 1. Save full training log ──
_log_path = OUTPUT_DIR / 'milestone4_training_log.json'
with open(str(_log_path), 'w', encoding='utf-8') as _fp:
    _json.dump(RESULTS, _fp, indent=2, default=str)
print(f'[SAVED] Training log -> {_log_path.name}  ({len(RESULTS)} experiments)')

# ── 2. List all files in OUTPUT_DIR ──
print(f'\nAll saved artifacts in: {OUTPUT_DIR}')
print(f'{"File":<50} {"Size":>10}')
print('-' * 62)
_total_bytes = 0
try:
    _files = sorted(OUTPUT_DIR.iterdir())
    for _fp2 in _files:
        if _fp2.is_file():
            _sz = _fp2.stat().st_size
            _total_bytes += _sz
            _sz_str = f'{_sz/1024:.1f} KB' if _sz < 1_048_576 else f'{_sz/1_048_576:.2f} MB'
            print(f'{_fp2.name:<50} {_sz_str:>10}')
    print('-' * 62)
    _tot_str = (f'{_total_bytes/1024:.1f} KB' if _total_bytes < 1_048_576
                else f'{_total_bytes/1_048_576:.2f} MB')
    print(f'{"TOTAL":<50} {_tot_str:>10}')
except Exception as _e:
    print(f'[WARN] Could not list OUTPUT_DIR: {_e}')

# ── 3. Best-model summary ──
print('\n── Best Model per Dataset (by Macro-F1) ──')
_best_rows = []
for _k, _m in RESULTS.items():
    _f1  = _m.get('macro_f1', None)
    _acc = _m.get('accuracy', _m.get('rmse', None))
    if _f1 is not None:
        if _k.startswith('rav_'):          _ds = 'RAVDESS'
        elif _k.startswith('daic_phq'):    _ds = 'DAIC-WOZ (Regress)'
        elif _k.startswith('daic_'):       _ds = 'DAIC-WOZ'
        elif _k.startswith('modma_'):      _ds = 'MODMA'
        elif _k.startswith('stress_'):     _ds = 'Stress'
        else:                              _ds = 'Other'
        _best_rows.append({'Dataset': _ds, 'Experiment': _k,
                            'Macro-F1': round(float(_f1), 4),
                            'Acc/RMSE': round(float(_acc), 4) if _acc else '-'})
_best_df = pd.DataFrame(_best_rows)
if not _best_df.empty:
    _best_df = (_best_df.sort_values(['Dataset', 'Macro-F1'], ascending=[True, False])
                        .groupby('Dataset').first().reset_index())
    print(_best_df.to_string(index=False))
else:
    print('[WARN] RESULTS dict is empty — run all training cells first')

print('\n[DONE] All Milestone 4 artifacts saved and inventoried.')
# Out:
# ...
#   MILESTONE 4 — FINAL ARTIFACT INVENTORY
# ...
# [SAVED] Training log -> milestone4_training_log.json  (84 experiments)
#
# All saved artifacts in: /kaggle/working/models_output
# File                                                     Size
# --------------------------------------------------------------
# daic_acoustic_xgb.json                               224.7 KB
# daic_modma_confusion_matrices.png                     46.3 KB
# daic_modma_roc_curves.png                             76.1 KB
# milestone4_grand_results.csv                           7.3 KB
# milestone4_training_log.json                          12.7 KB
# modma_svm_final.pkl                                   34.0 KB
# modma_whisper_svm.pkl                                542.9 KB
# modma_whisper_xgb.json                               114.6 KB
# modma_xgb_final.json                                  68.4 KB
# rav_mlp_final.pth                                    516.7 KB
# ...
